# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader 
import numpy as np
from scipy import io
import matplotlib.pyplot as plt
import argparse
import os
import copy
import time


def inital_soln(xt_grid):
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = torch.cos((30/d)*x_grid.sum(axis = 1)).reshape(-1,1)

    return u.flatten()


def exact_soln(xt_grid):
    
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = torch.cos((30/d)*x_grid.sum(axis = 1)).reshape(-1,1)*torch.exp(-t)
    
    return u.flatten()


def f_function(xt_grid):
    
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = (900/d-1)*torch.cos((30/d)*x_grid.sum(axis = 1)).reshape(-1,1)*torch.exp(-t)
    
    return u.flatten()


def stacked_grid(*args):
    # Generate meshgrid dynamically
    grids = torch.meshgrid(*args, indexing='ij')
    # Flatten and stack the grids into a single tensor
    stacked = torch.hstack([g.flatten()[:, None] for g in grids])
    return stacked.float()


def cal_domain_grad(model, XTGrid, device):
    Loss = torch.nn.MSELoss(reduction='mean')

    XTGrid = XTGrid.requires_grad_(True).to(device)
    u = model.forward(XTGrid)
    
    # Compute first derivatives
    u_grad = torch.autograd.grad(outputs=u, 
                                 inputs=XTGrid, 
                                 grad_outputs=torch.ones_like(u).to(device), 
                                 create_graph=True, 
                                 allow_unused=True)[0]

    # Compute second derivatives for each spatial dimension
    u_laplacian = torch.zeros_like(u[:,0], device=device)
    for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
        ux = u_grad[:, d]
        uxx = torch.autograd.grad(outputs=ux, 
                                  inputs=XTGrid, 
                                  grad_outputs=torch.ones_like(ux).to(device), 
                                  create_graph=True, 
                                  allow_unused=True)[0][:, d]
        u_laplacian += uxx
    f = f_function(XTGrid)
    # Time derivative
    ut = u_grad[:, -1]  # Assuming last dimension is time

    # PDE residual loss (generalized heat/diffusion equation)
    lossf = Loss(ut-u_laplacian, f.flatten())

    # Compute gradient of loss function w.r.t. inputs (for adaptivity or error estimation)
    grad = torch.autograd.grad(outputs=lossf, 
                               inputs=XTGrid, 
                               grad_outputs=torch.ones_like(lossf).to(device),
                               create_graph=True,
                               allow_unused=True)[0]
    
    return grad


class RADSampler():
    def __init__(self, Nf, device, k, c, dim = 1):    
        self.device = device
        self.k = k
        self.c = c
        self.Nf = Nf
        self.dense_Nf = Nf*1
        self.dim = dim
        
    def update(self, model):
        
        x_new = torch.zeros(self.dense_Nf, self.dim, dtype = torch.float32, device=self.device).uniform_(-1, 1)
        t_new = torch.zeros(self.dense_Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
        x_t_new = torch.concatenate((x_new,t_new), axis = 1)
        
        XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True) 
        XTGrid = XTGrid.to(self.device)

        XTGrid = XTGrid.requires_grad_(True).to(self.device)
        
        u = model.forward(XTGrid)
        
        u_grad = torch.autograd.grad(outputs=u, 
                                     inputs=XTGrid, 
                                     grad_outputs=torch.ones_like(u).to(device), 
                                     create_graph=True, 
                                     allow_unused=True)[0]
    
        u_laplacian = torch.zeros_like(u[:,0], device=device)
        for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
            ux = u_grad[:, d]
            uxx = torch.autograd.grad(outputs=ux, 
                                      inputs=XTGrid, 
                                      grad_outputs=torch.ones_like(ux).to(device), 
                                      create_graph=True, 
                                      allow_unused=True)[0][:, d]
            u_laplacian += uxx
            
        f = f_function(XTGrid)
        ut = u_grad[:, -1]  
    
        err = torch.abs((ut-u_laplacian-f.flatten()))
        err = (err**self.k)/((err**self.k).mean())+self.c
        err_norm = err/(err.sum())
        
        indice = torch.multinomial(err_norm, self.Nf, replacement = True)
        XTGrid = XTGrid[indice]
        self.XTGrid = XTGrid
        
class LASSampler():
    def __init__(self, Nf, fixed_uniform, device, L_iter = 1, beta = 0.2, tau = 0.002):
        self.Nf = Nf
        self.device = device
        self.cnt = 0
        self.beta = beta
        self.tau = tau
        self.L_iter = L_iter
        self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)

    def update(self, phy_lf, model):

        x_data = self.XTGrid
        samples = x_data.clone().detach().requires_grad_(True)
        
        for t in range(1, self.L_iter + 1):
            grad = phy_lf(model, samples, self.device)
            scaler = torch.sqrt(torch.sum((grad+1e-16)**2, axis = 1)).reshape(-1,1)
            grad = grad/scaler

            with torch.no_grad():
                samples = samples + self.tau * grad + self.beta*torch.sqrt(torch.tensor(2 * self.tau, device=self.device)) * torch.randn(samples.shape, device=self.device)
                for i in range(samples.shape[1]):
                    if i < int(samples.shape[1]-1):
                        samples[:, i] = torch.clamp(samples[:, i], min=-1, max=1) 
                    else:
                        samples[:, i] = torch.clamp(samples[:, i], min=0, max=1)
                        
            samples = samples.clone().detach().requires_grad_(True)
        self.XTGrid = samples.detach()

class L_INFSampler():
    def __init__(self, Nf, device, step_size = 0.05 , n_iter = 20, dim = 1):

        self.Nf = Nf
        self.device = device
        self.step_size = step_size
        self.n_iter = n_iter
        self.dim = dim

    def update(self, phy_lf, model):

        x_new = torch.zeros(self.Nf, self.dim, dtype = torch.float32, device=self.device).uniform_(-1, 1)
        t_new = torch.zeros(self.Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
        x_t_new = torch.concatenate((x_new,t_new), axis = 1)
        self.XTGrid = x_t_new
            
        x_data = self.XTGrid
        samples = x_data.clone().detach().requires_grad_(True)
    
        for t in range(1, self.n_iter + 1):
            grad = phy_lf(model, samples, self.device)
            with torch.no_grad():
                samples = samples + self.step_size * torch.sign(grad)
                for i in range(samples.shape[1]):
                    if i < int(samples.shape[1]-1):
                        samples[:, i] = torch.clamp(samples[:, i], min=-1, max=1)
                    else:
                        samples[:, i] = torch.clamp(samples[:, i], min=0, max=1)
                        
            samples = samples.clone().detach().requires_grad_(True)
        self.XTGrid = samples.detach()           


class R3Sampler(nn.Module):
    def __init__(self,Nf, fixed_uniform, device):
        super(R3Sampler, self).__init__()
        self.Nf = Nf
        self.device = device
        self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
    
    def update(self, loss_aver, loss_ele):
        with torch.no_grad():
            cho_i = loss_ele > loss_aver
            cho_i = cho_i.to('cpu')
            self.XTGrid = self.XTGrid[cho_i].detach()
            need_n_sample = self.Nf-self.XTGrid.shape[0]
            x_new = torch.zeros(need_n_sample, self.XTGrid.shape[1]-1, dtype = torch.float32, device=self.device).uniform_(-1, 1)
            t_new = torch.zeros(need_n_sample, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
            x_t_new = torch.concatenate((x_new,t_new), axis = 1)
            self.XTGrid = torch.concatenate((self.XTGrid, x_t_new), axis = 0)
            self.XTGrid = torch.tensor(self.XTGrid, dtype = torch.float32, device=self.device, requires_grad=True)
    
class PINN(nn.Module):
    def __init__(self,k , c , t, exact_XYT, exact_u, LBs, UBs, Layers, N0, Nb, Nf, 
                 Activation = nn.Tanh(), 
                 model_name = "PINN.model", device = 'cpu',
                  display_freq = 100, samp = 'fixed' ):
        
        super(PINN, self).__init__()
        
        
        self.LBs = torch.tensor(LBs, dtype=torch.float32)
        self.UBs = torch.tensor(UBs, dtype=torch.float32)
        
        self.Layers = Layers
        self.in_dim  = Layers[0]
        self.out_dim = Layers[-1]
        self.Activation = Activation
        
        self.device = device
        
        x_init = torch.zeros(Nf, len(self.LBs) - 1, dtype = torch.float32, device=self.device).uniform_(0, UBs[0])
        t_init = torch.zeros(Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, UBs[-1])
        x_t_init = torch.concatenate((x_init,t_init), axis = 1)
        self.fixed_uniform = torch.tensor(x_t_init, dtype = torch.float32, device=self.device, requires_grad=True)
        
        self.N0 = N0
        self.Nb = Nb
        self.Nf = Nf
        
        self.t = t
        self.exact_XYT = exact_XYT
        self.exact_u = exact_u.reshape(-1,1)
        
        self.XT0, self.u0  = self.InitialCondition(self.N0, self.LBs, self.UBs)
        self.boundary_set = self.BoundaryCondition(self.Nb, self.LBs, self.UBs)
        
        self.XT0 = self.XT0.to(device)
        self.u0 = self.u0.to(device) 
        
        self._nn = self.build_model()
        self._nn.to(self.device)
        self.Loss = torch.nn.MSELoss(reduction='mean')
        
        self.model_name = model_name
        self.display_freq = display_freq
        
        self.k = k
        self.c = c
        self.X_star = self.exact_XYT
        self.method = samp
        
        self.r3_sample = R3Sampler(self.Nf, self.fixed_uniform, device)
        self.las = LASSampler(self.Nf, fixed_uniform=self.fixed_uniform, device=self.device, L_iter = 1, beta = 0.2, tau=1e-2)
        self.l_inf = L_INFSampler(self.Nf, device=self.device, step_size = 0.05 , n_iter = 20, dim = len(self.LBs) - 1)
        self.rad = RADSampler(Nf = self.Nf, device=self.device, k = self.k, c=self.c, dim = len(self.LBs) - 1)
        
    
    def build_model(self):
        Seq = nn.Sequential()
        for ii in range(len(self.Layers)-1):
            this_module = nn.Linear(self.Layers[ii], self.Layers[ii+1])
            nn.init.xavier_normal_(this_module.weight)
            Seq.add_module("Linear" + str(ii), this_module)
            if not ii == len(self.Layers)-2:
                Seq.add_module("Activation" + str(ii), self.Activation)
        return Seq
        
    def forward(self, x):
        return self._nn.forward(x.to(self.device)).reshape(-1)

    def InitialCondition(self, N0, LB, UB):
        n_per_dim = int(np.round(N0**(1/len(LB[:-1]))))
#         n_per_dim = int(np.round(np.sqrt(N0)))
        nodes = []
        for i in range(len(LB)-1):
            X = torch.linspace(LB[i], UB[i], n_per_dim).float()
            nodes.append(X)
            
        t_in = torch.tensor([LB[-1]]).float()
        nodes.append(t_in)
        
        XT_in = stacked_grid(*nodes)
        u0 = inital_soln(XT_in)
        return XT_in, u0

    def ICLoss(self):
        uv0_pred = self.forward(self.XT0)
        loss = self.Loss(uv0_pred, self.u0.to(self.device))
        return loss 

    def BoundaryPoints(self, nb, boundary_index, LBs, UBs, boundary_type):
        """
        Generalized function to get boundary points in an N-dimensional space.
        - `boundary_index`: Index of the dimension where the boundary is applied.
        - `nb`: Number of boundary points.
        - `LBs`, `UBs`: Lower and upper bounds for each dimension.
        - `boundary_type`: 'lower' for the lower boundary, 'upper' for the upper boundary.
        """
        n_per_dim = int(np.round(nb ** (1 / (len(LBs) - 1))))  # Distribute points across remaining dimensions
        
        # Create grid ranges for each dimension
        grid_ranges = []
        for i in range(len(LBs)  - 1):  # Excluding time
            if i == boundary_index:
                if boundary_type == 'lower':
                    grid_ranges.append(torch.tensor([LBs[i]]).float().to(self.device))  # Fixed lower boundary position
                else:
                    grid_ranges.append(torch.tensor([UBs[i]]).float().to(self.device))  # Fixed upper boundary position
            else:
                grid_ranges.append(torch.linspace(LBs[i], UBs[i], n_per_dim).float().to(self.device))

        # Time dimension (last dimension)
        grid_ranges.append(torch.linspace(LBs[-1], UBs[-1], nb).float().to(self.device))

        return stacked_grid(*grid_ranges)

    
    def BoundaryCondition(self, Nb, LBs, UBs):
        """
        Generalized function to get all boundary conditions in an N-dimensional space.
        - `Nb`: Total number of boundary points.
        - `LBs`, `UBs`: Lower and upper bounds for each dimension.
        """
        nb = int(np.round(Nb / (2 * (len(LBs) - 1))))  # Divide points across boundary faces
        boundary_sets = []
        
        for d in range(len(LBs) - 1):  # Iterate over all spatial dimensions
            lower_boundary = self.BoundaryPoints(nb, d, LBs, UBs, 'lower')
            upper_boundary = self.BoundaryPoints(nb, d, LBs, UBs, 'upper')
            boundary_sets.append((lower_boundary, upper_boundary))

        return boundary_sets  # Returns pairs of boundaries per dimension

    def BCLoss(self):
        """
        Compute boundary condition loss given a model, exact solution, and loss function.
        """
        total_loss = 0
        for lower, upper in self.boundary_set:
            U_L, U_R = self.forward(lower), self.forward(upper)
            UL_exact, UR_exact = exact_soln(lower), exact_soln(upper)

            total_loss += self.Loss(U_L, UL_exact) + self.Loss(U_R, UR_exact)
        
        return total_loss
    
    def PhysicsLoss(self, XTGrid):
        XTGrid = XTGrid.requires_grad_(True).to(device)
        u = self.forward(XTGrid)

        # Compute first derivatives
        u_grad = torch.autograd.grad(outputs=u, 
                                     inputs=XTGrid, 
                                     grad_outputs=torch.ones_like(u).to(device), 
                                     create_graph=True, 
                                     allow_unused=True)[0]

        # Compute second derivatives for each spatial dimension
        u_laplacian = torch.zeros_like(u, device=device)
        for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
            ux = u_grad[:, d]
            uxx = torch.autograd.grad(outputs=ux, 
                                      inputs=XTGrid, 
                                      grad_outputs=torch.ones_like(ux).to(device), 
                                      create_graph=True, 
                                      allow_unused=True)[0][:, d]
            u_laplacian += uxx
            
        f = f_function(XTGrid)

        # Time derivative
        ut = u_grad[:, -1]  # Assuming last dimension is time

        loss2 = (u_laplacian - ut+f.flatten())**2
        loss1 = loss2.mean()

        return loss1, loss2 

    def Train(self, n_iters, weights=(1.0,1.0,1.0)):
        params = list(self.parameters())
        optimizer = optim.Adam(params, lr=1e-3)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 5000, gamma=0.9, last_epoch=-1)
        min_loss = 999999.0
        Training_Losses = [-10]*n_iters
        Test_Losses = []
        rel_error = [-10]*(1+n_iters//10)
        
        for jj in range(n_iters):
            Total_ICLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            Total_BCLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            Total_PhysicsLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            
            Total_ICLoss = Total_ICLoss + self.ICLoss()
            Total_BCLoss = Total_BCLoss + self.BCLoss()
            
            if self.method =='r3':
                if jj == 0:
                    XTGrid = self.r3_sample.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype = torch.float32, device=self.device, requires_grad=True) 
                else:
                    with torch.no_grad():
                        self.r3_sample.update(loss1, loss2)
                        XTGrid = self.r3_sample.XTGrid
                        XTGrid = torch.tensor(XTGrid, dtype = torch.float32, device=self.device, requires_grad=True) 
                        
            elif self.method == 'las':
                if jj == 0:
                    XTGrid = self.las.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                else:
                    if self.las.cnt % 1 == 0:# 4,6,8,10 cnt = 4, 
                        self.las.update(cal_domain_grad, self._nn)
                    XTGrid = self.las.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                self.las.cnt += 1
            
            elif self.method =='l_inf':
                    self.l_inf.update(cal_domain_grad, self._nn)
                    XTGrid = self.l_inf.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                
            elif self.method =='rad':
                    self.rad.update(self._nn)
                    XTGrid = self.rad.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)   
            
            elif self.method =='fixed':
                    XTGrid = torch.tensor(self.fixed_uniform, dtype = torch.float32, device=self.device, requires_grad=True) 
            
            elif self.method =='random-r':
                    x_new = torch.zeros(self.Nf, len(self.LBs) - 1, dtype = torch.float32, device=self.device).uniform_(-1, 1)
                    t_new = torch.zeros(self.Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
                    x_t_new = torch.concatenate((x_new,t_new), axis = 1)
                    XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True) 
                
            optimizer.zero_grad()    
            loss1, loss2 = self.PhysicsLoss(XTGrid) # For r3 method, loss2 contains element-wise errors
            
            Total_PhysicsLoss = Total_PhysicsLoss + loss1
            Total_Loss = weights[0]*Total_ICLoss + weights[1]*Total_BCLoss\
                        + weights[2]*Total_PhysicsLoss 
            
            Total_Loss.backward()
            optimizer.step()
            scheduler.step()
            if Total_Loss < min_loss:
                torch.save(self._nn.state_dict(), "../models/"+self.method+'_'+str(len(self.Layers)-2)+'_'+str(self.Nf)+'.pt')
                min_loss = float(Total_Loss)
                    
            Training_Losses[jj] = float(Total_Loss)
            
            if (jj+1) % self.display_freq == 0:
                with torch.no_grad():
                    outputs = self.forward(self.X_star)
                    outputs = outputs.reshape(-1,1)
                    re = np.linalg.norm(self.exact_u.cpu()-outputs.cpu().detach()) / np.linalg.norm(self.exact_u.cpu().detach())
                    rel_error[int((jj+1)/10)] = float(re*100)
                    
                print("Iteration Number = {}".format(jj+1))
                print("\tIC Loss = {}".format(float(Total_ICLoss)))
                print("\tBC Loss = {}".format(float(Total_BCLoss)))
                print("\tPhysics Loss = {}".format(float(Total_PhysicsLoss)))
                print("\tTraining Loss = {}".format(float(Total_Loss)))
                print("\tRelative L2 error (test) = {}".format(float(re*100)))

        return Training_Losses, rel_error


if __name__ == "__main__":
                
        parser = argparse.ArgumentParser()
        parser.add_argument('--nodes', type=int, default = 128, help='The number of nodes per hidden layer in the neural network')
        parser.add_argument('--layers', type=int, default = 8, help='The number of hidden layers in the neural network')
        parser.add_argument('--N0', type=int, default = 250, help='The number of points to use on the initial condition')
        parser.add_argument('--Nb', type=int, default = 250, help='The number of points to use on the boundary condition')
        parser.add_argument('--Nf', type=int, default = 1000, help='The number of collocation points to use')
        parser.add_argument('--epochs', type=int, default = 10000, help='The number of epochs to train the neural network')
        parser.add_argument('--method', type=str, default='random-r', help='Sampling method') # fixed, random-r, rad, r3, l_inf, las 
        parser.add_argument('--model-name', type=str, default='PINN_model', help='File name to save the model')
        parser.add_argument('--display-freq', type=int, default=10, help='How often to display loss information')
        parser.add_argument('-f')
        args = parser.parse_args()

        if not os.path.exists("../models/"):
            os.mkdir("../models/")
            
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        NHiddenLayers = args.layers

        desired_dim = 6
    
        LBs = [-1]*desired_dim
        UBs = [1]*desired_dim

        LBs.append(0)
        UBs.append(1)

        Nx = 8
        Nt = 8
        mesh_nodes = []
    
        for i in range(len(LBs)-1):
            X = torch.linspace(LBs[i], UBs[i], Nx).float()
            mesh_nodes.append(X)
        
        T = torch.linspace(LBs[-1], UBs[-1], Nt).float()
        mesh_nodes.append(T)
        
        XYT = stacked_grid(*mesh_nodes)
        Exact_U = exact_soln(XYT)
        Activation = nn.Tanh()
    
        Layers = [desired_dim+1] + [args.nodes]*NHiddenLayers + [1]

        k = 1
        c = 1

        repeat = [0, 1, 2, 3, 4]
        for i in repeat:
            pinn = PINN(  k = k,
                          c = c,
                          t= T,
                          exact_XYT = XYT,
                          exact_u = Exact_U,
                          Layers = Layers,
                          LBs = LBs,
                          UBs = UBs,
                          N0 = args.N0,
                          Nb = args.Nb,
                          Nf = args.Nf,
                          Activation = Activation,
                          device = device,
                          model_name = "../models/" + args.model_name + ".model_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i),
                          display_freq = args.display_freq, samp = args.method )

            Losses_train, Losses_rel_l2 = pinn.Train(args.epochs, weights = (1, 1, 1)) # initial, boundary, residual

            torch.save(Losses_train, "../models/" + args.model_name + ".loss_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
            torch.save(Losses_rel_l2, "../models/" + args.model_name + ".rel_l2_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
# Out:
# /tmp/ipykernel_1103819/2562604190.py:248: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.fixed_uniform = torch.tensor(x_t_init, dtype = torch.float32, device=self.device, requires_grad=True)
# /tmp/ipykernel_1103819/2562604190.py:212: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
# /tmp/ipykernel_1103819/2562604190.py:151: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
# /tmp/ipykernel_1103819/2562604190.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True)
# Iteration Number = 10
# 	IC Loss = 0.6168827414512634
# 	BC Loss = 5.069838523864746
# 	Physics Loss = 4752.1162109375
# 	Training Loss = 4757.802734375
# 	Relative L2 error (test) = 111.03110313415527
# Iteration Number = 20
# 	IC Loss = 0.4871157109737396
# 	BC Loss = 3.6301751136779785
# 	Physics Loss = 5045.39501953125
# 	Training Loss = 5049.51220703125
# 	Relative L2 error (test) = 103.77471446990967
# Iteration Number = 30
# 	IC Loss = 0.5014821887016296
# 	BC Loss = 3.6682448387145996
# 	Physics Loss = 5011.0703125
# 	Training Loss = 5015.240234375
# 	Relative L2 error (test) = 102.54703760147095
# Iteration Number = 40
# 	IC Loss = 0.5001886487007141
# 	BC Loss = 3.6517395973205566
# 	Physics Loss = 4664.3232421875
# 	Training Loss = 4668.47509765625
# 	Relative L2 error (test) = 101.66395902633667
# Iteration Number = 50
# 	IC Loss = 0.5001784563064575
# 	BC Loss = 3.637507915496826
# 	Physics Loss = 4942.18212890625
# 	Training Loss = 4946.31982421875
# 	Relative L2 error (test) = 100.68317651748657
# Iteration Number = 60
# 	IC Loss = 0.4893515110015869
# 	BC Loss = 3.611746311187744
# 	Physics Loss = 4969.46337890625
# 	Training Loss = 4973.564453125
# 	Relative L2 error (test) = 101.06825828552246
# Iteration Number = 70
# 	IC Loss = 0.5284379720687866
# 	BC Loss = 3.7684125900268555
# 	Physics Loss = 4828.60546875
# 	Training Loss = 4832.90234375
# 	Relative L2 error (test) = 105.24442195892334
# Iteration Number = 80
# 	IC Loss = 0.5371483564376831
# 	BC Loss = 3.8217945098876953
# 	Physics Loss = 4670.7314453125
# 	Training Loss = 4675.09033203125
# 	Relative L2 error (test) = 106.57597780227661
# Iteration Number = 90
# 	IC Loss = 0.6041240692138672
# 	BC Loss = 4.806055545806885
# 	Physics Loss = 5013.00341796875
# 	Training Loss = 5018.41357421875
# 	Relative L2 error (test) = 115.3261661529541
# Iteration Number = 100
# 	IC Loss = 0.504676103591919
# 	BC Loss = 3.6292786598205566
# 	Physics Loss = 4784.1904296875
# 	Training Loss = 4788.32421875
# 	Relative L2 error (test) = 102.47071981430054
# Iteration Number = 110
# 	IC Loss = 0.4934460520744324
# 	BC Loss = 3.6285438537597656
# 	Physics Loss = 4650.951171875
# 	Training Loss = 4655.0732421875
# 	Relative L2 error (test) = 101.38994455337524
# Iteration Number = 120
# 	IC Loss = 0.49545741081237793
# 	BC Loss = 3.572317600250244
# 	Physics Loss = 4741.2861328125
# 	Training Loss = 4745.35400390625
# 	Relative L2 error (test) = 101.94178819656372
# Iteration Number = 130
# 	IC Loss = 0.47630438208580017
# 	BC Loss = 3.788536548614502
# 	Physics Loss = 5019.71142578125
# 	Training Loss = 5023.97607421875
# 	Relative L2 error (test) = 108.13400745391846
# Iteration Number = 140
# 	IC Loss = 0.49525994062423706
# 	BC Loss = 3.6207785606384277
# 	Physics Loss = 4826.37841796875
# 	Training Loss = 4830.49462890625
# 	Relative L2 error (test) = 101.5525221824646
# Iteration Number = 150
# 	IC Loss = 0.5012249946594238
# 	BC Loss = 3.5821661949157715
# 	Physics Loss = 4780.73388671875
# 	Training Loss = 4784.8173828125
# 	Relative L2 error (test) = 100.82494020462036
# Iteration Number = 160
# 	IC Loss = 0.5026977062225342
# 	BC Loss = 3.5704965591430664
# 	Physics Loss = 4733.70068359375
# 	Training Loss = 4737.77392578125
# 	Relative L2 error (test) = 100.19835233688354
# Iteration Number = 170
# 	IC Loss = 0.49968022108078003
# 	BC Loss = 3.5704312324523926
# 	Physics Loss = 4906.9736328125
# 	Training Loss = 4911.0439453125
# 	Relative L2 error (test) = 100.1604676246643
# Iteration Number = 180
# 	IC Loss = 0.4999343454837799
# 	BC Loss = 3.561774730682373
# 	Physics Loss = 4894.43310546875
# 	Training Loss = 4898.49462890625
# 	Relative L2 error (test) = 100.21071434020996
# Iteration Number = 190
# 	IC Loss = 0.5005168318748474
# 	BC Loss = 3.562056064605713
# 	Physics Loss = 5033.96435546875
# 	Training Loss = 5038.02685546875
# 	Relative L2 error (test) = 100.12255907058716
# Iteration Number = 200
# 	IC Loss = 0.5002686381340027
# 	BC Loss = 3.5583276748657227
# 	Physics Loss = 4689.44140625
# 	Training Loss = 4693.5
# 	Relative L2 error (test) = 100.19389390945435
# Iteration Number = 210
# 	IC Loss = 0.500231146812439
# 	BC Loss = 3.559427261352539
# 	Physics Loss = 4826.826171875
# 	Training Loss = 4830.8857421875
# 	Relative L2 error (test) = 100.0571608543396
# Iteration Number = 220
# 	IC Loss = 0.5003510117530823
# 	BC Loss = 3.55993914604187
# 	Physics Loss = 4769.3984375
# 	Training Loss = 4773.45849609375
# 	Relative L2 error (test) = 100.0555157661438
# Iteration Number = 230
# 	IC Loss = 0.5007351636886597
# 	BC Loss = 3.5615696907043457
# 	Physics Loss = 4758.43896484375
# 	Training Loss = 4762.50146484375
# 	Relative L2 error (test) = 100.0665545463562
# Iteration Number = 240
# 	IC Loss = 0.5020379424095154
# 	BC Loss = 3.5780582427978516
# 	Physics Loss = 4611.8466796875
# 	Training Loss = 4615.9267578125
# 	Relative L2 error (test) = 100.27048587799072
# Iteration Number = 250
# 	IC Loss = 0.5021615624427795
# 	BC Loss = 3.5701422691345215
# 	Physics Loss = 4724.75732421875
# 	Training Loss = 4728.82958984375
# 	Relative L2 error (test) = 100.348961353302
# Iteration Number = 260
# 	IC Loss = 0.5000354051589966
# 	BC Loss = 3.555494785308838
# 	Physics Loss = 4733.92919921875
# 	Training Loss = 4737.98486328125
# 	Relative L2 error (test) = 100.13260841369629
# Iteration Number = 270
# 	IC Loss = 0.49966129660606384
# 	BC Loss = 3.554635524749756
# 	Physics Loss = 4742.05322265625
# 	Training Loss = 4746.107421875
# 	Relative L2 error (test) = 100.19739866256714
# Iteration Number = 280
# 	IC Loss = 0.49868276715278625
# 	BC Loss = 3.5557684898376465
# 	Physics Loss = 4831.265625
# 	Training Loss = 4835.3203125
# 	Relative L2 error (test) = 100.09592771530151
# Iteration Number = 290
# 	IC Loss = 0.4979754686355591
# 	BC Loss = 3.5581774711608887
# 	Physics Loss = 4800.4482421875
# 	Training Loss = 4804.50439453125
# 	Relative L2 error (test) = 100.31564235687256
# Iteration Number = 300
# 	IC Loss = 0.4964681565761566
# 	BC Loss = 3.5628647804260254
# 	Physics Loss = 4740.75830078125
# 	Training Loss = 4744.81787109375
# 	Relative L2 error (test) = 100.11985301971436
# Iteration Number = 310
# 	IC Loss = 0.4955270290374756
# 	BC Loss = 3.571104049682617
# 	Physics Loss = 4816.22216796875
# 	Training Loss = 4820.28857421875
# 	Relative L2 error (test) = 100.21423101425171
# Iteration Number = 320
# 	IC Loss = 0.49900195002555847
# 	BC Loss = 3.613518238067627
# 	Physics Loss = 4618.32275390625
# 	Training Loss = 4622.43505859375
# 	Relative L2 error (test) = 102.74078845977783
# Iteration Number = 330
# 	IC Loss = 0.5066366791725159
# 	BC Loss = 3.626875400543213
# 	Physics Loss = 4696.83544921875
# 	Training Loss = 4700.96875
# 	Relative L2 error (test) = 100.90222358703613
# Iteration Number = 340
# 	IC Loss = 0.49681010842323303
# 	BC Loss = 3.548973560333252
# 	Physics Loss = 4983.25732421875
# 	Training Loss = 4987.30322265625
# 	Relative L2 error (test) = 100.2619743347168
# Iteration Number = 350
# 	IC Loss = 0.49787524342536926
# 	BC Loss = 3.5512967109680176
# 	Physics Loss = 4375.77880859375
# 	Training Loss = 4379.828125
# 	Relative L2 error (test) = 100.14644861221313
# Iteration Number = 360
# 	IC Loss = 0.4985499680042267
# 	BC Loss = 3.5571141242980957
# 	Physics Loss = 4798.56201171875
# 	Training Loss = 4802.61767578125
# 	Relative L2 error (test) = 100.17911195755005
# Iteration Number = 370
# 	IC Loss = 0.4982115924358368
# 	BC Loss = 3.551945686340332
# 	Physics Loss = 4700.4091796875
# 	Training Loss = 4704.45947265625
# 	Relative L2 error (test) = 100.05505084991455
# Iteration Number = 380
# 	IC Loss = 0.4988521337509155
# 	BC Loss = 3.5585055351257324
# 	Physics Loss = 4613.5361328125
# 	Training Loss = 4617.59326171875
# 	Relative L2 error (test) = 100.11098384857178
# Iteration Number = 390
# 	IC Loss = 0.5011587142944336
# 	BC Loss = 3.572065591812134
# 	Physics Loss = 5102.2470703125
# 	Training Loss = 5106.3203125
# 	Relative L2 error (test) = 100.12787580490112
# Iteration Number = 400
# 	IC Loss = 0.4996028244495392
# 	BC Loss = 3.557678699493408
# 	Physics Loss = 4752.89111328125
# 	Training Loss = 4756.9482421875
# 	Relative L2 error (test) = 100.05278587341309
# Iteration Number = 410
# 	IC Loss = 0.4996234178543091
# 	BC Loss = 3.55729341506958
# 	Physics Loss = 4691.13134765625
# 	Training Loss = 4695.1884765625
# 	Relative L2 error (test) = 100.06890296936035
# Iteration Number = 420
# 	IC Loss = 0.5003107190132141
# 	BC Loss = 3.5767836570739746
# 	Physics Loss = 4947.00634765625
# 	Training Loss = 4951.08349609375
# 	Relative L2 error (test) = 100.4196286201477
# Iteration Number = 430
# 	IC Loss = 0.49981915950775146
# 	BC Loss = 3.5734810829162598
# 	Physics Loss = 4961.4150390625
# 	Training Loss = 4965.48828125
# 	Relative L2 error (test) = 100.13275146484375
# Iteration Number = 440
# 	IC Loss = 0.4988791346549988
# 	BC Loss = 3.552839756011963
# 	Physics Loss = 4678.548828125
# 	Training Loss = 4682.6005859375
# 	Relative L2 error (test) = 100.04119873046875
# Iteration Number = 450
# 	IC Loss = 0.49890244007110596
# 	BC Loss = 3.5519661903381348
# 	Physics Loss = 4737.43505859375
# 	Training Loss = 4741.48583984375
# 	Relative L2 error (test) = 100.04229545593262
# Iteration Number = 460
# 	IC Loss = 0.4994317591190338
# 	BC Loss = 3.5533244609832764
# 	Physics Loss = 4742.63427734375
# 	Training Loss = 4746.68701171875
# 	Relative L2 error (test) = 100.0220537185669
# Iteration Number = 470
# 	IC Loss = 0.498714417219162
# 	BC Loss = 3.5535049438476562
# 	Physics Loss = 4675.54248046875
# 	Training Loss = 4679.5947265625
# 	Relative L2 error (test) = 100.06651878356934
# Iteration Number = 480
# 	IC Loss = 0.49875083565711975
# 	BC Loss = 3.55232572555542
# 	Physics Loss = 4913.51953125
# 	Training Loss = 4917.57080078125
# 	Relative L2 error (test) = 100.02751350402832
# Iteration Number = 490
# 	IC Loss = 0.4992881715297699
# 	BC Loss = 3.552861213684082
# 	Physics Loss = 4717.53076171875
# 	Training Loss = 4721.5830078125
# 	Relative L2 error (test) = 100.00344514846802
# Iteration Number = 500
# 	IC Loss = 0.49871599674224854
# 	BC Loss = 3.551025629043579
# 	Physics Loss = 4849.2841796875
# 	Training Loss = 4853.333984375
# 	Relative L2 error (test) = 100.02176761627197
# Iteration Number = 510
# 	IC Loss = 0.49840638041496277
# 	BC Loss = 3.5515737533569336
# 	Physics Loss = 5048.47509765625
# 	Training Loss = 5052.52490234375
# 	Relative L2 error (test) = 100.00544786453247
# Iteration Number = 520
# 	IC Loss = 0.49865445494651794
# 	BC Loss = 3.5511269569396973
# 	Physics Loss = 4831.08056640625
# 	Training Loss = 4835.13037109375
# 	Relative L2 error (test) = 100.01204013824463
# Iteration Number = 530
# 	IC Loss = 0.49799078702926636
# 	BC Loss = 3.5500829219818115
# 	Physics Loss = 4682.12841796875
# 	Training Loss = 4686.17626953125
# 	Relative L2 error (test) = 100.03377199172974
# Iteration Number = 540
# 	IC Loss = 0.49801701307296753
# 	BC Loss = 3.555293560028076
# 	Physics Loss = 4948.11279296875
# 	Training Loss = 4952.166015625
# 	Relative L2 error (test) = 100.08525848388672
# Iteration Number = 550
# 	IC Loss = 0.49853575229644775
# 	BC Loss = 3.5539984703063965
# 	Physics Loss = 5172.283203125
# 	Training Loss = 5176.3359375
# 	Relative L2 error (test) = 100.09524822235107
# Iteration Number = 560
# 	IC Loss = 0.4986007809638977
# 	BC Loss = 3.5572729110717773
# 	Physics Loss = 4610.1982421875
# 	Training Loss = 4614.25390625
# 	Relative L2 error (test) = 100.15240907669067
# Iteration Number = 570
# 	IC Loss = 0.4980216324329376
# 	BC Loss = 3.555123805999756
# 	Physics Loss = 4715.28564453125
# 	Training Loss = 4719.3388671875
# 	Relative L2 error (test) = 100.14915466308594
# Iteration Number = 580
# 	IC Loss = 0.4974392354488373
# 	BC Loss = 3.556326389312744
# 	Physics Loss = 4755.76025390625
# 	Training Loss = 4759.81396484375
# 	Relative L2 error (test) = 100.31359195709229
# Iteration Number = 590
# 	IC Loss = 0.4972919225692749
# 	BC Loss = 3.5806126594543457
# 	Physics Loss = 4666.51806640625
# 	Training Loss = 4670.59619140625
# 	Relative L2 error (test) = 101.77510976791382
# Iteration Number = 600
# 	IC Loss = 0.506197452545166
# 	BC Loss = 3.624117851257324
# 	Physics Loss = 4816.51904296875
# 	Training Loss = 4820.6494140625
# 	Relative L2 error (test) = 102.32623815536499
# Iteration Number = 610
# 	IC Loss = 0.5017338395118713
# 	BC Loss = 3.582059860229492
# 	Physics Loss = 5052.609375
# 	Training Loss = 5056.693359375
# 	Relative L2 error (test) = 101.87952518463135
# Iteration Number = 620
# 	IC Loss = 0.4977421164512634
# 	BC Loss = 3.5566277503967285
# 	Physics Loss = 4559.5400390625
# 	Training Loss = 4563.59423828125
# 	Relative L2 error (test) = 101.12597942352295
# Iteration Number = 630
# 	IC Loss = 0.4985654652118683
# 	BC Loss = 3.578629970550537
# 	Physics Loss = 4792.13525390625
# 	Training Loss = 4796.21240234375
# 	Relative L2 error (test) = 102.14394330978394
# Iteration Number = 640
# 	IC Loss = 0.4968661963939667
# 	BC Loss = 3.5510828495025635
# 	Physics Loss = 4641.14208984375
# 	Training Loss = 4645.18994140625
# 	Relative L2 error (test) = 100.36102533340454
# Iteration Number = 650
# 	IC Loss = 0.49720725417137146
# 	BC Loss = 3.546907424926758
# 	Physics Loss = 4600.04931640625
# 	Training Loss = 4604.09326171875
# 	Relative L2 error (test) = 100.31405687332153
# Iteration Number = 660
# 	IC Loss = 0.4981568157672882
# 	BC Loss = 3.5493416786193848
# 	Physics Loss = 4892.93017578125
# 	Training Loss = 4896.9775390625
# 	Relative L2 error (test) = 100.0247597694397
# Iteration Number = 670
# 	IC Loss = 0.4972732663154602
# 	BC Loss = 3.5459647178649902
# 	Physics Loss = 4940.26611328125
# 	Training Loss = 4944.3095703125
# 	Relative L2 error (test) = 100.01192092895508
# Iteration Number = 680
# 	IC Loss = 0.49677762389183044
# 	BC Loss = 3.5443782806396484
# 	Physics Loss = 4710.373046875
# 	Training Loss = 4714.4140625
# 	Relative L2 error (test) = 100.10738372802734
# Iteration Number = 690
# 	IC Loss = 0.49245867133140564
# 	BC Loss = 3.526946544647217
# 	Physics Loss = 4792.87158203125
# 	Training Loss = 4796.89111328125
# 	Relative L2 error (test) = 100.10737180709839
# Iteration Number = 700
# 	IC Loss = 0.48581358790397644
# 	BC Loss = 3.487575054168701
# 	Physics Loss = 5002.412109375
# 	Training Loss = 5006.3857421875
# 	Relative L2 error (test) = 100.34658908843994
# Iteration Number = 710
# 	IC Loss = 0.48563364148139954
# 	BC Loss = 3.5073742866516113
# 	Physics Loss = 4794.83203125
# 	Training Loss = 4798.8251953125
# 	Relative L2 error (test) = 100.1349925994873
# Iteration Number = 720
# 	IC Loss = 0.4942791759967804
# 	BC Loss = 3.545114040374756
# 	Physics Loss = 4814.86376953125
# 	Training Loss = 4818.9033203125
# 	Relative L2 error (test) = 100.11671781539917
# Iteration Number = 730
# 	IC Loss = 0.4919452369213104
# 	BC Loss = 3.5357613563537598
# 	Physics Loss = 4613.95068359375
# 	Training Loss = 4617.978515625
# 	Relative L2 error (test) = 100.40522813796997
# Iteration Number = 740
# 	IC Loss = 0.4835802912712097
# 	BC Loss = 3.5263242721557617
# 	Physics Loss = 4884.345703125
# 	Training Loss = 4888.35546875
# 	Relative L2 error (test) = 100.44724941253662
# Iteration Number = 750
# 	IC Loss = 0.47450438141822815
# 	BC Loss = 3.5385851860046387
# 	Physics Loss = 4659.18359375
# 	Training Loss = 4663.19677734375
# 	Relative L2 error (test) = 101.5052318572998
# Iteration Number = 760
# 	IC Loss = 0.5104000568389893
# 	BC Loss = 3.763498306274414
# 	Physics Loss = 4815.15478515625
# 	Training Loss = 4819.4287109375
# 	Relative L2 error (test) = 101.39175653457642
# Iteration Number = 770
# 	IC Loss = 0.5012950897216797
# 	BC Loss = 3.5524463653564453
# 	Physics Loss = 4676.7275390625
# 	Training Loss = 4680.78125
# 	Relative L2 error (test) = 110.80018281936646
# Iteration Number = 780
# 	IC Loss = 0.5193849205970764
# 	BC Loss = 3.793189525604248
# 	Physics Loss = 4766.30908203125
# 	Training Loss = 4770.62158203125
# 	Relative L2 error (test) = 100.35245418548584
# Iteration Number = 790
# 	IC Loss = 0.49919071793556213
# 	BC Loss = 3.5703177452087402
# 	Physics Loss = 4758.06689453125
# 	Training Loss = 4762.13623046875
# 	Relative L2 error (test) = 101.31632089614868
# Iteration Number = 800
# 	IC Loss = 0.4971020519733429
# 	BC Loss = 3.561323642730713
# 	Physics Loss = 4502.87060546875
# 	Training Loss = 4506.92919921875
# 	Relative L2 error (test) = 100.25498867034912
# Iteration Number = 810
# 	IC Loss = 0.5005863308906555
# 	BC Loss = 3.5653469562530518
# 	Physics Loss = 4561.89697265625
# 	Training Loss = 4565.962890625
# 	Relative L2 error (test) = 100.03217458724976
# Iteration Number = 820
# 	IC Loss = 0.5005649924278259
# 	BC Loss = 3.5580883026123047
# 	Physics Loss = 4872.36181640625
# 	Training Loss = 4876.42041015625
# 	Relative L2 error (test) = 100.04233121871948
# Iteration Number = 830
# 	IC Loss = 0.5002559423446655
# 	BC Loss = 3.556725025177002
# 	Physics Loss = 4622.92138671875
# 	Training Loss = 4626.978515625
# 	Relative L2 error (test) = 100.00367164611816
# Iteration Number = 840
# 	IC Loss = 0.4991633892059326
# 	BC Loss = 3.5523033142089844
# 	Physics Loss = 4470.51904296875
# 	Training Loss = 4474.5703125
# 	Relative L2 error (test) = 100.01349449157715
# Iteration Number = 850
# 	IC Loss = 0.4992069900035858
# 	BC Loss = 3.5506696701049805
# 	Physics Loss = 5175.32080078125
# 	Training Loss = 5179.37060546875
# 	Relative L2 error (test) = 100.01140832901001
# Iteration Number = 860
# 	IC Loss = 0.49868711829185486
# 	BC Loss = 3.548552989959717
# 	Physics Loss = 4933.98779296875
# 	Training Loss = 4938.03515625
# 	Relative L2 error (test) = 100.00694990158081
# Iteration Number = 870
# 	IC Loss = 0.49873822927474976
# 	BC Loss = 3.5481948852539062
# 	Physics Loss = 4721.03759765625
# 	Training Loss = 4725.08447265625
# 	Relative L2 error (test) = 100.00966787338257
# Iteration Number = 880
# 	IC Loss = 0.501621425151825
# 	BC Loss = 3.5594944953918457
# 	Physics Loss = 4535.36328125
# 	Training Loss = 4539.42431640625
# 	Relative L2 error (test) = 100.0227689743042
# Iteration Number = 890
# 	IC Loss = 0.4999588131904602
# 	BC Loss = 3.5546579360961914
# 	Physics Loss = 4951.55029296875
# 	Training Loss = 4955.60498046875
# 	Relative L2 error (test) = 100.00314712524414
# Iteration Number = 900
# 	IC Loss = 0.49907824397087097
# 	BC Loss = 3.5517868995666504
# 	Physics Loss = 4785.71728515625
# 	Training Loss = 4789.76806640625
# 	Relative L2 error (test) = 100.00839233398438
# Iteration Number = 910
# 	IC Loss = 0.49826109409332275
# 	BC Loss = 3.549302101135254
# 	Physics Loss = 4972.96728515625
# 	Training Loss = 4977.0146484375
# 	Relative L2 error (test) = 100.01188516616821
# Iteration Number = 920
# 	IC Loss = 0.49476128816604614
# 	BC Loss = 3.54232120513916
# 	Physics Loss = 4864.25341796875
# 	Training Loss = 4868.29052734375
# 	Relative L2 error (test) = 100.10702610015869
# Iteration Number = 930
# 	IC Loss = 0.4901040196418762
# 	BC Loss = 3.537911891937256
# 	Physics Loss = 4904.85400390625
# 	Training Loss = 4908.8818359375
# 	Relative L2 error (test) = 100.09304285049438
# Iteration Number = 940
# 	IC Loss = 0.49190258979797363
# 	BC Loss = 3.552729606628418
# 	Physics Loss = 4406.40869140625
# 	Training Loss = 4410.453125
# 	Relative L2 error (test) = 100.2117395401001
# Iteration Number = 950
# 	IC Loss = 0.4979354441165924
# 	BC Loss = 3.5490288734436035
# 	Physics Loss = 4882.916015625
# 	Training Loss = 4886.962890625
# 	Relative L2 error (test) = 100.07439851760864
# Iteration Number = 960
# 	IC Loss = 0.49921199679374695
# 	BC Loss = 3.551685333251953
# 	Physics Loss = 4759.3330078125
# 	Training Loss = 4763.3837890625
# 	Relative L2 error (test) = 100.00312328338623
# Iteration Number = 970
# 	IC Loss = 0.49929940700531006
# 	BC Loss = 3.5515999794006348
# 	Physics Loss = 4591.60302734375
# 	Training Loss = 4595.65380859375
# 	Relative L2 error (test) = 100.00823736190796
# Iteration Number = 980
# 	IC Loss = 0.4994201362133026
# 	BC Loss = 3.5526273250579834
# 	Physics Loss = 4793.75146484375
# 	Training Loss = 4797.8037109375
# 	Relative L2 error (test) = 100.00133514404297
# Iteration Number = 990
# 	IC Loss = 0.49935171008110046
# 	BC Loss = 3.552187442779541
# 	Physics Loss = 4509.42138671875
# 	Training Loss = 4513.47314453125
# 	Relative L2 error (test) = 100.00169277191162
# Iteration Number = 1000
# 	IC Loss = 0.49924272298812866
# 	BC Loss = 3.551985740661621
# 	Physics Loss = 4934.92822265625
# 	Training Loss = 4938.9794921875
# 	Relative L2 error (test) = 100.00609159469604
# Iteration Number = 1010
# 	IC Loss = 0.4991946518421173
# 	BC Loss = 3.551539421081543
# 	Physics Loss = 5086.85302734375
# 	Training Loss = 5090.90380859375
# 	Relative L2 error (test) = 100.00544786453247
# Iteration Number = 1020
# 	IC Loss = 0.4990968704223633
# 	BC Loss = 3.5511600971221924
# 	Physics Loss = 4739.95703125
# 	Training Loss = 4744.00732421875
# 	Relative L2 error (test) = 100.00361204147339
# Iteration Number = 1030
# 	IC Loss = 0.49904704093933105
# 	BC Loss = 3.550942897796631
# 	Physics Loss = 4841.81201171875
# 	Training Loss = 4845.86181640625
# 	Relative L2 error (test) = 100.00340938568115
# Iteration Number = 1040
# 	IC Loss = 0.49875661730766296
# 	BC Loss = 3.550062656402588
# 	Physics Loss = 4877.97607421875
# 	Training Loss = 4882.02490234375
# 	Relative L2 error (test) = 100.00573396682739
# Iteration Number = 1050
# 	IC Loss = 0.498870313167572
# 	BC Loss = 3.5503029823303223
# 	Physics Loss = 4836.32421875
# 	Training Loss = 4840.37353515625
# 	Relative L2 error (test) = 100.0059723854065
# Iteration Number = 1060
# 	IC Loss = 0.4989737868309021
# 	BC Loss = 3.5506744384765625
# 	Physics Loss = 4874.71630859375
# 	Training Loss = 4878.76611328125
# 	Relative L2 error (test) = 100.00773668289185
# Iteration Number = 1070
# 	IC Loss = 0.49897804856300354
# 	BC Loss = 3.5504350662231445
# 	Physics Loss = 4781.92236328125
# 	Training Loss = 4785.9716796875
# 	Relative L2 error (test) = 100.00525712966919
# Iteration Number = 1080
# 	IC Loss = 0.49899613857269287
# 	BC Loss = 3.5504865646362305
# 	Physics Loss = 5161.29248046875
# 	Training Loss = 5165.341796875
# 	Relative L2 error (test) = 100.00532865524292
# Iteration Number = 1090
# 	IC Loss = 0.4987543523311615
# 	BC Loss = 3.5496654510498047
# 	Physics Loss = 4688.123046875
# 	Training Loss = 4692.17138671875
# 	Relative L2 error (test) = 100.00903606414795
# Iteration Number = 1100
# 	IC Loss = 0.49796628952026367
# 	BC Loss = 3.5470335483551025
# 	Physics Loss = 4955.19873046875
# 	Training Loss = 4959.24365234375
# 	Relative L2 error (test) = 100.0173568725586
# Iteration Number = 1110
# 	IC Loss = 0.49652212858200073
# 	BC Loss = 3.542135238647461
# 	Physics Loss = 4602.27099609375
# 	Training Loss = 4606.3095703125
# 	Relative L2 error (test) = 100.03162622451782
# Iteration Number = 1120
# 	IC Loss = 0.4965583086013794
# 	BC Loss = 3.5415029525756836
# 	Physics Loss = 4639.64990234375
# 	Training Loss = 4643.68798828125
# 	Relative L2 error (test) = 100.02332925796509
# Iteration Number = 1130
# 	IC Loss = 0.49548575282096863
# 	BC Loss = 3.538433074951172
# 	Physics Loss = 4690.068359375
# 	Training Loss = 4694.10205078125
# 	Relative L2 error (test) = 100.03541707992554
# Iteration Number = 1140
# 	IC Loss = 0.49308520555496216
# 	BC Loss = 3.5302484035491943
# 	Physics Loss = 4922.9013671875
# 	Training Loss = 4926.9248046875
# 	Relative L2 error (test) = 100.05338191986084
# Iteration Number = 1150
# 	IC Loss = 0.4972701072692871
# 	BC Loss = 3.5449187755584717
# 	Physics Loss = 4641.3408203125
# 	Training Loss = 4645.3828125
# 	Relative L2 error (test) = 100.0058650970459
# Iteration Number = 1160
# 	IC Loss = 0.49822938442230225
# 	BC Loss = 3.5481038093566895
# 	Physics Loss = 4871.2763671875
# 	Training Loss = 4875.32275390625
# 	Relative L2 error (test) = 100.00410079956055
# Iteration Number = 1170
# 	IC Loss = 0.498149573802948
# 	BC Loss = 3.5478482246398926
# 	Physics Loss = 4435.607421875
# 	Training Loss = 4439.6533203125
# 	Relative L2 error (test) = 100.00478029251099
# Iteration Number = 1180
# 	IC Loss = 0.4974823296070099
# 	BC Loss = 3.5457773208618164
# 	Physics Loss = 4850.35302734375
# 	Training Loss = 4854.396484375
# 	Relative L2 error (test) = 100.01022815704346
# Iteration Number = 1190
# 	IC Loss = 0.4957239031791687
# 	BC Loss = 3.5396862030029297
# 	Physics Loss = 4733.83544921875
# 	Training Loss = 4737.87109375
# 	Relative L2 error (test) = 100.02356767654419
# Iteration Number = 1200
# 	IC Loss = 0.4898589551448822
# 	BC Loss = 3.521082878112793
# 	Physics Loss = 4661.0185546875
# 	Training Loss = 4665.029296875
# 	Relative L2 error (test) = 100.10796785354614
# Iteration Number = 1210
# 	IC Loss = 0.44360944628715515
# 	BC Loss = 3.310307025909424
# 	Physics Loss = 4688.5703125
# 	Training Loss = 4692.32421875
# 	Relative L2 error (test) = 101.68100595474243
# Iteration Number = 1220
# 	IC Loss = 0.5029534697532654
# 	BC Loss = 3.590071201324463
# 	Physics Loss = 4781.57421875
# 	Training Loss = 4785.66748046875
# 	Relative L2 error (test) = 100.39125680923462
# Iteration Number = 1230
# 	IC Loss = 0.49632638692855835
# 	BC Loss = 3.5407800674438477
# 	Physics Loss = 4757.01611328125
# 	Training Loss = 4761.05322265625
# 	Relative L2 error (test) = 100.41754245758057
# Iteration Number = 1240
# 	IC Loss = 0.4959942698478699
# 	BC Loss = 3.544919013977051
# 	Physics Loss = 4885.9326171875
# 	Training Loss = 4889.9736328125
# 	Relative L2 error (test) = 100.1895546913147
# Iteration Number = 1250
# 	IC Loss = 0.5106059312820435
# 	BC Loss = 3.6137943267822266
# 	Physics Loss = 4712.00439453125
# 	Training Loss = 4716.12890625
# 	Relative L2 error (test) = 100.55358409881592
# Iteration Number = 1260
# 	IC Loss = 0.5564535856246948
# 	BC Loss = 4.267979621887207
# 	Physics Loss = 4724.2919921875
# 	Training Loss = 4729.1162109375
# 	Relative L2 error (test) = 111.86244487762451
# Iteration Number = 1270
# 	IC Loss = 0.5022852420806885
# 	BC Loss = 3.5666050910949707
# 	Physics Loss = 4601.744140625
# 	Training Loss = 4605.81298828125
# 	Relative L2 error (test) = 100.79008340835571
# Iteration Number = 1280
# 	IC Loss = 0.5030652284622192
# 	BC Loss = 3.571289539337158
# 	Physics Loss = 4685.07568359375
# 	Training Loss = 4689.14990234375
# 	Relative L2 error (test) = 100.42015314102173
# Iteration Number = 1290
# 	IC Loss = 0.49976786971092224
# 	BC Loss = 3.5646281242370605
# 	Physics Loss = 4828.13037109375
# 	Training Loss = 4832.19482421875
# 	Relative L2 error (test) = 100.01659393310547
# Iteration Number = 1300
# 	IC Loss = 0.5001857280731201
# 	BC Loss = 3.553950786590576
# 	Physics Loss = 4906.91455078125
# 	Training Loss = 4910.96875
# 	Relative L2 error (test) = 100.03972053527832
# Iteration Number = 1310
# 	IC Loss = 0.5001704692840576
# 	BC Loss = 3.553799629211426
# 	Physics Loss = 4702.55859375
# 	Training Loss = 4706.61279296875
# 	Relative L2 error (test) = 100.01739263534546
# Iteration Number = 1320
# 	IC Loss = 0.4996064007282257
# 	BC Loss = 3.5540771484375
# 	Physics Loss = 4769.3740234375
# 	Training Loss = 4773.427734375
# 	Relative L2 error (test) = 100.00773668289185
# Iteration Number = 1330
# 	IC Loss = 0.4998461902141571
# 	BC Loss = 3.5535693168640137
# 	Physics Loss = 4954.39404296875
# 	Training Loss = 4958.447265625
# 	Relative L2 error (test) = 100.0048279762268
# Iteration Number = 1340
# 	IC Loss = 0.49980083107948303
# 	BC Loss = 3.553658962249756
# 	Physics Loss = 4435.63134765625
# 	Training Loss = 4439.6845703125
# 	Relative L2 error (test) = 100.00262260437012
# Iteration Number = 1350
# 	IC Loss = 0.49971097707748413
# 	BC Loss = 3.5536861419677734
# 	Physics Loss = 5044.25390625
# 	Training Loss = 5048.30712890625
# 	Relative L2 error (test) = 100.00399351119995
# Iteration Number = 1360
# 	IC Loss = 0.49993637204170227
# 	BC Loss = 3.553483486175537
# 	Physics Loss = 4524.89599609375
# 	Training Loss = 4528.94921875
# 	Relative L2 error (test) = 100.00293254852295
# Iteration Number = 1370
# 	IC Loss = 0.4998733699321747
# 	BC Loss = 3.553567886352539
# 	Physics Loss = 4718.55419921875
# 	Training Loss = 4722.607421875
# 	Relative L2 error (test) = 100.00052452087402
# Iteration Number = 1380
# 	IC Loss = 0.4997442066669464
# 	BC Loss = 3.5537610054016113
# 	Physics Loss = 4755.88232421875
# 	Training Loss = 4759.93603515625
# 	Relative L2 error (test) = 100.00414848327637
# Iteration Number = 1390
# 	IC Loss = 0.49980947375297546
# 	BC Loss = 3.5532851219177246
# 	Physics Loss = 4687.5673828125
# 	Training Loss = 4691.62060546875
# 	Relative L2 error (test) = 100.0031590461731
# Iteration Number = 1400
# 	IC Loss = 0.4995221495628357
# 	BC Loss = 3.5534377098083496
# 	Physics Loss = 5123.14892578125
# 	Training Loss = 5127.20166015625
# 	Relative L2 error (test) = 100.00522136688232
# Iteration Number = 1410
# 	IC Loss = 0.49907246232032776
# 	BC Loss = 3.5532889366149902
# 	Physics Loss = 5053.32421875
# 	Training Loss = 5057.37646484375
# 	Relative L2 error (test) = 100.01286268234253
# Iteration Number = 1420
# 	IC Loss = 0.49891313910484314
# 	BC Loss = 3.550719738006592
# 	Physics Loss = 4978.63134765625
# 	Training Loss = 4982.68115234375
# 	Relative L2 error (test) = 100.01604557037354
# Iteration Number = 1430
# 	IC Loss = 0.4997468590736389
# 	BC Loss = 3.5525121688842773
# 	Physics Loss = 4581.2490234375
# 	Training Loss = 4585.30126953125
# 	Relative L2 error (test) = 100.00483989715576
# Iteration Number = 1440
# 	IC Loss = 0.5000469088554382
# 	BC Loss = 3.553865432739258
# 	Physics Loss = 4692.90185546875
# 	Training Loss = 4696.95556640625
# 	Relative L2 error (test) = 100.00268220901489
# Iteration Number = 1450
# 	IC Loss = 0.5001963973045349
# 	BC Loss = 3.5551390647888184
# 	Physics Loss = 4812.18017578125
# 	Training Loss = 4816.2353515625
# 	Relative L2 error (test) = 100.002920627594
# Iteration Number = 1460
# 	IC Loss = 0.4998137652873993
# 	BC Loss = 3.5516295433044434
# 	Physics Loss = 4983.36279296875
# 	Training Loss = 4987.4140625
# 	Relative L2 error (test) = 100.00250339508057
# Iteration Number = 1470
# 	IC Loss = 0.4992850720882416
# 	BC Loss = 3.549424648284912
# 	Physics Loss = 4806.1630859375
# 	Training Loss = 4810.2119140625
# 	Relative L2 error (test) = 100.01286268234253
# Iteration Number = 1480
# 	IC Loss = 0.49925753474235535
# 	BC Loss = 3.5499367713928223
# 	Physics Loss = 4641.3623046875
# 	Training Loss = 4645.41162109375
# 	Relative L2 error (test) = 100.00889301300049
# Iteration Number = 1490
# 	IC Loss = 0.49944859743118286
# 	BC Loss = 3.5500717163085938
# 	Physics Loss = 5152.73095703125
# 	Training Loss = 5156.7802734375
# 	Relative L2 error (test) = 100.00962018966675
# Iteration Number = 1500
# 	IC Loss = 0.4993703365325928
# 	BC Loss = 3.5494463443756104
# 	Physics Loss = 4741.791015625
# 	Training Loss = 4745.83984375
# 	Relative L2 error (test) = 100.00566244125366
# Iteration Number = 1510
# 	IC Loss = 0.4994374215602875
# 	BC Loss = 3.5490899085998535
# 	Physics Loss = 4838.2744140625
# 	Training Loss = 4842.32275390625
# 	Relative L2 error (test) = 100.00605583190918
# Iteration Number = 1520
# 	IC Loss = 0.49951717257499695
# 	BC Loss = 3.547616958618164
# 	Physics Loss = 4854.0810546875
# 	Training Loss = 4858.12841796875
# 	Relative L2 error (test) = 100.04408359527588
# Iteration Number = 1530
# 	IC Loss = 0.4992995262145996
# 	BC Loss = 3.5479302406311035
# 	Physics Loss = 4819.3359375
# 	Training Loss = 4823.38330078125
# 	Relative L2 error (test) = 100.01873970031738
# Iteration Number = 1540
# 	IC Loss = 0.4989696145057678
# 	BC Loss = 3.5456418991088867
# 	Physics Loss = 4670.96240234375
# 	Training Loss = 4675.0068359375
# 	Relative L2 error (test) = 100.03702640533447
# Iteration Number = 1550
# 	IC Loss = 0.4995254576206207
# 	BC Loss = 3.5486395359039307
# 	Physics Loss = 4862.447265625
# 	Training Loss = 4866.49560546875
# 	Relative L2 error (test) = 100.0086784362793
# Iteration Number = 1560
# 	IC Loss = 0.5001790523529053
# 	BC Loss = 3.553649425506592
# 	Physics Loss = 4732.87353515625
# 	Training Loss = 4736.92724609375
# 	Relative L2 error (test) = 100.0051736831665
# Iteration Number = 1570
# 	IC Loss = 0.5001979470252991
# 	BC Loss = 3.5553536415100098
# 	Physics Loss = 4821.07177734375
# 	Training Loss = 4825.12744140625
# 	Relative L2 error (test) = 100.0022292137146
# Iteration Number = 1580
# 	IC Loss = 0.5002731084823608
# 	BC Loss = 3.5563559532165527
# 	Physics Loss = 4665.09521484375
# 	Training Loss = 4669.15185546875
# 	Relative L2 error (test) = 100.00295639038086
# Iteration Number = 1590
# 	IC Loss = 0.5003122687339783
# 	BC Loss = 3.556373119354248
# 	Physics Loss = 4852.873046875
# 	Training Loss = 4856.9296875
# 	Relative L2 error (test) = 100.00176429748535
# Iteration Number = 1600
# 	IC Loss = 0.5003072619438171
# 	BC Loss = 3.5565404891967773
# 	Physics Loss = 4673.1875
# 	Training Loss = 4677.244140625
# 	Relative L2 error (test) = 100.0017523765564
# Iteration Number = 1610
# 	IC Loss = 0.5001851320266724
# 	BC Loss = 3.555579423904419
# 	Physics Loss = 4774.5791015625
# 	Training Loss = 4778.634765625
# 	Relative L2 error (test) = 100.00150203704834
# Iteration Number = 1620
# 	IC Loss = 0.5000991225242615
# 	BC Loss = 3.5546836853027344
# 	Physics Loss = 4904.818359375
# 	Training Loss = 4908.873046875
# 	Relative L2 error (test) = 100.00159740447998
# Iteration Number = 1630
# 	IC Loss = 0.5001060962677002
# 	BC Loss = 3.55462646484375
# 	Physics Loss = 4757.4892578125
# 	Training Loss = 4761.5439453125
# 	Relative L2 error (test) = 100.0004768371582
# Iteration Number = 1640
# 	IC Loss = 0.5000765919685364
# 	BC Loss = 3.5545668601989746
# 	Physics Loss = 4749.87109375
# 	Training Loss = 4753.92578125
# 	Relative L2 error (test) = 100.00022649765015
# Iteration Number = 1650
# 	IC Loss = 0.500034511089325
# 	BC Loss = 3.554440498352051
# 	Physics Loss = 4603.8203125
# 	Training Loss = 4607.875
# 	Relative L2 error (test) = 100.00025033950806
# Iteration Number = 1660
# 	IC Loss = 0.4999907910823822
# 	BC Loss = 3.5543055534362793
# 	Physics Loss = 4955.3564453125
# 	Training Loss = 4959.41064453125
# 	Relative L2 error (test) = 100.00030994415283
# Iteration Number = 1670
# 	IC Loss = 0.49997127056121826
# 	BC Loss = 3.5542540550231934
# 	Physics Loss = 4759.91845703125
# 	Training Loss = 4763.97265625
# 	Relative L2 error (test) = 100.00061988830566
# Iteration Number = 1680
# 	IC Loss = 0.49998170137405396
# 	BC Loss = 3.5542001724243164
# 	Physics Loss = 4981.22705078125
# 	Training Loss = 4985.28125
# 	Relative L2 error (test) = 100.00096559524536
# Iteration Number = 1690
# 	IC Loss = 0.4999854266643524
# 	BC Loss = 3.554098606109619
# 	Physics Loss = 4852.19970703125
# 	Training Loss = 4856.25390625
# 	Relative L2 error (test) = 100.00102519989014
# Iteration Number = 1700
# 	IC Loss = 0.499973863363266
# 	BC Loss = 3.553950786590576
# 	Physics Loss = 4787.7587890625
# 	Training Loss = 4791.8125
# 	Relative L2 error (test) = 100.0008225440979
# Iteration Number = 1710
# 	IC Loss = 0.499971479177475
# 	BC Loss = 3.5538277626037598
# 	Physics Loss = 4750.3212890625
# 	Training Loss = 4754.375
# 	Relative L2 error (test) = 100.00028610229492
# Iteration Number = 1720
# 	IC Loss = 0.4999425709247589
# 	BC Loss = 3.553722858428955
# 	Physics Loss = 4491.607421875
# 	Training Loss = 4495.6611328125
# 	Relative L2 error (test) = 100.00022649765015
# Iteration Number = 1730
# 	IC Loss = 0.49992311000823975
# 	BC Loss = 3.5537142753601074
# 	Physics Loss = 4997.46630859375
# 	Training Loss = 5001.52001953125
# 	Relative L2 error (test) = 100.00041723251343
# Iteration Number = 1740
# 	IC Loss = 0.49991747736930847
# 	BC Loss = 3.5537333488464355
# 	Physics Loss = 4977.42236328125
# 	Training Loss = 4981.47607421875
# 	Relative L2 error (test) = 100.00048875808716
# Iteration Number = 1750
# 	IC Loss = 0.49991971254348755
# 	BC Loss = 3.553764820098877
# 	Physics Loss = 4875.8369140625
# 	Training Loss = 4879.890625
# 	Relative L2 error (test) = 100.00067949295044
# Iteration Number = 1760
# 	IC Loss = 0.4999338686466217
# 	BC Loss = 3.5538179874420166
# 	Physics Loss = 4846.45947265625
# 	Training Loss = 4850.51318359375
# 	Relative L2 error (test) = 100.00065565109253
# Iteration Number = 1770
# 	IC Loss = 0.4999365210533142
# 	BC Loss = 3.553859233856201
# 	Physics Loss = 5081.88818359375
# 	Training Loss = 5085.94189453125
# 	Relative L2 error (test) = 100.00056028366089
# Iteration Number = 1780
# 	IC Loss = 0.4999525547027588
# 	BC Loss = 3.5538763999938965
# 	Physics Loss = 4944.625
# 	Training Loss = 4948.6787109375
# 	Relative L2 error (test) = 100.00064373016357
# Iteration Number = 1790
# 	IC Loss = 0.49992817640304565
# 	BC Loss = 3.5538086891174316
# 	Physics Loss = 4769.05419921875
# 	Training Loss = 4773.10791015625
# 	Relative L2 error (test) = 100.00075101852417
# Iteration Number = 1800
# 	IC Loss = 0.4999285042285919
# 	BC Loss = 3.5537819862365723
# 	Physics Loss = 4760.8125
# 	Training Loss = 4764.8662109375
# 	Relative L2 error (test) = 100.00110864639282
# Iteration Number = 1810
# 	IC Loss = 0.4999319314956665
# 	BC Loss = 3.5537772178649902
# 	Physics Loss = 4805.115234375
# 	Training Loss = 4809.1689453125
# 	Relative L2 error (test) = 100.00077486038208
# Iteration Number = 1820
# 	IC Loss = 0.49995365738868713
# 	BC Loss = 3.5538439750671387
# 	Physics Loss = 4831.03369140625
# 	Training Loss = 4835.08740234375
# 	Relative L2 error (test) = 100.00065565109253
# Iteration Number = 1830
# 	IC Loss = 0.49995294213294983
# 	BC Loss = 3.553846836090088
# 	Physics Loss = 4839.826171875
# 	Training Loss = 4843.8798828125
# 	Relative L2 error (test) = 100.00064373016357
# Iteration Number = 1840
# 	IC Loss = 0.49993419647216797
# 	BC Loss = 3.553834915161133
# 	Physics Loss = 4918.50927734375
# 	Training Loss = 4922.56298828125
# 	Relative L2 error (test) = 100.00044107437134
# Iteration Number = 1850
# 	IC Loss = 0.4999314248561859
# 	BC Loss = 3.55380916595459
# 	Physics Loss = 5154.5947265625
# 	Training Loss = 5158.6484375
# 	Relative L2 error (test) = 100.00053644180298
# Iteration Number = 1860
# 	IC Loss = 0.4999270439147949
# 	BC Loss = 3.5537919998168945
# 	Physics Loss = 4865.42626953125
# 	Training Loss = 4869.47998046875
# 	Relative L2 error (test) = 100.00040531158447
# Iteration Number = 1870
# 	IC Loss = 0.49989259243011475
# 	BC Loss = 3.553663730621338
# 	Physics Loss = 4759.3359375
# 	Training Loss = 4763.3896484375
# 	Relative L2 error (test) = 100.00066757202148
# Iteration Number = 1880
# 	IC Loss = 0.49989378452301025
# 	BC Loss = 3.553622245788574
# 	Physics Loss = 4746.4140625
# 	Training Loss = 4750.4677734375
# 	Relative L2 error (test) = 100.00088214874268
# Iteration Number = 1890
# 	IC Loss = 0.49993225932121277
# 	BC Loss = 3.553762435913086
# 	Physics Loss = 4613.2373046875
# 	Training Loss = 4617.291015625
# 	Relative L2 error (test) = 100.00079870223999
# Iteration Number = 1900
# 	IC Loss = 0.49994751811027527
# 	BC Loss = 3.553898334503174
# 	Physics Loss = 4734.1162109375
# 	Training Loss = 4738.169921875
# 	Relative L2 error (test) = 100.0006914138794
# Iteration Number = 1910
# 	IC Loss = 0.4999494254589081
# 	BC Loss = 3.5539612770080566
# 	Physics Loss = 4695.26708984375
# 	Training Loss = 4699.32080078125
# 	Relative L2 error (test) = 100.0005841255188
# Iteration Number = 1920
# 	IC Loss = 0.49993762373924255
# 	BC Loss = 3.5539231300354004
# 	Physics Loss = 4935.9599609375
# 	Training Loss = 4940.013671875
# 	Relative L2 error (test) = 100.00076293945312
# Iteration Number = 1930
# 	IC Loss = 0.49993857741355896
# 	BC Loss = 3.5538535118103027
# 	Physics Loss = 5027.89892578125
# 	Training Loss = 5031.95263671875
# 	Relative L2 error (test) = 100.00060796737671
# Iteration Number = 1940
# 	IC Loss = 0.4999411106109619
# 	BC Loss = 3.5538597106933594
# 	Physics Loss = 4661.22021484375
# 	Training Loss = 4665.27392578125
# 	Relative L2 error (test) = 100.00053644180298
# Iteration Number = 1950
# 	IC Loss = 0.4999188780784607
# 	BC Loss = 3.553793430328369
# 	Physics Loss = 5039.95849609375
# 	Training Loss = 5044.01220703125
# 	Relative L2 error (test) = 100.00067949295044
# Iteration Number = 1960
# 	IC Loss = 0.4999067187309265
# 	BC Loss = 3.5536558628082275
# 	Physics Loss = 4658.67578125
# 	Training Loss = 4662.7294921875
# 	Relative L2 error (test) = 100.00067949295044
# Iteration Number = 1970
# 	IC Loss = 0.49988970160484314
# 	BC Loss = 3.5536046028137207
# 	Physics Loss = 4639.740234375
# 	Training Loss = 4643.7939453125
# 	Relative L2 error (test) = 100.00102519989014
# Iteration Number = 1980
# 	IC Loss = 0.49987754225730896
# 	BC Loss = 3.5534865856170654
# 	Physics Loss = 4701.48193359375
# 	Training Loss = 4705.53515625
# 	Relative L2 error (test) = 100.00057220458984
# Iteration Number = 1990
# 	IC Loss = 0.499875009059906
# 	BC Loss = 3.553433418273926
# 	Physics Loss = 4986.02734375
# 	Training Loss = 4990.08056640625
# 	Relative L2 error (test) = 100.00067949295044
# Iteration Number = 2000
# 	IC Loss = 0.4998466670513153
# 	BC Loss = 3.5533604621887207
# 	Physics Loss = 5053.02734375
# 	Training Loss = 5057.08056640625
# 	Relative L2 error (test) = 100.0009298324585
# Iteration Number = 2010
# 	IC Loss = 0.4998510479927063
# 	BC Loss = 3.55324125289917
# 	Physics Loss = 4700.080078125
# 	Training Loss = 4704.13330078125
# 	Relative L2 error (test) = 100.00119209289551
# Iteration Number = 2020
# 	IC Loss = 0.4998527765274048
# 	BC Loss = 3.553300380706787
# 	Physics Loss = 4588.78515625
# 	Training Loss = 4592.83837890625
# 	Relative L2 error (test) = 100.00123977661133
# Iteration Number = 2030
# 	IC Loss = 0.4998440146446228
# 	BC Loss = 3.553279399871826
# 	Physics Loss = 4780.078125
# 	Training Loss = 4784.13134765625
# 	Relative L2 error (test) = 100.00119209289551
# Iteration Number = 2040
# 	IC Loss = 0.4998287856578827
# 	BC Loss = 3.553330898284912
# 	Physics Loss = 4642.7373046875
# 	Training Loss = 4646.79052734375
# 	Relative L2 error (test) = 100.00107288360596
# Iteration Number = 2050
# 	IC Loss = 0.4998179078102112
# 	BC Loss = 3.5532402992248535
# 	Physics Loss = 4530.0341796875
# 	Training Loss = 4534.08740234375
# 	Relative L2 error (test) = 100.00104904174805
# Iteration Number = 2060
# 	IC Loss = 0.49978554248809814
# 	BC Loss = 3.5530619621276855
# 	Physics Loss = 4676.482421875
# 	Training Loss = 4680.53515625
# 	Relative L2 error (test) = 100.0007152557373
# Iteration Number = 2070
# 	IC Loss = 0.4997662901878357
# 	BC Loss = 3.553011417388916
# 	Physics Loss = 4822.78564453125
# 	Training Loss = 4826.83837890625
# 	Relative L2 error (test) = 100.0017523765564
# Iteration Number = 2080
# 	IC Loss = 0.49978700280189514
# 	BC Loss = 3.5530991554260254
# 	Physics Loss = 4983.94140625
# 	Training Loss = 4987.994140625
# 	Relative L2 error (test) = 100.0015139579773
# Iteration Number = 2090
# 	IC Loss = 0.4997948408126831
# 	BC Loss = 3.5529274940490723
# 	Physics Loss = 4726.2294921875
# 	Training Loss = 4730.2822265625
# 	Relative L2 error (test) = 100.0009536743164
# Iteration Number = 2100
# 	IC Loss = 0.4998159408569336
# 	BC Loss = 3.5529470443725586
# 	Physics Loss = 4642.5361328125
# 	Training Loss = 4646.5888671875
# 	Relative L2 error (test) = 100.00227689743042
# Iteration Number = 2110
# 	IC Loss = 0.4997522234916687
# 	BC Loss = 3.5529332160949707
# 	Physics Loss = 4805.44921875
# 	Training Loss = 4809.501953125
# 	Relative L2 error (test) = 100.00373125076294
# Iteration Number = 2120
# 	IC Loss = 0.49970442056655884
# 	BC Loss = 3.552949905395508
# 	Physics Loss = 4705.46533203125
# 	Training Loss = 4709.51806640625
# 	Relative L2 error (test) = 100.00244379043579
# Iteration Number = 2130
# 	IC Loss = 0.4997204542160034
# 	BC Loss = 3.5528273582458496
# 	Physics Loss = 5051.3271484375
# 	Training Loss = 5055.3798828125
# 	Relative L2 error (test) = 100.0029444694519
# Iteration Number = 2140
# 	IC Loss = 0.49965500831604004
# 	BC Loss = 3.553095817565918
# 	Physics Loss = 4867.501953125
# 	Training Loss = 4871.5546875
# 	Relative L2 error (test) = 100.00336170196533
# Iteration Number = 2150
# 	IC Loss = 0.49972522258758545
# 	BC Loss = 3.5530447959899902
# 	Physics Loss = 4844.60400390625
# 	Training Loss = 4848.65673828125
# 	Relative L2 error (test) = 100.00185966491699
# Iteration Number = 2160
# 	IC Loss = 0.4998120069503784
# 	BC Loss = 3.5531139373779297
# 	Physics Loss = 4826.7255859375
# 	Training Loss = 4830.7783203125
# 	Relative L2 error (test) = 100.00115633010864
# Iteration Number = 2170
# 	IC Loss = 0.4998362362384796
# 	BC Loss = 3.5530874729156494
# 	Physics Loss = 4559.73828125
# 	Training Loss = 4563.791015625
# 	Relative L2 error (test) = 100.00133514404297
# Iteration Number = 2180
# 	IC Loss = 0.4998037815093994
# 	BC Loss = 3.5531821250915527
# 	Physics Loss = 4814.26123046875
# 	Training Loss = 4818.314453125
# 	Relative L2 error (test) = 100.00216960906982
# Iteration Number = 2190
# 	IC Loss = 0.49978500604629517
# 	BC Loss = 3.5531325340270996
# 	Physics Loss = 4618.005859375
# 	Training Loss = 4622.05859375
# 	Relative L2 error (test) = 100.00323057174683
# Iteration Number = 2200
# 	IC Loss = 0.49970996379852295
# 	BC Loss = 3.553032875061035
# 	Physics Loss = 4791.0419921875
# 	Training Loss = 4795.0947265625
# 	Relative L2 error (test) = 100.00149011611938
# Iteration Number = 2210
# 	IC Loss = 0.49976009130477905
# 	BC Loss = 3.552858352661133
# 	Physics Loss = 4785.2490234375
# 	Training Loss = 4789.3017578125
# 	Relative L2 error (test) = 100.00125169754028
# Iteration Number = 2220
# 	IC Loss = 0.49961650371551514
# 	BC Loss = 3.5525121688842773
# 	Physics Loss = 4791.025390625
# 	Training Loss = 4795.07763671875
# 	Relative L2 error (test) = 100.00215768814087
# Iteration Number = 2230
# 	IC Loss = 0.4996751546859741
# 	BC Loss = 3.5524840354919434
# 	Physics Loss = 4994.84423828125
# 	Training Loss = 4998.896484375
# 	Relative L2 error (test) = 100.00150203704834
# Iteration Number = 2240
# 	IC Loss = 0.4996441602706909
# 	BC Loss = 3.5522942543029785
# 	Physics Loss = 5007.435546875
# 	Training Loss = 5011.4873046875
# 	Relative L2 error (test) = 100.0023603439331
# Iteration Number = 2250
# 	IC Loss = 0.49957144260406494
# 	BC Loss = 3.5521769523620605
# 	Physics Loss = 4644.51220703125
# 	Training Loss = 4648.56396484375
# 	Relative L2 error (test) = 100.00451803207397
# Iteration Number = 2260
# 	IC Loss = 0.49935129284858704
# 	BC Loss = 3.551328659057617
# 	Physics Loss = 4896.5517578125
# 	Training Loss = 4900.6025390625
# 	Relative L2 error (test) = 100.00272989273071
# Iteration Number = 2270
# 	IC Loss = 0.49933934211730957
# 	BC Loss = 3.550464630126953
# 	Physics Loss = 4838.6923828125
# 	Training Loss = 4842.7421875
# 	Relative L2 error (test) = 100.00581741333008
# Iteration Number = 2280
# 	IC Loss = 0.4992443919181824
# 	BC Loss = 3.5503392219543457
# 	Physics Loss = 4836.33447265625
# 	Training Loss = 4840.38427734375
# 	Relative L2 error (test) = 100.00569820404053
# Iteration Number = 2290
# 	IC Loss = 0.4993392527103424
# 	BC Loss = 3.549882173538208
# 	Physics Loss = 4697.37841796875
# 	Training Loss = 4701.427734375
# 	Relative L2 error (test) = 100.00686645507812
# Iteration Number = 2300
# 	IC Loss = 0.4992524981498718
# 	BC Loss = 3.5492491722106934
# 	Physics Loss = 4842.27392578125
# 	Training Loss = 4846.322265625
# 	Relative L2 error (test) = 100.00168085098267
# Iteration Number = 2310
# 	IC Loss = 0.4992551803588867
# 	BC Loss = 3.5472989082336426
# 	Physics Loss = 4905.77685546875
# 	Training Loss = 4909.8232421875
# 	Relative L2 error (test) = 100.00416040420532
# Iteration Number = 2320
# 	IC Loss = 0.4988372027873993
# 	BC Loss = 3.5444607734680176
# 	Physics Loss = 4618.83935546875
# 	Training Loss = 4622.8828125
# 	Relative L2 error (test) = 100.00478029251099
# Iteration Number = 2330
# 	IC Loss = 0.49888965487480164
# 	BC Loss = 3.543090343475342
# 	Physics Loss = 4805.103515625
# 	Training Loss = 4809.1455078125
# 	Relative L2 error (test) = 100.00437498092651
# Iteration Number = 2340
# 	IC Loss = 0.49877554178237915
# 	BC Loss = 3.545064926147461
# 	Physics Loss = 4940.33935546875
# 	Training Loss = 4944.38330078125
# 	Relative L2 error (test) = 100.01189708709717
# Iteration Number = 2350
# 	IC Loss = 0.49820569157600403
# 	BC Loss = 3.5390987396240234
# 	Physics Loss = 4870.2607421875
# 	Training Loss = 4874.2978515625
# 	Relative L2 error (test) = 100.01716613769531
# Iteration Number = 2360
# 	IC Loss = 0.49724093079566956
# 	BC Loss = 3.5278096199035645
# 	Physics Loss = 4713.240234375
# 	Training Loss = 4717.26513671875
# 	Relative L2 error (test) = 100.03821849822998
# Iteration Number = 2370
# 	IC Loss = 0.49783262610435486
# 	BC Loss = 3.5269432067871094
# 	Physics Loss = 4646.17236328125
# 	Training Loss = 4650.197265625
# 	Relative L2 error (test) = 100.0124454498291
# Iteration Number = 2380
# 	IC Loss = 0.49559128284454346
# 	BC Loss = 3.494509220123291
# 	Physics Loss = 4785.21630859375
# 	Training Loss = 4789.20654296875
# 	Relative L2 error (test) = 100.05228519439697
# Iteration Number = 2390
# 	IC Loss = 0.4966323971748352
# 	BC Loss = 3.524223804473877
# 	Physics Loss = 4502.8017578125
# 	Training Loss = 4506.82275390625
# ...
# 	BC Loss = 3.5541014671325684
# 	Physics Loss = 4728.7392578125
# 	Training Loss = 4732.79345703125
# 	Relative L2 error (test) = 100.001060962677
# Iteration Number = 3980
# 	IC Loss = 0.4999474585056305
# 	BC Loss = 3.5540995597839355
# 	Physics Loss = 5096.01123046875
# 	Training Loss = 5100.0654296875
# 	Relative L2 error (test) = 100.00084638595581
# Iteration Number = 3990
# 	IC Loss = 0.49994561076164246
# 	BC Loss = 3.5540950298309326
# 	Physics Loss = 4541.486328125
# 	Training Loss = 4545.54052734375
# 	Relative L2 error (test) = 100.00109672546387
# Iteration Number = 4000
# 	IC Loss = 0.4999501407146454
# 	BC Loss = 3.554081678390503
# 	Physics Loss = 4650.43408203125
# 	Training Loss = 4654.48828125
# 	Relative L2 error (test) = 100.00078678131104
# Iteration Number = 4010
# 	IC Loss = 0.49995186924934387
# 	BC Loss = 3.5540733337402344
# 	Physics Loss = 4920.75634765625
# 	Training Loss = 4924.810546875
# 	Relative L2 error (test) = 100.00077486038208
# Iteration Number = 4020
# 	IC Loss = 0.49993687868118286
# 	BC Loss = 3.5540807247161865
# 	Physics Loss = 4573.30029296875
# 	Training Loss = 4577.3544921875
# 	Relative L2 error (test) = 100.00096559524536
# Iteration Number = 4030
# 	IC Loss = 0.49991685152053833
# 	BC Loss = 3.5540919303894043
# 	Physics Loss = 4952.2900390625
# 	Training Loss = 4956.34423828125
# 	Relative L2 error (test) = 100.00126361846924
# Iteration Number = 4040
# 	IC Loss = 0.499909907579422
# 	BC Loss = 3.5540857315063477
# 	Physics Loss = 4871.88330078125
# 	Training Loss = 4875.9375
# 	Relative L2 error (test) = 100.00112056732178
# Iteration Number = 4050
# 	IC Loss = 0.49991559982299805
# 	BC Loss = 3.554067611694336
# 	Physics Loss = 4844.4111328125
# 	Training Loss = 4848.46533203125
# 	Relative L2 error (test) = 100.00098943710327
# Iteration Number = 4060
# 	IC Loss = 0.4999196231365204
# 	BC Loss = 3.554060459136963
# 	Physics Loss = 4652.4404296875
# 	Training Loss = 4656.49462890625
# 	Relative L2 error (test) = 100.00094175338745
# Iteration Number = 4070
# 	IC Loss = 0.4999293386936188
# 	BC Loss = 3.5540547370910645
# 	Physics Loss = 4858.8623046875
# 	Training Loss = 4862.91650390625
# 	Relative L2 error (test) = 100.00083446502686
# Iteration Number = 4080
# 	IC Loss = 0.49994292855262756
# 	BC Loss = 3.5540380477905273
# 	Physics Loss = 4539.2197265625
# 	Training Loss = 4543.27392578125
# 	Relative L2 error (test) = 100.00056028366089
# Iteration Number = 4090
# 	IC Loss = 0.4999467134475708
# 	BC Loss = 3.5540242195129395
# 	Physics Loss = 4846.068359375
# 	Training Loss = 4850.12255859375
# 	Relative L2 error (test) = 100.00083446502686
# Iteration Number = 4100
# 	IC Loss = 0.4999382197856903
# 	BC Loss = 3.554014205932617
# 	Physics Loss = 4712.3544921875
# 	Training Loss = 4716.408203125
# 	Relative L2 error (test) = 100.001060962677
# Iteration Number = 4110
# 	IC Loss = 0.4999423921108246
# 	BC Loss = 3.5539917945861816
# 	Physics Loss = 4631.4326171875
# 	Training Loss = 4635.486328125
# 	Relative L2 error (test) = 100.00088214874268
# Iteration Number = 4120
# 	IC Loss = 0.4999418556690216
# 	BC Loss = 3.5539727210998535
# 	Physics Loss = 4805.67236328125
# 	Training Loss = 4809.72607421875
# 	Relative L2 error (test) = 100.00085830688477
# Iteration Number = 4130
# 	IC Loss = 0.49994969367980957
# 	BC Loss = 3.5539488792419434
# 	Physics Loss = 4865.787109375
# 	Training Loss = 4869.8408203125
# 	Relative L2 error (test) = 100.00030994415283
# Iteration Number = 4140
# 	IC Loss = 0.499969482421875
# 	BC Loss = 3.5539286136627197
# 	Physics Loss = 4592.09033203125
# 	Training Loss = 4596.14404296875
# 	Relative L2 error (test) = 100.00033378601074
# Iteration Number = 4150
# 	IC Loss = 0.49997052550315857
# 	BC Loss = 3.553925037384033
# 	Physics Loss = 4846.30126953125
# 	Training Loss = 4850.35498046875
# 	Relative L2 error (test) = 100.00089406967163
# Iteration Number = 4160
# 	IC Loss = 0.49996986985206604
# 	BC Loss = 3.553919792175293
# 	Physics Loss = 4839.97216796875
# 	Training Loss = 4844.02587890625
# 	Relative L2 error (test) = 100.00032186508179
# Iteration Number = 4170
# 	IC Loss = 0.49998652935028076
# 	BC Loss = 3.553886890411377
# 	Physics Loss = 4847.9462890625
# 	Training Loss = 4852.0
# 	Relative L2 error (test) = 100.00033378601074
# Iteration Number = 4180
# 	IC Loss = 0.4999656677246094
# 	BC Loss = 3.5538976192474365
# 	Physics Loss = 4686.375
# 	Training Loss = 4690.4287109375
# 	Relative L2 error (test) = 100.00123977661133
# Iteration Number = 4190
# 	IC Loss = 0.4999539852142334
# 	BC Loss = 3.5539045333862305
# 	Physics Loss = 4651.4765625
# 	Training Loss = 4655.5302734375
# 	Relative L2 error (test) = 100.00088214874268
# Iteration Number = 4200
# 	IC Loss = 0.49995896220207214
# 	BC Loss = 3.5538907051086426
# 	Physics Loss = 4894.943359375
# 	Training Loss = 4898.9970703125
# 	Relative L2 error (test) = 100.00050067901611
# Iteration Number = 4210
# 	IC Loss = 0.4999481439590454
# 	BC Loss = 3.5538763999938965
# 	Physics Loss = 4904.857421875
# 	Training Loss = 4908.9111328125
# 	Relative L2 error (test) = 100.00098943710327
# Iteration Number = 4220
# 	IC Loss = 0.4999622702598572
# 	BC Loss = 3.5538344383239746
# 	Physics Loss = 4780.26708984375
# 	Training Loss = 4784.32080078125
# 	Relative L2 error (test) = 100.00030994415283
# Iteration Number = 4230
# 	IC Loss = 0.4999568462371826
# 	BC Loss = 3.553802013397217
# 	Physics Loss = 4777.47802734375
# 	Training Loss = 4781.53173828125
# 	Relative L2 error (test) = 100.00050067901611
# Iteration Number = 4240
# 	IC Loss = 0.499938040971756
# 	BC Loss = 3.5537610054016113
# 	Physics Loss = 4971.619140625
# 	Training Loss = 4975.6728515625
# 	Relative L2 error (test) = 100.00057220458984
# Iteration Number = 4250
# 	IC Loss = 0.49993160367012024
# 	BC Loss = 3.553722858428955
# 	Physics Loss = 4745.5732421875
# 	Training Loss = 4749.626953125
# 	Relative L2 error (test) = 100.00051259994507
# Iteration Number = 4260
# 	IC Loss = 0.49990418553352356
# 	BC Loss = 3.5537352561950684
# 	Physics Loss = 4547.7744140625
# 	Training Loss = 4551.828125
# 	Relative L2 error (test) = 100.00076293945312
# Iteration Number = 4270
# 	IC Loss = 0.4998903274536133
# 	BC Loss = 3.5537772178649902
# 	Physics Loss = 4862.98828125
# 	Training Loss = 4867.0419921875
# 	Relative L2 error (test) = 100.00113248825073
# Iteration Number = 4280
# 	IC Loss = 0.4999012351036072
# 	BC Loss = 3.5537617206573486
# 	Physics Loss = 4693.0654296875
# 	Training Loss = 4697.119140625
# 	Relative L2 error (test) = 100.00107288360596
# Iteration Number = 4290
# 	IC Loss = 0.499910831451416
# 	BC Loss = 3.5537424087524414
# 	Physics Loss = 4730.13232421875
# 	Training Loss = 4734.18603515625
# 	Relative L2 error (test) = 100.0007152557373
# Iteration Number = 4300
# 	IC Loss = 0.49990153312683105
# 	BC Loss = 3.553736448287964
# 	Physics Loss = 4980.86181640625
# 	Training Loss = 4984.91552734375
# 	Relative L2 error (test) = 100.00033378601074
# Iteration Number = 4310
# 	IC Loss = 0.4998951852321625
# 	BC Loss = 3.553704023361206
# 	Physics Loss = 4820.6025390625
# 	Training Loss = 4824.65625
# 	Relative L2 error (test) = 100.00101327896118
# Iteration Number = 4320
# 	IC Loss = 0.49985530972480774
# 	BC Loss = 3.553642749786377
# 	Physics Loss = 4666.7421875
# 	Training Loss = 4670.7958984375
# 	Relative L2 error (test) = 100.00112056732178
# Iteration Number = 4330
# 	IC Loss = 0.49982520937919617
# 	BC Loss = 3.553556442260742
# 	Physics Loss = 4939.53759765625
# 	Training Loss = 4943.5908203125
# 	Relative L2 error (test) = 100.0009536743164
# Iteration Number = 4340
# 	IC Loss = 0.4998374879360199
# 	BC Loss = 3.5534443855285645
# 	Physics Loss = 4548.76611328125
# 	Training Loss = 4552.8193359375
# 	Relative L2 error (test) = 100.00051259994507
# Iteration Number = 4350
# 	IC Loss = 0.49980834126472473
# 	BC Loss = 3.553349018096924
# 	Physics Loss = 4629.01220703125
# 	Training Loss = 4633.0654296875
# 	Relative L2 error (test) = 100.00104904174805
# Iteration Number = 4360
# 	IC Loss = 0.4997505843639374
# 	BC Loss = 3.5532162189483643
# 	Physics Loss = 4675.56396484375
# 	Training Loss = 4679.61669921875
# 	Relative L2 error (test) = 100.00135898590088
# Iteration Number = 4370
# 	IC Loss = 0.49977046251296997
# 	BC Loss = 3.5532193183898926
# 	Physics Loss = 4799.4814453125
# 	Training Loss = 4803.53466796875
# 	Relative L2 error (test) = 100.00041723251343
# Iteration Number = 4380
# 	IC Loss = 0.4997754991054535
# 	BC Loss = 3.553345203399658
# 	Physics Loss = 4801.25146484375
# 	Training Loss = 4805.3046875
# 	Relative L2 error (test) = 100.00150203704834
# Iteration Number = 4390
# 	IC Loss = 0.4997895061969757
# 	BC Loss = 3.5533390045166016
# 	Physics Loss = 5048.66015625
# 	Training Loss = 5052.71337890625
# 	Relative L2 error (test) = 100.00036954879761
# Iteration Number = 4400
# 	IC Loss = 0.49976497888565063
# 	BC Loss = 3.553215503692627
# 	Physics Loss = 4896.21923828125
# 	Training Loss = 4900.2724609375
# 	Relative L2 error (test) = 100.00060796737671
# Iteration Number = 4410
# 	IC Loss = 0.4997659921646118
# 	BC Loss = 3.553110122680664
# 	Physics Loss = 4907.3701171875
# 	Training Loss = 4911.4228515625
# 	Relative L2 error (test) = 100.00132322311401
# Iteration Number = 4420
# 	IC Loss = 0.49981796741485596
# 	BC Loss = 3.5530025959014893
# 	Physics Loss = 4767.22412109375
# 	Training Loss = 4771.27685546875
# 	Relative L2 error (test) = 100.001060962677
# Iteration Number = 4430
# 	IC Loss = 0.49983540177345276
# 	BC Loss = 3.552905559539795
# 	Physics Loss = 4774.0576171875
# 	Training Loss = 4778.1103515625
# 	Relative L2 error (test) = 100.00050067901611
# Iteration Number = 4440
# 	IC Loss = 0.49972957372665405
# 	BC Loss = 3.5527901649475098
# 	Physics Loss = 4833.71435546875
# 	Training Loss = 4837.76708984375
# 	Relative L2 error (test) = 100.0018835067749
# Iteration Number = 4450
# 	IC Loss = 0.4996913969516754
# 	BC Loss = 3.55263614654541
# 	Physics Loss = 4709.79541015625
# 	Training Loss = 4713.84765625
# 	Relative L2 error (test) = 100.00054836273193
# Iteration Number = 4460
# 	IC Loss = 0.49968594312667847
# 	BC Loss = 3.552551746368408
# 	Physics Loss = 4856.99853515625
# 	Training Loss = 4861.05078125
# 	Relative L2 error (test) = 100.00060796737671
# Iteration Number = 4470
# 	IC Loss = 0.4996383786201477
# 	BC Loss = 3.5523667335510254
# 	Physics Loss = 4968.05126953125
# 	Training Loss = 4972.103515625
# 	Relative L2 error (test) = 100.00077486038208
# Iteration Number = 4480
# 	IC Loss = 0.4996005892753601
# 	BC Loss = 3.55184268951416
# 	Physics Loss = 5021.96923828125
# 	Training Loss = 5026.0205078125
# 	Relative L2 error (test) = 100.00102519989014
# Iteration Number = 4490
# 	IC Loss = 0.49957749247550964
# 	BC Loss = 3.5513195991516113
# 	Physics Loss = 4548.18798828125
# 	Training Loss = 4552.23876953125
# 	Relative L2 error (test) = 100.00324249267578
# Iteration Number = 4500
# 	IC Loss = 0.49945563077926636
# 	BC Loss = 3.5504050254821777
# 	Physics Loss = 4715.87841796875
# 	Training Loss = 4719.92822265625
# 	Relative L2 error (test) = 100.00125169754028
# Iteration Number = 4510
# 	IC Loss = 0.49917539954185486
# 	BC Loss = 3.5491127967834473
# 	Physics Loss = 4589.95361328125
# 	Training Loss = 4594.001953125
# 	Relative L2 error (test) = 100.00206232070923
# Iteration Number = 4520
# 	IC Loss = 0.4986635148525238
# 	BC Loss = 3.54818058013916
# 	Physics Loss = 4750.1591796875
# 	Training Loss = 4754.2060546875
# 	Relative L2 error (test) = 100.01022815704346
# Iteration Number = 4530
# 	IC Loss = 0.4989713728427887
# 	BC Loss = 3.5471301078796387
# 	Physics Loss = 4872.42822265625
# 	Training Loss = 4876.47412109375
# 	Relative L2 error (test) = 100.00326633453369
# Iteration Number = 4540
# 	IC Loss = 0.4988098442554474
# 	BC Loss = 3.5424466133117676
# 	Physics Loss = 4774.09326171875
# 	Training Loss = 4778.13427734375
# 	Relative L2 error (test) = 100.02831220626831
# Iteration Number = 4550
# 	IC Loss = 0.5000686049461365
# 	BC Loss = 3.526179790496826
# 	Physics Loss = 4818.6103515625
# 	Training Loss = 4822.63671875
# 	Relative L2 error (test) = 100.85960626602173
# Iteration Number = 4560
# 	IC Loss = 0.5041777491569519
# 	BC Loss = 3.585175037384033
# 	Physics Loss = 4954.2744140625
# 	Training Loss = 4958.36376953125
# 	Relative L2 error (test) = 100.29895305633545
# Iteration Number = 4570
# 	IC Loss = 0.5013733506202698
# 	BC Loss = 3.5596723556518555
# 	Physics Loss = 4874.04052734375
# 	Training Loss = 4878.1015625
# 	Relative L2 error (test) = 100.35591125488281
# Iteration Number = 4580
# 	IC Loss = 0.49966979026794434
# 	BC Loss = 3.559940814971924
# 	Physics Loss = 5132.30224609375
# 	Training Loss = 5136.36181640625
# 	Relative L2 error (test) = 100.13463497161865
# Iteration Number = 4590
# 	IC Loss = 0.5006703734397888
# 	BC Loss = 3.555788040161133
# 	Physics Loss = 4672.9072265625
# 	Training Loss = 4676.9638671875
# 	Relative L2 error (test) = 100.02638101577759
# Iteration Number = 4600
# 	IC Loss = 0.49978089332580566
# 	BC Loss = 3.5552260875701904
# 	Physics Loss = 4767.23046875
# 	Training Loss = 4771.28564453125
# 	Relative L2 error (test) = 100.01890659332275
# Iteration Number = 4610
# 	IC Loss = 0.500186562538147
# 	BC Loss = 3.554255485534668
# 	Physics Loss = 4950.94775390625
# 	Training Loss = 4955.001953125
# 	Relative L2 error (test) = 100.00170469284058
# Iteration Number = 4620
# 	IC Loss = 0.4999088644981384
# 	BC Loss = 3.5543456077575684
# 	Physics Loss = 4897.3818359375
# 	Training Loss = 4901.43603515625
# 	Relative L2 error (test) = 100.00475645065308
# Iteration Number = 4630
# 	IC Loss = 0.5000529885292053
# 	BC Loss = 3.5541446208953857
# 	Physics Loss = 4678.35302734375
# 	Training Loss = 4682.4072265625
# 	Relative L2 error (test) = 99.99991059303284
# Iteration Number = 4640
# 	IC Loss = 0.4999690651893616
# 	BC Loss = 3.5542168617248535
# 	Physics Loss = 4995.15087890625
# 	Training Loss = 4999.205078125
# 	Relative L2 error (test) = 100.0018835067749
# Iteration Number = 4650
# 	IC Loss = 0.5000184774398804
# 	BC Loss = 3.5541601181030273
# 	Physics Loss = 4788.482421875
# 	Training Loss = 4792.53662109375
# 	Relative L2 error (test) = 100.00038146972656
# Iteration Number = 4660
# 	IC Loss = 0.49998563528060913
# 	BC Loss = 3.5541844367980957
# 	Physics Loss = 4588.49169921875
# 	Training Loss = 4592.5458984375
# 	Relative L2 error (test) = 100.00132322311401
# Iteration Number = 4670
# 	IC Loss = 0.5000025033950806
# 	BC Loss = 3.5541625022888184
# 	Physics Loss = 4889.470703125
# 	Training Loss = 4893.52490234375
# 	Relative L2 error (test) = 100.00014305114746
# Iteration Number = 4680
# 	IC Loss = 0.49999362230300903
# 	BC Loss = 3.554171562194824
# 	Physics Loss = 5013.47705078125
# 	Training Loss = 5017.53125
# 	Relative L2 error (test) = 100.00090599060059
# Iteration Number = 4690
# 	IC Loss = 0.5000079274177551
# 	BC Loss = 3.5541648864746094
# 	Physics Loss = 4551.22802734375
# 	Training Loss = 4555.2822265625
# 	Relative L2 error (test) = 100.0005841255188
# Iteration Number = 4700
# 	IC Loss = 0.5000072121620178
# 	BC Loss = 3.5541739463806152
# 	Physics Loss = 4850.58447265625
# 	Training Loss = 4854.638671875
# 	Relative L2 error (test) = 100.0006914138794
# Iteration Number = 4710
# 	IC Loss = 0.5000188946723938
# 	BC Loss = 3.554168224334717
# 	Physics Loss = 4645.41845703125
# 	Training Loss = 4649.47265625
# 	Relative L2 error (test) = 100.0004768371582
# Iteration Number = 4720
# 	IC Loss = 0.5000134706497192
# 	BC Loss = 3.5541653633117676
# 	Physics Loss = 5244.53564453125
# 	Training Loss = 5248.58984375
# 	Relative L2 error (test) = 100.00060796737671
# Iteration Number = 4730
# 	IC Loss = 0.5000142455101013
# 	BC Loss = 3.5541419982910156
# 	Physics Loss = 4518.279296875
# 	Training Loss = 4522.33349609375
# 	Relative L2 error (test) = 100.00065565109253
# Iteration Number = 4740
# 	IC Loss = 0.5000121593475342
# 	BC Loss = 3.5541226863861084
# 	Physics Loss = 5044.14404296875
# 	Training Loss = 5048.1982421875
# 	Relative L2 error (test) = 100.00052452087402
# Iteration Number = 4750
# 	IC Loss = 0.5000067949295044
# 	BC Loss = 3.554110050201416
# 	Physics Loss = 5088.04833984375
# 	Training Loss = 5092.1025390625
# 	Relative L2 error (test) = 100.00061988830566
# Iteration Number = 4760
# 	IC Loss = 0.4999963939189911
# 	BC Loss = 3.5540947914123535
# 	Physics Loss = 4702.234375
# 	Training Loss = 4706.28857421875
# 	Relative L2 error (test) = 100.00059604644775
# Iteration Number = 4770
# 	IC Loss = 0.4999898672103882
# 	BC Loss = 3.554089069366455
# 	Physics Loss = 4561.6328125
# 	Training Loss = 4565.68701171875
# 	Relative L2 error (test) = 100.0006914138794
# Iteration Number = 4780
# 	IC Loss = 0.49998927116394043
# 	BC Loss = 3.5540771484375
# 	Physics Loss = 4912.12060546875
# 	Training Loss = 4916.1748046875
# 	Relative L2 error (test) = 100.00064373016357
# KeyboardInterrupt
