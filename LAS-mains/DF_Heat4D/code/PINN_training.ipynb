# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader 
import numpy as np
from scipy import io
import matplotlib.pyplot as plt
import argparse
import os
import copy
import time


def inital_soln(xt_grid):
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = torch.cos((20/d)*x_grid.sum(axis = 1)).reshape(-1,1)

    return u.flatten()


def exact_soln(xt_grid):
    
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = torch.cos((20/d)*x_grid.sum(axis = 1)).reshape(-1,1)*torch.exp(-t)
    
    return u.flatten()


def f_function(xt_grid):
    
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = (400/d-1)*torch.cos((20/d)*x_grid.sum(axis = 1)).reshape(-1,1)*torch.exp(-t)
    
    return u.flatten()


def stacked_grid(*args):
    # Generate meshgrid dynamically
    grids = torch.meshgrid(*args, indexing='ij')
    # Flatten and stack the grids into a single tensor
    stacked = torch.hstack([g.flatten()[:, None] for g in grids])
    return stacked.float()


def cal_domain_grad(model, XTGrid, device):
    Loss = torch.nn.MSELoss(reduction='mean')

    XTGrid = XTGrid.requires_grad_(True).to(device)
    u = model.forward(XTGrid)
    
    # Compute first derivatives
    u_grad = torch.autograd.grad(outputs=u, 
                                 inputs=XTGrid, 
                                 grad_outputs=torch.ones_like(u).to(device), 
                                 create_graph=True, 
                                 allow_unused=True)[0]

    # Compute second derivatives for each spatial dimension
    u_laplacian = torch.zeros_like(u[:,0], device=device)
    for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
        ux = u_grad[:, d]
        uxx = torch.autograd.grad(outputs=ux, 
                                  inputs=XTGrid, 
                                  grad_outputs=torch.ones_like(ux).to(device), 
                                  create_graph=True, 
                                  allow_unused=True)[0][:, d]
        u_laplacian += uxx
    f = f_function(XTGrid)
    # Time derivative
    ut = u_grad[:, -1]  # Assuming last dimension is time

    # PDE residual loss (generalized heat/diffusion equation)
    lossf = Loss(ut-u_laplacian, f.flatten())

    # Compute gradient of loss function w.r.t. inputs (for adaptivity or error estimation)
    grad = torch.autograd.grad(outputs=lossf, 
                               inputs=XTGrid, 
                               grad_outputs=torch.ones_like(lossf).to(device),
                               create_graph=True,
                               allow_unused=True)[0]
    
    return grad


class RADSampler():
    def __init__(self, Nf, device, k, c, dim = 1):    
        self.device = device
        self.k = k
        self.c = c
        self.Nf = Nf
        self.dense_Nf = Nf*1
        self.dim = dim
        
    def update(self, model):
        
        x_new = torch.zeros(self.dense_Nf, self.dim, dtype = torch.float32, device=self.device).uniform_(-1, 1)
        t_new = torch.zeros(self.dense_Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
        x_t_new = torch.concatenate((x_new,t_new), axis = 1)
        
        XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True) 
        XTGrid = XTGrid.to(self.device)

        XTGrid = XTGrid.requires_grad_(True).to(self.device)
        
        u = model.forward(XTGrid)
        
        u_grad = torch.autograd.grad(outputs=u, 
                                     inputs=XTGrid, 
                                     grad_outputs=torch.ones_like(u).to(device), 
                                     create_graph=True, 
                                     allow_unused=True)[0]
    
        u_laplacian = torch.zeros_like(u[:,0], device=device)
        for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
            ux = u_grad[:, d]
            uxx = torch.autograd.grad(outputs=ux, 
                                      inputs=XTGrid, 
                                      grad_outputs=torch.ones_like(ux).to(device), 
                                      create_graph=True, 
                                      allow_unused=True)[0][:, d]
            u_laplacian += uxx
            
        f = f_function(XTGrid)
        ut = u_grad[:, -1]  
    
        err = torch.abs((ut-u_laplacian-f.flatten()))
        err = (err**self.k)/((err**self.k).mean())+self.c
        err_norm = err/(err.sum())
        
        indice = torch.multinomial(err_norm, self.Nf, replacement = True)
        XTGrid = XTGrid[indice]
        self.XTGrid = XTGrid
        
class LASSampler():
    def __init__(self, Nf, fixed_uniform, device, L_iter = 1, beta = 0.2, tau = 0.002):
        self.Nf = Nf
        self.device = device
        self.cnt = 0
        self.beta = beta
        self.tau = tau
        self.L_iter = L_iter
        self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)

    def update(self, phy_lf, model):

        x_data = self.XTGrid
        samples = x_data.clone().detach().requires_grad_(True)
        
        for t in range(1, self.L_iter + 1):
            grad = phy_lf(model, samples, self.device)
            scaler = torch.sqrt(torch.sum((grad+1e-16)**2, axis = 1)).reshape(-1,1)
            grad = grad/scaler

            with torch.no_grad():
                samples = samples + self.tau * grad + self.beta*torch.sqrt(torch.tensor(2 * self.tau, device=self.device)) * torch.randn(samples.shape, device=self.device)
                for i in range(samples.shape[1]):
                    if i < int(samples.shape[1]-1):
                        samples[:, i] = torch.clamp(samples[:, i], min=-1, max=1)  
                    else:
                        samples[:, i] = torch.clamp(samples[:, i], min=0, max=1) 
                        
            samples = samples.clone().detach().requires_grad_(True)
        self.XTGrid = samples.detach()

class L_INFSampler():
    def __init__(self, Nf, device, step_size = 0.05 , n_iter = 20, dim = 1):

        self.Nf = Nf
        self.device = device
        self.step_size = step_size
        self.n_iter = n_iter
        self.dim = dim

    def update(self, phy_lf, model):

        x_new = torch.zeros(self.Nf, self.dim, dtype = torch.float32, device=self.device).uniform_(-1, 1)
        t_new = torch.zeros(self.Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
        x_t_new = torch.concatenate((x_new,t_new), axis = 1)
        self.XTGrid = x_t_new
            
        x_data = self.XTGrid
        samples = x_data.clone().detach().requires_grad_(True)
    
        for t in range(1, self.n_iter + 1):
            grad = phy_lf(model, samples, self.device)
            with torch.no_grad():
                samples = samples + self.step_size * torch.sign(grad)
                for i in range(samples.shape[1]):
                    if i < int(samples.shape[1]-1):
                        samples[:, i] = torch.clamp(samples[:, i], min=-1, max=1)
                    else:
                        samples[:, i] = torch.clamp(samples[:, i], min=0, max=1)
                        
            samples = samples.clone().detach().requires_grad_(True)
        self.XTGrid = samples.detach()           


class R3Sampler(nn.Module):
    def __init__(self,Nf, fixed_uniform, device):
        super(R3Sampler, self).__init__()
        self.Nf = Nf
        self.device = device
        self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
    
    def update(self, loss_aver, loss_ele):
        with torch.no_grad():
            cho_i = loss_ele > loss_aver
            cho_i = cho_i.to('cpu')
            self.XTGrid = self.XTGrid[cho_i].detach()
            need_n_sample = self.Nf-self.XTGrid.shape[0]
            x_new = torch.zeros(need_n_sample, self.XTGrid.shape[1]-1, dtype = torch.float32, device=self.device).uniform_(-1, 1)
            t_new = torch.zeros(need_n_sample, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
            x_t_new = torch.concatenate((x_new,t_new), axis = 1)
            self.XTGrid = torch.concatenate((self.XTGrid, x_t_new), axis = 0)
            self.XTGrid = torch.tensor(self.XTGrid, dtype = torch.float32, device=self.device, requires_grad=True)
    
class PINN(nn.Module):
    def __init__(self,k , c , t, exact_XYT, exact_u, LBs, UBs, Layers, N0, Nb, Nf, 
                 Activation = nn.Tanh(), 
                 model_name = "PINN.model", device = 'cpu',
                  display_freq = 100, samp = 'fixed' ):
        
        super(PINN, self).__init__()
        
        
        self.LBs = torch.tensor(LBs, dtype=torch.float32)
        self.UBs = torch.tensor(UBs, dtype=torch.float32)
        
        self.Layers = Layers
        self.in_dim  = Layers[0]
        self.out_dim = Layers[-1]
        self.Activation = Activation
        
        self.device = device
        
        x_init = torch.zeros(Nf, len(self.LBs) - 1, dtype = torch.float32, device=self.device).uniform_(0, UBs[0])
        t_init = torch.zeros(Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, UBs[-1])
        x_t_init = torch.concatenate((x_init,t_init), axis = 1)
        self.fixed_uniform = torch.tensor(x_t_init, dtype = torch.float32, device=self.device, requires_grad=True)
        
        self.N0 = N0
        self.Nb = Nb
        self.Nf = Nf
        
        self.t = t
        self.exact_XYT = exact_XYT
        self.exact_u = exact_u.reshape(-1,1)
        
        self.XT0, self.u0  = self.InitialCondition(self.N0, self.LBs, self.UBs)
        self.boundary_set = self.BoundaryCondition(self.Nb, self.LBs, self.UBs)
        
        self.XT0 = self.XT0.to(device)
        self.u0 = self.u0.to(device) 
        
        self._nn = self.build_model()
        self._nn.to(self.device)
        self.Loss = torch.nn.MSELoss(reduction='mean')
        
        self.model_name = model_name
        self.display_freq = display_freq
        
        self.k = k
        self.c = c
        self.X_star = self.exact_XYT
        self.method = samp
        
        self.r3_sample = R3Sampler(self.Nf, self.fixed_uniform, device)
        self.las = LASSampler(self.Nf, fixed_uniform=self.fixed_uniform, device=self.device, L_iter = 1, beta = 0.2, tau=1e-2)
        self.l_inf = L_INFSampler(self.Nf, device=self.device, step_size = 0.05 , n_iter = 20, dim = len(self.LBs) - 1)
        self.rad = RADSampler(Nf = self.Nf, device=self.device, k = self.k, c=self.c, dim = len(self.LBs) - 1)
        
    
    def build_model(self):
        Seq = nn.Sequential()
        for ii in range(len(self.Layers)-1):
            this_module = nn.Linear(self.Layers[ii], self.Layers[ii+1])
            nn.init.xavier_normal_(this_module.weight)
            Seq.add_module("Linear" + str(ii), this_module)
            if not ii == len(self.Layers)-2:
                Seq.add_module("Activation" + str(ii), self.Activation)
        return Seq
        
    def forward(self, x):
        return self._nn.forward(x.to(self.device)).reshape(-1)

    def InitialCondition(self, N0, LB, UB):
        n_per_dim = int(np.round(N0**(1/len(LB[:-1]))))
#         n_per_dim = int(np.round(np.sqrt(N0)))
        nodes = []
        for i in range(len(LB)-1):
            X = torch.linspace(LB[i], UB[i], n_per_dim).float()
            nodes.append(X)
            
        t_in = torch.tensor([LB[-1]]).float()
        nodes.append(t_in)
        
        XT_in = stacked_grid(*nodes)
        u0 = inital_soln(XT_in)
        return XT_in, u0

    def ICLoss(self):
        uv0_pred = self.forward(self.XT0)
        loss = self.Loss(uv0_pred, self.u0.to(self.device))
        return loss 

    def BoundaryPoints(self, nb, boundary_index, LBs, UBs, boundary_type):
        """
        Generalized function to get boundary points in an N-dimensional space.
        - `boundary_index`: Index of the dimension where the boundary is applied.
        - `nb`: Number of boundary points.
        - `LBs`, `UBs`: Lower and upper bounds for each dimension.
        - `boundary_type`: 'lower' for the lower boundary, 'upper' for the upper boundary.
        """
        n_per_dim = int(np.round(nb ** (1 / (len(LBs) - 1))))  # Distribute points across remaining dimensions
        
        # Create grid ranges for each dimension
        grid_ranges = []
        for i in range(len(LBs)  - 1):  # Excluding time
            if i == boundary_index:
                if boundary_type == 'lower':
                    grid_ranges.append(torch.tensor([LBs[i]]).float().to(self.device))  # Fixed lower boundary position
                else:
                    grid_ranges.append(torch.tensor([UBs[i]]).float().to(self.device))  # Fixed upper boundary position
            else:
                grid_ranges.append(torch.linspace(LBs[i], UBs[i], n_per_dim).float().to(self.device))

        # Time dimension (last dimension)
        grid_ranges.append(torch.linspace(LBs[-1], UBs[-1], nb).float().to(self.device))

        return stacked_grid(*grid_ranges)

    
    def BoundaryCondition(self, Nb, LBs, UBs):
        """
        Generalized function to get all boundary conditions in an N-dimensional space.
        - `Nb`: Total number of boundary points.
        - `LBs`, `UBs`: Lower and upper bounds for each dimension.
        """
        nb = int(np.round(Nb / (2 * (len(LBs) - 1))))  # Divide points across boundary faces
        boundary_sets = []
        
        for d in range(len(LBs) - 1):  # Iterate over all spatial dimensions
            lower_boundary = self.BoundaryPoints(nb, d, LBs, UBs, 'lower')
            upper_boundary = self.BoundaryPoints(nb, d, LBs, UBs, 'upper')
            boundary_sets.append((lower_boundary, upper_boundary))

        return boundary_sets  # Returns pairs of boundaries per dimension

    def BCLoss(self):
        """
        Compute boundary condition loss given a model, exact solution, and loss function.
        """
        total_loss = 0
        for lower, upper in self.boundary_set:
            U_L, U_R = self.forward(lower), self.forward(upper)
            UL_exact, UR_exact = exact_soln(lower), exact_soln(upper)

            total_loss += self.Loss(U_L, UL_exact) + self.Loss(U_R, UR_exact)
        
        return total_loss
    
    def PhysicsLoss(self, XTGrid):
        XTGrid = XTGrid.requires_grad_(True).to(device)
        u = self.forward(XTGrid)

        # Compute first derivatives
        u_grad = torch.autograd.grad(outputs=u, 
                                     inputs=XTGrid, 
                                     grad_outputs=torch.ones_like(u).to(device), 
                                     create_graph=True, 
                                     allow_unused=True)[0]

        # Compute second derivatives for each spatial dimension
        u_laplacian = torch.zeros_like(u, device=device)
        for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
            ux = u_grad[:, d]
            uxx = torch.autograd.grad(outputs=ux, 
                                      inputs=XTGrid, 
                                      grad_outputs=torch.ones_like(ux).to(device), 
                                      create_graph=True, 
                                      allow_unused=True)[0][:, d]
            u_laplacian += uxx
            
        f = f_function(XTGrid)

        # Time derivative
        ut = u_grad[:, -1]  # Assuming last dimension is time

        loss2 = (u_laplacian - ut+f.flatten())**2
        loss1 = loss2.mean()

        return loss1, loss2 

    def Train(self, n_iters, weights=(1.0,1.0,1.0)):
        params = list(self.parameters())
        optimizer = optim.Adam(params, lr=1e-3)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 5000, gamma=0.9, last_epoch=-1)
        min_loss = 999999.0
        Training_Losses = [-10]*n_iters
        Test_Losses = []
        rel_error = [-10]*(1+n_iters//10)
        
        for jj in range(n_iters):
            Total_ICLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            Total_BCLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            Total_PhysicsLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            
            Total_ICLoss = Total_ICLoss + self.ICLoss()
            Total_BCLoss = Total_BCLoss + self.BCLoss()
            
            if self.method =='r3':
                if jj == 0:
                    XTGrid = self.r3_sample.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype = torch.float32, device=self.device, requires_grad=True) 
                else:
                    with torch.no_grad():
                        self.r3_sample.update(loss1, loss2)
                        XTGrid = self.r3_sample.XTGrid
                        XTGrid = torch.tensor(XTGrid, dtype = torch.float32, device=self.device, requires_grad=True) 
                        
            elif self.method == 'las':
                if jj == 0:
                    XTGrid = self.las.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                else:
                    if self.las.cnt % 1 == 0:# 4,6,8,10 cnt = 4, 
                        self.las.update(cal_domain_grad, self._nn)
                    XTGrid = self.las.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                self.las.cnt += 1
            
            elif self.method =='l_inf':
                    self.l_inf.update(cal_domain_grad, self._nn)
                    XTGrid = self.l_inf.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                
            elif self.method =='rad':
                    self.rad.update(self._nn)
                    XTGrid = self.rad.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)   
            
            elif self.method =='fixed':
                    XTGrid = torch.tensor(self.fixed_uniform, dtype = torch.float32, device=self.device, requires_grad=True) 
            
            elif self.method =='random-r':
                    x_new = torch.zeros(self.Nf, len(self.LBs) - 1, dtype = torch.float32, device=self.device).uniform_(-1, 1)
                    t_new = torch.zeros(self.Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
                    x_t_new = torch.concatenate((x_new,t_new), axis = 1)
                    XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True) 
                
            optimizer.zero_grad()    
            loss1, loss2 = self.PhysicsLoss(XTGrid) # For r3 method, loss2 contains element-wise errors
            
            Total_PhysicsLoss = Total_PhysicsLoss + loss1
            Total_Loss = weights[0]*Total_ICLoss + weights[1]*Total_BCLoss\
                        + weights[2]*Total_PhysicsLoss 
            
            Total_Loss.backward()
            optimizer.step()
            scheduler.step()
            if Total_Loss < min_loss:
                torch.save(self._nn.state_dict(), "../models/"+self.method+'_'+str(len(self.Layers)-2)+'_'+str(self.Nf)+'.pt')
                min_loss = float(Total_Loss)
                    
            Training_Losses[jj] = float(Total_Loss)
            
            if (jj+1) % self.display_freq == 0:
                with torch.no_grad():
                    outputs = self.forward(self.X_star)
                    outputs = outputs.reshape(-1,1)
                    re = np.linalg.norm(self.exact_u.cpu()-outputs.cpu().detach()) / np.linalg.norm(self.exact_u.cpu().detach())
                    rel_error[int((jj+1)/10)] = float(re*100)
                    
                print("Iteration Number = {}".format(jj+1))
                print("\tIC Loss = {}".format(float(Total_ICLoss)))
                print("\tBC Loss = {}".format(float(Total_BCLoss)))
                print("\tPhysics Loss = {}".format(float(Total_PhysicsLoss)))
                print("\tTraining Loss = {}".format(float(Total_Loss)))
                print("\tRelative L2 error (test) = {}".format(float(re*100)))

        return Training_Losses, rel_error


if __name__ == "__main__":
                
        parser = argparse.ArgumentParser()
        parser.add_argument('--nodes', type=int, default = 128, help='The number of nodes per hidden layer in the neural network')
        parser.add_argument('--layers', type=int, default = 8, help='The number of hidden layers in the neural network')
        parser.add_argument('--N0', type=int, default = 100, help='The number of points to use on the initial condition')
        parser.add_argument('--Nb', type=int, default = 100, help='The number of points to use on the boundary condition')
        parser.add_argument('--Nf', type=int, default = 1000, help='The number of collocation points to use')
        parser.add_argument('--epochs', type=int, default = 10000, help='The number of epochs to train the neural network')
        parser.add_argument('--method', type=str, default='rad', help='Sampling method') # fixed, random-r, rad, r3, l_inf, las 
        parser.add_argument('--model-name', type=str, default='PINN_model', help='File name to save the model')
        parser.add_argument('--display-freq', type=int, default=10, help='How often to display loss information')
        parser.add_argument('-f')
        args = parser.parse_args()

        if not os.path.exists("../models/"):
            os.mkdir("../models/")
            
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        NHiddenLayers = args.layers

        desired_dim = 4
    
        LBs = [-1]*desired_dim
        UBs = [1]*desired_dim

        LBs.append(0)
        UBs.append(1)

        Nx = 20
        Nt = 20
        mesh_nodes = []
    
        for i in range(len(LBs)-1):
            X = torch.linspace(LBs[i], UBs[i], Nx).float()
            mesh_nodes.append(X)
        
        T = torch.linspace(LBs[-1], UBs[-1], Nt).float()
        mesh_nodes.append(T)
        
        XYT = stacked_grid(*mesh_nodes)
        Exact_U = exact_soln(XYT)
        Activation = nn.Tanh()
    
        Layers = [desired_dim+1] + [args.nodes]*NHiddenLayers + [1]

        k = 1
        c = 1

        repeat = [0, 1, 2, 3, 4]
        for i in repeat:
            pinn = PINN(  k = k,
                          c = c,
                          t= T,
                          exact_XYT = XYT,
                          exact_u = Exact_U,
                          Layers = Layers,
                          LBs = LBs,
                          UBs = UBs,
                          N0 = args.N0,
                          Nb = args.Nb,
                          Nf = args.Nf,
                          Activation = Activation,
                          device = device,
                          model_name = "../models/" + args.model_name + ".model_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i),
                          display_freq = args.display_freq, samp = args.method )

            Losses_train, Losses_rel_l2 = pinn.Train(args.epochs, weights = (1, 1, 1)) # initial, boundary, residual

            torch.save(Losses_train, "../models/" + args.model_name + ".loss_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
            torch.save(Losses_rel_l2, "../models/" + args.model_name + ".rel_l2_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
# Out:
# /tmp/ipykernel_1094362/2105174498.py:248: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.fixed_uniform = torch.tensor(x_t_init, dtype = torch.float32, device=self.device, requires_grad=True)
# /tmp/ipykernel_1094362/2105174498.py:212: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
# /tmp/ipykernel_1094362/2105174498.py:151: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
# /tmp/ipykernel_1094362/2105174498.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True)
# /tmp/ipykernel_1094362/2105174498.py:449: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
# Iteration Number = 10
# 	IC Loss = 0.5338843464851379
# 	BC Loss = 3.0511512756347656
# 	Physics Loss = 2701.248046875
# 	Training Loss = 2704.8330078125
# 	Relative L2 error (test) = 105.19651174545288
# Iteration Number = 20
# 	IC Loss = 0.5175329446792603
# 	BC Loss = 2.8916635513305664
# 	Physics Loss = 2800.358642578125
# 	Training Loss = 2803.767822265625
# 	Relative L2 error (test) = 105.77619075775146
# Iteration Number = 30
# 	IC Loss = 0.5647761821746826
# 	BC Loss = 3.424623489379883
# 	Physics Loss = 2693.5498046875
# 	Training Loss = 2697.539306640625
# 	Relative L2 error (test) = 116.58012866973877
# Iteration Number = 40
# 	IC Loss = 0.7454725503921509
# 	BC Loss = 4.4484758377075195
# 	Physics Loss = 2637.813232421875
# 	Training Loss = 2643.007080078125
# 	Relative L2 error (test) = 145.44506072998047
# Iteration Number = 50
# 	IC Loss = 0.5147466659545898
# 	BC Loss = 2.674617052078247
# 	Physics Loss = 2610.959716796875
# 	Training Loss = 2614.149169921875
# 	Relative L2 error (test) = 107.46846199035645
# Iteration Number = 60
# 	IC Loss = 0.5771209597587585
# 	BC Loss = 2.9614992141723633
# 	Physics Loss = 2652.443115234375
# 	Training Loss = 2655.981689453125
# 	Relative L2 error (test) = 104.61865663528442
# Iteration Number = 70
# 	IC Loss = 0.6025976538658142
# 	BC Loss = 3.07832407951355
# 	Physics Loss = 2965.55859375
# 	Training Loss = 2969.239501953125
# 	Relative L2 error (test) = 102.92010307312012
# Iteration Number = 80
# 	IC Loss = 0.549717366695404
# 	BC Loss = 2.8664774894714355
# 	Physics Loss = 2463.13916015625
# 	Training Loss = 2466.555419921875
# 	Relative L2 error (test) = 102.44934558868408
# Iteration Number = 90
# 	IC Loss = 0.4928465485572815
# 	BC Loss = 2.7001309394836426
# 	Physics Loss = 2731.98193359375
# 	Training Loss = 2735.1748046875
# 	Relative L2 error (test) = 100.63725709915161
# Iteration Number = 100
# 	IC Loss = 0.48992788791656494
# 	BC Loss = 2.6815459728240967
# 	Physics Loss = 2692.772216796875
# 	Training Loss = 2695.943603515625
# 	Relative L2 error (test) = 100.65546035766602
# Iteration Number = 110
# 	IC Loss = 0.5014351010322571
# 	BC Loss = 2.675689697265625
# 	Physics Loss = 2775.895263671875
# 	Training Loss = 2779.072509765625
# 	Relative L2 error (test) = 100.47521591186523
# Iteration Number = 120
# 	IC Loss = 0.49603748321533203
# 	BC Loss = 2.714656352996826
# 	Physics Loss = 2534.98828125
# 	Training Loss = 2538.198974609375
# 	Relative L2 error (test) = 101.5670657157898
# Iteration Number = 130
# 	IC Loss = 0.5004558563232422
# 	BC Loss = 2.662189483642578
# 	Physics Loss = 2574.55517578125
# 	Training Loss = 2577.7177734375
# 	Relative L2 error (test) = 100.08201599121094
# Iteration Number = 140
# 	IC Loss = 0.49716803431510925
# 	BC Loss = 2.659198045730591
# 	Physics Loss = 2556.542236328125
# 	Training Loss = 2559.698486328125
# 	Relative L2 error (test) = 100.20896196365356
# Iteration Number = 150
# 	IC Loss = 0.49898624420166016
# 	BC Loss = 2.656968116760254
# 	Physics Loss = 2576.602294921875
# 	Training Loss = 2579.75830078125
# 	Relative L2 error (test) = 100.02872943878174
# Iteration Number = 160
# 	IC Loss = 0.49633246660232544
# 	BC Loss = 2.656704902648926
# 	Physics Loss = 2745.710205078125
# 	Training Loss = 2748.86328125
# 	Relative L2 error (test) = 100.24793148040771
# Iteration Number = 170
# 	IC Loss = 0.4968433082103729
# 	BC Loss = 2.652766227722168
# 	Physics Loss = 2657.523681640625
# 	Training Loss = 2660.67333984375
# 	Relative L2 error (test) = 100.12900829315186
# Iteration Number = 180
# 	IC Loss = 0.49340665340423584
# 	BC Loss = 2.6499791145324707
# 	Physics Loss = 2673.418212890625
# 	Training Loss = 2676.5615234375
# 	Relative L2 error (test) = 100.27018785476685
# Iteration Number = 190
# 	IC Loss = 0.49188879132270813
# 	BC Loss = 2.645672559738159
# 	Physics Loss = 2685.39453125
# 	Training Loss = 2688.531982421875
# 	Relative L2 error (test) = 100.38843154907227
# Iteration Number = 200
# 	IC Loss = 0.489678293466568
# 	BC Loss = 2.636563777923584
# 	Physics Loss = 2680.74462890625
# 	Training Loss = 2683.870849609375
# 	Relative L2 error (test) = 100.36755800247192
# Iteration Number = 210
# 	IC Loss = 0.49120405316352844
# 	BC Loss = 2.639071464538574
# 	Physics Loss = 2478.0576171875
# 	Training Loss = 2481.18798828125
# 	Relative L2 error (test) = 100.2195954322815
# Iteration Number = 220
# 	IC Loss = 0.48985451459884644
# 	BC Loss = 2.631608247756958
# 	Physics Loss = 2653.570556640625
# 	Training Loss = 2656.692138671875
# 	Relative L2 error (test) = 100.14550685882568
# Iteration Number = 230
# 	IC Loss = 0.48559117317199707
# 	BC Loss = 2.629218578338623
# 	Physics Loss = 2684.128173828125
# 	Training Loss = 2687.242919921875
# 	Relative L2 error (test) = 100.34250020980835
# Iteration Number = 240
# 	IC Loss = 0.4837660789489746
# 	BC Loss = 2.6164021492004395
# 	Physics Loss = 2922.949462890625
# 	Training Loss = 2926.049560546875
# 	Relative L2 error (test) = 100.38849115371704
# Iteration Number = 250
# 	IC Loss = 0.48418116569519043
# 	BC Loss = 2.6139986515045166
# 	Physics Loss = 2647.615966796875
# 	Training Loss = 2650.714111328125
# 	Relative L2 error (test) = 100.05084276199341
# Iteration Number = 260
# 	IC Loss = 0.47280892729759216
# 	BC Loss = 2.5940849781036377
# 	Physics Loss = 2716.68212890625
# 	Training Loss = 2719.7490234375
# 	Relative L2 error (test) = 100.6110429763794
# Iteration Number = 270
# 	IC Loss = 0.46782171726226807
# 	BC Loss = 2.6122050285339355
# 	Physics Loss = 2988.860595703125
# 	Training Loss = 2991.940673828125
# 	Relative L2 error (test) = 102.29718685150146
# Iteration Number = 280
# 	IC Loss = 0.483494371175766
# 	BC Loss = 2.6135406494140625
# 	Physics Loss = 2794.267822265625
# 	Training Loss = 2797.36474609375
# 	Relative L2 error (test) = 101.29767656326294
# Iteration Number = 290
# 	IC Loss = 0.4811798930168152
# 	BC Loss = 2.617067337036133
# 	Physics Loss = 2787.612060546875
# 	Training Loss = 2790.710205078125
# 	Relative L2 error (test) = 100.42835474014282
# Iteration Number = 300
# 	IC Loss = 0.4554992914199829
# 	BC Loss = 2.545867443084717
# 	Physics Loss = 2735.927490234375
# 	Training Loss = 2738.928955078125
# 	Relative L2 error (test) = 101.29256248474121
# Iteration Number = 310
# 	IC Loss = 0.40620559453964233
# 	BC Loss = 2.339510440826416
# 	Physics Loss = 2838.37255859375
# 	Training Loss = 2841.1181640625
# 	Relative L2 error (test) = 104.72173690795898
# Iteration Number = 320
# 	IC Loss = 0.47817352414131165
# 	BC Loss = 2.6650142669677734
# 	Physics Loss = 2684.55419921875
# 	Training Loss = 2687.697265625
# 	Relative L2 error (test) = 102.75270938873291
# Iteration Number = 330
# 	IC Loss = 0.496271014213562
# 	BC Loss = 2.6323580741882324
# 	Physics Loss = 2808.59814453125
# 	Training Loss = 2811.726806640625
# 	Relative L2 error (test) = 100.03210306167603
# Iteration Number = 340
# 	IC Loss = 0.48993948101997375
# 	BC Loss = 2.626391887664795
# 	Physics Loss = 2859.626708984375
# 	Training Loss = 2862.742919921875
# 	Relative L2 error (test) = 100.05087852478027
# Iteration Number = 350
# 	IC Loss = 0.4803050458431244
# 	BC Loss = 2.589740753173828
# 	Physics Loss = 2784.453125
# 	Training Loss = 2787.523193359375
# 	Relative L2 error (test) = 100.27915239334106
# Iteration Number = 360
# 	IC Loss = 0.4737846553325653
# 	BC Loss = 2.5605742931365967
# 	Physics Loss = 2763.99609375
# 	Training Loss = 2767.030517578125
# 	Relative L2 error (test) = 100.43137073516846
# Iteration Number = 370
# 	IC Loss = 0.473065048456192
# 	BC Loss = 2.6526522636413574
# 	Physics Loss = 2720.41259765625
# 	Training Loss = 2723.538330078125
# 	Relative L2 error (test) = 109.04310941696167
# Iteration Number = 380
# 	IC Loss = 0.5561776161193848
# 	BC Loss = 3.0883307456970215
# 	Physics Loss = 2577.753662109375
# 	Training Loss = 2581.398193359375
# 	Relative L2 error (test) = 114.27206993103027
# Iteration Number = 390
# 	IC Loss = 0.7375760078430176
# 	BC Loss = 5.5643510818481445
# 	Physics Loss = 2010.5516357421875
# 	Training Loss = 2016.853515625
# 	Relative L2 error (test) = 285.11273860931396
# Iteration Number = 400
# 	IC Loss = 3.356377601623535
# 	BC Loss = 24.22254753112793
# 	Physics Loss = 2387.51220703125
# 	Training Loss = 2415.091064453125
# 	Relative L2 error (test) = 205.1626682281494
# Iteration Number = 410
# 	IC Loss = 1.5184229612350464
# 	BC Loss = 13.600123405456543
# 	Physics Loss = 1408.048095703125
# 	Training Loss = 1423.1666259765625
# 	Relative L2 error (test) = 179.94049787521362
# Iteration Number = 420
# 	IC Loss = 7.65850305557251
# 	BC Loss = 61.8433837890625
# 	Physics Loss = 1488.685302734375
# 	Training Loss = 1558.1871337890625
# 	Relative L2 error (test) = 472.2726821899414
# Iteration Number = 430
# 	IC Loss = 8.96189022064209
# 	BC Loss = 79.16233825683594
# 	Physics Loss = 1679.3201904296875
# 	Training Loss = 1767.4444580078125
# 	Relative L2 error (test) = 537.5186920166016
# Iteration Number = 440
# 	IC Loss = 4.1774187088012695
# 	BC Loss = 46.184425354003906
# 	Physics Loss = 1287.23046875
# 	Training Loss = 1337.59228515625
# 	Relative L2 error (test) = 314.5460844039917
# Iteration Number = 450
# 	IC Loss = 2.8385729789733887
# 	BC Loss = 19.92047119140625
# 	Physics Loss = 938.7213134765625
# 	Training Loss = 961.4803466796875
# 	Relative L2 error (test) = 216.21341705322266
# Iteration Number = 460
# 	IC Loss = 1.985571026802063
# 	BC Loss = 13.085733413696289
# 	Physics Loss = 830.0686645507812
# 	Training Loss = 845.1399536132812
# 	Relative L2 error (test) = 228.15170288085938
# Iteration Number = 470
# 	IC Loss = 0.9703092575073242
# 	BC Loss = 7.6714677810668945
# 	Physics Loss = 799.2510375976562
# 	Training Loss = 807.892822265625
# 	Relative L2 error (test) = 223.88620376586914
# Iteration Number = 480
# 	IC Loss = 0.6877518892288208
# 	BC Loss = 10.27225112915039
# 	Physics Loss = 448.34515380859375
# 	Training Loss = 459.3051452636719
# 	Relative L2 error (test) = 283.7473154067993
# Iteration Number = 490
# 	IC Loss = 0.6372916102409363
# 	BC Loss = 9.643850326538086
# 	Physics Loss = 274.77667236328125
# 	Training Loss = 285.05780029296875
# 	Relative L2 error (test) = 179.30986881256104
# Iteration Number = 500
# 	IC Loss = 0.8037303686141968
# 	BC Loss = 10.127339363098145
# 	Physics Loss = 544.954345703125
# 	Training Loss = 555.8854370117188
# 	Relative L2 error (test) = 225.76406002044678
# Iteration Number = 510
# 	IC Loss = 0.6795432567596436
# 	BC Loss = 7.727810859680176
# 	Physics Loss = 471.228515625
# 	Training Loss = 479.6358642578125
# 	Relative L2 error (test) = 182.97191858291626
# Iteration Number = 520
# 	IC Loss = 0.8829542398452759
# 	BC Loss = 7.47706413269043
# 	Physics Loss = 570.2820434570312
# 	Training Loss = 578.64208984375
# 	Relative L2 error (test) = 158.94629955291748
# Iteration Number = 530
# 	IC Loss = 0.6270118355751038
# 	BC Loss = 6.556071758270264
# 	Physics Loss = 263.609619140625
# 	Training Loss = 270.7926940917969
# 	Relative L2 error (test) = 144.4727897644043
# Iteration Number = 540
# 	IC Loss = 0.5047675967216492
# 	BC Loss = 6.559172630310059
# 	Physics Loss = 339.7974853515625
# 	Training Loss = 346.8614196777344
# 	Relative L2 error (test) = 145.11499404907227
# Iteration Number = 550
# 	IC Loss = 0.29022982716560364
# 	BC Loss = 9.251977920532227
# 	Physics Loss = 174.52487182617188
# 	Training Loss = 184.06707763671875
# 	Relative L2 error (test) = 193.35819482803345
# Iteration Number = 560
# 	IC Loss = 0.476251482963562
# 	BC Loss = 6.164392471313477
# 	Physics Loss = 324.8780212402344
# 	Training Loss = 331.5186767578125
# 	Relative L2 error (test) = 107.52283334732056
# Iteration Number = 570
# 	IC Loss = 0.5166683793067932
# 	BC Loss = 7.93856143951416
# 	Physics Loss = 204.26451110839844
# 	Training Loss = 212.71974182128906
# 	Relative L2 error (test) = 123.12088012695312
# Iteration Number = 580
# 	IC Loss = 0.5987105965614319
# 	BC Loss = 5.993041038513184
# 	Physics Loss = 250.63954162597656
# 	Training Loss = 257.2312927246094
# 	Relative L2 error (test) = 97.4415123462677
# Iteration Number = 590
# 	IC Loss = 0.5780272483825684
# 	BC Loss = 6.988631248474121
# 	Physics Loss = 114.22882843017578
# 	Training Loss = 121.79548645019531
# 	Relative L2 error (test) = 132.896625995636
# Iteration Number = 600
# 	IC Loss = 0.6558865904808044
# 	BC Loss = 6.805508613586426
# 	Physics Loss = 216.25454711914062
# 	Training Loss = 223.7159423828125
# 	Relative L2 error (test) = 111.77178621292114
# Iteration Number = 610
# 	IC Loss = 0.6493549346923828
# 	BC Loss = 7.773962020874023
# 	Physics Loss = 123.2400131225586
# 	Training Loss = 131.663330078125
# 	Relative L2 error (test) = 133.00660848617554
# Iteration Number = 620
# 	IC Loss = 0.6617519855499268
# 	BC Loss = 6.301570892333984
# 	Physics Loss = 278.13763427734375
# 	Training Loss = 285.1009521484375
# 	Relative L2 error (test) = 114.16829824447632
# Iteration Number = 630
# 	IC Loss = 0.6288999915122986
# 	BC Loss = 5.246305465698242
# 	Physics Loss = 149.5137939453125
# 	Training Loss = 155.3889923095703
# 	Relative L2 error (test) = 84.96920466423035
# Iteration Number = 640
# 	IC Loss = 0.5758772492408752
# 	BC Loss = 5.797956466674805
# 	Physics Loss = 77.32137298583984
# 	Training Loss = 83.69520568847656
# 	Relative L2 error (test) = 100.71307420730591
# Iteration Number = 650
# 	IC Loss = 0.5444272756576538
# 	BC Loss = 5.252979278564453
# 	Physics Loss = 106.7599105834961
# 	Training Loss = 112.55731964111328
# 	Relative L2 error (test) = 105.24578094482422
# Iteration Number = 660
# 	IC Loss = 0.411660373210907
# 	BC Loss = 3.8302769660949707
# 	Physics Loss = 105.59406280517578
# 	Training Loss = 109.83599853515625
# 	Relative L2 error (test) = 104.95245456695557
# Iteration Number = 670
# 	IC Loss = 0.6299423575401306
# 	BC Loss = 5.460977077484131
# 	Physics Loss = 285.37445068359375
# 	Training Loss = 291.4653625488281
# 	Relative L2 error (test) = 106.4461350440979
# Iteration Number = 680
# 	IC Loss = 0.39561915397644043
# 	BC Loss = 2.8624720573425293
# 	Physics Loss = 334.556396484375
# 	Training Loss = 337.8144836425781
# 	Relative L2 error (test) = 115.4102087020874
# Iteration Number = 690
# 	IC Loss = 0.6015085577964783
# 	BC Loss = 3.463797092437744
# 	Physics Loss = 287.4746398925781
# 	Training Loss = 291.5399475097656
# 	Relative L2 error (test) = 85.84753274917603
# Iteration Number = 700
# 	IC Loss = 1.0892753601074219
# 	BC Loss = 5.49857234954834
# 	Physics Loss = 298.8161315917969
# 	Training Loss = 305.40399169921875
# 	Relative L2 error (test) = 161.38256788253784
# Iteration Number = 710
# 	IC Loss = 0.3270875811576843
# 	BC Loss = 1.7026176452636719
# 	Physics Loss = 239.96994018554688
# 	Training Loss = 241.99964904785156
# 	Relative L2 error (test) = 63.15330266952515
# Iteration Number = 720
# 	IC Loss = 0.28878939151763916
# 	BC Loss = 1.4403002262115479
# 	Physics Loss = 153.50888061523438
# 	Training Loss = 155.23797607421875
# 	Relative L2 error (test) = 80.26660084724426
# Iteration Number = 730
# 	IC Loss = 0.30905377864837646
# 	BC Loss = 1.3530811071395874
# 	Physics Loss = 102.24943542480469
# 	Training Loss = 103.91156768798828
# 	Relative L2 error (test) = 65.28436541557312
# Iteration Number = 740
# 	IC Loss = 0.36501869559288025
# 	BC Loss = 3.058675765991211
# 	Physics Loss = 81.17420959472656
# 	Training Loss = 84.597900390625
# 	Relative L2 error (test) = 80.3337574005127
# Iteration Number = 750
# 	IC Loss = 0.22346588969230652
# 	BC Loss = 1.1468398571014404
# 	Physics Loss = 38.55118179321289
# 	Training Loss = 39.921485900878906
# 	Relative L2 error (test) = 83.57683420181274
# Iteration Number = 760
# 	IC Loss = 0.2419920116662979
# 	BC Loss = 2.012444496154785
# 	Physics Loss = 84.58988189697266
# 	Training Loss = 86.84431457519531
# 	Relative L2 error (test) = 99.6566116809845
# Iteration Number = 770
# 	IC Loss = 0.09373074024915695
# 	BC Loss = 2.491239070892334
# 	Physics Loss = 35.86151123046875
# 	Training Loss = 38.44647979736328
# 	Relative L2 error (test) = 77.41274237632751
# Iteration Number = 780
# 	IC Loss = 0.16392718255519867
# 	BC Loss = 2.144035816192627
# 	Physics Loss = 44.25008773803711
# 	Training Loss = 46.55805206298828
# 	Relative L2 error (test) = 63.4527862071991
# Iteration Number = 790
# 	IC Loss = 0.22412830591201782
# 	BC Loss = 2.7347779273986816
# 	Physics Loss = 23.68946647644043
# 	Training Loss = 26.648372650146484
# 	Relative L2 error (test) = 84.21147465705872
# Iteration Number = 800
# 	IC Loss = 0.1376982033252716
# 	BC Loss = 2.1308298110961914
# 	Physics Loss = 29.27381134033203
# 	Training Loss = 31.542339324951172
# 	Relative L2 error (test) = 44.465723633766174
# Iteration Number = 810
# 	IC Loss = 0.057939134538173676
# 	BC Loss = 2.5985589027404785
# 	Physics Loss = 37.23982238769531
# 	Training Loss = 39.89632034301758
# 	Relative L2 error (test) = 59.28153991699219
# Iteration Number = 820
# 	IC Loss = 0.1342921406030655
# 	BC Loss = 2.517691135406494
# 	Physics Loss = 27.600017547607422
# 	Training Loss = 30.25200080871582
# 	Relative L2 error (test) = 69.86643075942993
# Iteration Number = 830
# 	IC Loss = 0.13800741732120514
# 	BC Loss = 2.4943602085113525
# 	Physics Loss = 53.47783660888672
# 	Training Loss = 56.11020278930664
# 	Relative L2 error (test) = 49.08852577209473
# Iteration Number = 840
# 	IC Loss = 0.10502895712852478
# 	BC Loss = 2.4516708850860596
# 	Physics Loss = 39.84553146362305
# 	Training Loss = 42.40222930908203
# 	Relative L2 error (test) = 42.00950860977173
# Iteration Number = 850
# 	IC Loss = 0.11183592677116394
# 	BC Loss = 2.964439868927002
# 	Physics Loss = 25.811723709106445
# 	Training Loss = 28.88800048828125
# 	Relative L2 error (test) = 75.58683753013611
# Iteration Number = 860
# 	IC Loss = 0.11614907532930374
# 	BC Loss = 2.6026973724365234
# 	Physics Loss = 28.383888244628906
# 	Training Loss = 31.10273551940918
# 	Relative L2 error (test) = 38.35258483886719
# Iteration Number = 870
# 	IC Loss = 0.11874057352542877
# 	BC Loss = 2.618807077407837
# 	Physics Loss = 20.465662002563477
# 	Training Loss = 23.203208923339844
# 	Relative L2 error (test) = 76.69827938079834
# Iteration Number = 880
# 	IC Loss = 0.1027287170290947
# 	BC Loss = 2.4927661418914795
# 	Physics Loss = 27.286754608154297
# 	Training Loss = 29.88224983215332
# 	Relative L2 error (test) = 38.555169105529785
# Iteration Number = 890
# 	IC Loss = 0.11610974371433258
# 	BC Loss = 2.540433406829834
# 	Physics Loss = 50.509986877441406
# 	Training Loss = 53.16653060913086
# 	Relative L2 error (test) = 53.896766901016235
# Iteration Number = 900
# 	IC Loss = 0.11786943674087524
# 	BC Loss = 2.2731428146362305
# 	Physics Loss = 48.89643859863281
# 	Training Loss = 51.287452697753906
# 	Relative L2 error (test) = 59.695374965667725
# Iteration Number = 910
# 	IC Loss = 0.09656532108783722
# 	BC Loss = 2.1030945777893066
# 	Physics Loss = 65.1579818725586
# 	Training Loss = 67.3576431274414
# 	Relative L2 error (test) = 36.746224761009216
# Iteration Number = 920
# 	IC Loss = 0.12948919832706451
# 	BC Loss = 2.0368831157684326
# 	Physics Loss = 70.10787963867188
# 	Training Loss = 72.27425384521484
# 	Relative L2 error (test) = 52.19277739524841
# Iteration Number = 930
# 	IC Loss = 0.08082044869661331
# 	BC Loss = 2.1133899688720703
# 	Physics Loss = 65.70903778076172
# 	Training Loss = 67.90325164794922
# 	Relative L2 error (test) = 63.49892020225525
# Iteration Number = 940
# 	IC Loss = 0.15160734951496124
# 	BC Loss = 2.614729404449463
# 	Physics Loss = 9.282108306884766
# 	Training Loss = 12.048444747924805
# 	Relative L2 error (test) = 59.87387299537659
# Iteration Number = 950
# 	IC Loss = 0.17061524093151093
# 	BC Loss = 2.497873306274414
# 	Physics Loss = 36.5604248046875
# 	Training Loss = 39.228912353515625
# 	Relative L2 error (test) = 51.21158957481384
# Iteration Number = 960
# 	IC Loss = 0.2199610471725464
# 	BC Loss = 2.7147839069366455
# 	Physics Loss = 47.37673568725586
# 	Training Loss = 50.31148147583008
# 	Relative L2 error (test) = 62.07038164138794
# Iteration Number = 970
# 	IC Loss = 0.09171571582555771
# 	BC Loss = 2.212589979171753
# 	Physics Loss = 56.49978256225586
# 	Training Loss = 58.8040885925293
# 	Relative L2 error (test) = 37.286072969436646
# Iteration Number = 980
# 	IC Loss = 0.24804720282554626
# 	BC Loss = 3.2967922687530518
# 	Physics Loss = 38.96227264404297
# 	Training Loss = 42.507110595703125
# 	Relative L2 error (test) = 78.41031551361084
# Iteration Number = 990
# 	IC Loss = 0.07430632412433624
# 	BC Loss = 2.182140827178955
# 	Physics Loss = 79.65292358398438
# 	Training Loss = 81.90937042236328
# 	Relative L2 error (test) = 42.829903960227966
# Iteration Number = 1000
# 	IC Loss = 0.15319883823394775
# 	BC Loss = 1.7217696905136108
# 	Physics Loss = 526.5706176757812
# 	Training Loss = 528.445556640625
# 	Relative L2 error (test) = 60.32736301422119
# Iteration Number = 1010
# 	IC Loss = 0.18972089886665344
# 	BC Loss = 2.8508613109588623
# 	Physics Loss = 627.4133911132812
# 	Training Loss = 630.4539794921875
# 	Relative L2 error (test) = 63.64865303039551
# Iteration Number = 1020
# 	IC Loss = 0.8135497570037842
# 	BC Loss = 4.410669326782227
# 	Physics Loss = 398.1358947753906
# 	Training Loss = 403.360107421875
# 	Relative L2 error (test) = 202.38816738128662
# Iteration Number = 1030
# 	IC Loss = 1.0450066328048706
# 	BC Loss = 12.191018104553223
# 	Physics Loss = 281.8328857421875
# 	Training Loss = 295.06890869140625
# 	Relative L2 error (test) = 322.45352268218994
# Iteration Number = 1040
# 	IC Loss = 0.7199916839599609
# 	BC Loss = 3.776503086090088
# 	Physics Loss = 117.51920318603516
# 	Training Loss = 122.01570129394531
# 	Relative L2 error (test) = 83.4415853023529
# Iteration Number = 1050
# 	IC Loss = 0.5093252658843994
# 	BC Loss = 3.038407802581787
# 	Physics Loss = 221.98544311523438
# 	Training Loss = 225.53317260742188
# 	Relative L2 error (test) = 88.41193318367004
# Iteration Number = 1060
# 	IC Loss = 0.4694354236125946
# 	BC Loss = 2.184809684753418
# 	Physics Loss = 105.95088195800781
# 	Training Loss = 108.6051254272461
# 	Relative L2 error (test) = 94.7820782661438
# Iteration Number = 1070
# 	IC Loss = 0.3470364212989807
# 	BC Loss = 1.232067584991455
# 	Physics Loss = 65.7987060546875
# 	Training Loss = 67.3778076171875
# 	Relative L2 error (test) = 63.05071711540222
# Iteration Number = 1080
# 	IC Loss = 0.4028468132019043
# 	BC Loss = 0.9988207817077637
# 	Physics Loss = 57.02450942993164
# 	Training Loss = 58.426177978515625
# 	Relative L2 error (test) = 77.02542543411255
# Iteration Number = 1090
# 	IC Loss = 0.22613006830215454
# 	BC Loss = 2.762320041656494
# 	Physics Loss = 42.57368469238281
# 	Training Loss = 45.5621337890625
# 	Relative L2 error (test) = 105.35465478897095
# Iteration Number = 1100
# 	IC Loss = 0.13141056895256042
# 	BC Loss = 2.475494861602783
# 	Physics Loss = 33.22936248779297
# 	Training Loss = 35.83626937866211
# 	Relative L2 error (test) = 52.86514163017273
# Iteration Number = 1110
# 	IC Loss = 0.13629120588302612
# 	BC Loss = 3.152179718017578
# 	Physics Loss = 99.26168060302734
# 	Training Loss = 102.5501480102539
# 	Relative L2 error (test) = 51.372528076171875
# Iteration Number = 1120
# 	IC Loss = 0.14504733681678772
# 	BC Loss = 2.5203771591186523
# 	Physics Loss = 91.9353256225586
# 	Training Loss = 94.60075378417969
# 	Relative L2 error (test) = 47.32629060745239
# Iteration Number = 1130
# 	IC Loss = 0.11495973914861679
# 	BC Loss = 2.4829392433166504
# 	Physics Loss = 17.679540634155273
# 	Training Loss = 20.27743911743164
# 	Relative L2 error (test) = 64.33651447296143
# Iteration Number = 1140
# 	IC Loss = 0.08704029768705368
# 	BC Loss = 2.366607189178467
# 	Physics Loss = 27.651592254638672
# 	Training Loss = 30.105239868164062
# 	Relative L2 error (test) = 42.500439286231995
# Iteration Number = 1150
# 	IC Loss = 0.09824224561452866
# 	BC Loss = 2.0243701934814453
# 	Physics Loss = 18.480039596557617
# 	Training Loss = 20.602651596069336
# 	Relative L2 error (test) = 34.7504585981369
# Iteration Number = 1160
# 	IC Loss = 0.06541476398706436
# 	BC Loss = 1.667881727218628
# 	Physics Loss = 46.53645706176758
# 	Training Loss = 48.269752502441406
# 	Relative L2 error (test) = 36.774665117263794
# Iteration Number = 1170
# 	IC Loss = 0.11817680299282074
# 	BC Loss = 2.1937294006347656
# 	Physics Loss = 92.52383422851562
# 	Training Loss = 94.83573913574219
# 	Relative L2 error (test) = 48.38539659976959
# Iteration Number = 1180
# 	IC Loss = 0.06788323074579239
# 	BC Loss = 1.469247817993164
# 	Physics Loss = 14.92802906036377
# 	Training Loss = 16.465160369873047
# 	Relative L2 error (test) = 51.90834999084473
# Iteration Number = 1190
# 	IC Loss = 0.15190385282039642
# 	BC Loss = 1.7483049631118774
# 	Physics Loss = 19.208980560302734
# 	Training Loss = 21.109189987182617
# 	Relative L2 error (test) = 38.987189531326294
# Iteration Number = 1200
# 	IC Loss = 0.062248870730400085
# 	BC Loss = 1.3687148094177246
# 	Physics Loss = 10.149175643920898
# 	Training Loss = 11.58013916015625
# 	Relative L2 error (test) = 37.4962717294693
# Iteration Number = 1210
# 	IC Loss = 0.05532189831137657
# 	BC Loss = 1.624617099761963
# 	Physics Loss = 57.87090301513672
# 	Training Loss = 59.55084228515625
# 	Relative L2 error (test) = 34.98257100582123
# Iteration Number = 1220
# 	IC Loss = 0.052201077342033386
# 	BC Loss = 1.2584466934204102
# 	Physics Loss = 6.352503299713135
# 	Training Loss = 7.663150787353516
# 	Relative L2 error (test) = 35.44422090053558
# Iteration Number = 1230
# 	IC Loss = 0.04569263383746147
# 	BC Loss = 1.0729775428771973
# 	Physics Loss = 8.326367378234863
# 	Training Loss = 9.445037841796875
# 	Relative L2 error (test) = 33.54182243347168
# Iteration Number = 1240
# 	IC Loss = 0.04079616814851761
# 	BC Loss = 1.3864521980285645
# 	Physics Loss = 11.619080543518066
# 	Training Loss = 13.0463285446167
# 	Relative L2 error (test) = 48.65494668483734
# Iteration Number = 1250
# 	IC Loss = 0.061034537851810455
# 	BC Loss = 0.8113980293273926
# 	Physics Loss = 34.70682144165039
# 	Training Loss = 35.579254150390625
# 	Relative L2 error (test) = 38.27134966850281
# Iteration Number = 1260
# 	IC Loss = 0.0644589439034462
# 	BC Loss = 0.5187911987304688
# 	Physics Loss = 78.7877197265625
# 	Training Loss = 79.3709716796875
# 	Relative L2 error (test) = 46.44082486629486
# Iteration Number = 1270
# 	IC Loss = 0.12411902844905853
# 	BC Loss = 0.7766022086143494
# 	Physics Loss = 110.83020782470703
# 	Training Loss = 111.73092651367188
# 	Relative L2 error (test) = 75.17495155334473
# Iteration Number = 1280
# 	IC Loss = 0.03153546527028084
# 	BC Loss = 0.3996332883834839
# 	Physics Loss = 24.317686080932617
# 	Training Loss = 24.748855590820312
# 	Relative L2 error (test) = 34.537363052368164
# Iteration Number = 1290
# 	IC Loss = 0.021440794691443443
# 	BC Loss = 0.4685600996017456
# 	Physics Loss = 51.048160552978516
# 	Training Loss = 51.53816223144531
# 	Relative L2 error (test) = 42.94905066490173
# Iteration Number = 1300
# 	IC Loss = 0.05475396290421486
# 	BC Loss = 0.5788078308105469
# 	Physics Loss = 20.801166534423828
# 	Training Loss = 21.434728622436523
# 	Relative L2 error (test) = 34.80914235115051
# Iteration Number = 1310
# 	IC Loss = 0.033708907663822174
# 	BC Loss = 0.8498275279998779
# 	Physics Loss = 27.838350296020508
# 	Training Loss = 28.721887588500977
# 	Relative L2 error (test) = 77.62214541435242
# Iteration Number = 1320
# 	IC Loss = 0.08067051321268082
# 	BC Loss = 0.30667054653167725
# 	Physics Loss = 10.643980979919434
# 	Training Loss = 11.031322479248047
# 	Relative L2 error (test) = 43.15275549888611
# Iteration Number = 1330
# 	IC Loss = 0.020927000790834427
# 	BC Loss = 0.3119848370552063
# 	Physics Loss = 7.022576808929443
# 	Training Loss = 7.3554887771606445
# 	Relative L2 error (test) = 32.599395513534546
# Iteration Number = 1340
# 	IC Loss = 0.04437386617064476
# 	BC Loss = 0.21953149139881134
# 	Physics Loss = 14.444064140319824
# 	Training Loss = 14.707969665527344
# 	Relative L2 error (test) = 39.954933524131775
# Iteration Number = 1350
# 	IC Loss = 0.01628054305911064
# 	BC Loss = 0.4513733983039856
# 	Physics Loss = 50.14222717285156
# 	Training Loss = 50.60988235473633
# 	Relative L2 error (test) = 48.51117730140686
# Iteration Number = 1360
# 	IC Loss = 0.11823880672454834
# 	BC Loss = 0.5846273899078369
# 	Physics Loss = 67.19535064697266
# 	Training Loss = 67.8982162475586
# 	Relative L2 error (test) = 39.81600105762482
# Iteration Number = 1370
# 	IC Loss = 0.02230805903673172
# 	BC Loss = 0.44059914350509644
# 	Physics Loss = 15.756811141967773
# 	Training Loss = 16.21971893310547
# 	Relative L2 error (test) = 57.823628187179565
# Iteration Number = 1380
# 	IC Loss = 0.0321074016392231
# 	BC Loss = 0.31245413422584534
# 	Physics Loss = 30.770551681518555
# 	Training Loss = 31.1151123046875
# 	Relative L2 error (test) = 39.5956426858902
# Iteration Number = 1390
# 	IC Loss = 0.05285080522298813
# 	BC Loss = 0.3354634642601013
# 	Physics Loss = 76.2777099609375
# 	Training Loss = 76.66602325439453
# 	Relative L2 error (test) = 37.86139190196991
# Iteration Number = 1400
# 	IC Loss = 0.07172544300556183
# 	BC Loss = 0.24980194866657257
# 	Physics Loss = 47.247039794921875
# 	Training Loss = 47.568565368652344
# 	Relative L2 error (test) = 39.03672993183136
# Iteration Number = 1410
# 	IC Loss = 0.057902101427316666
# 	BC Loss = 0.3909749388694763
# 	Physics Loss = 17.306560516357422
# 	Training Loss = 17.75543785095215
# 	Relative L2 error (test) = 50.070154666900635
# Iteration Number = 1420
# 	IC Loss = 0.11135243624448776
# 	BC Loss = 0.15695202350616455
# 	Physics Loss = 433.93194580078125
# 	Training Loss = 434.20025634765625
# 	Relative L2 error (test) = 60.012298822402954
# Iteration Number = 1430
# 	IC Loss = 0.12396012246608734
# 	BC Loss = 0.501083254814148
# 	Physics Loss = 451.4620361328125
# 	Training Loss = 452.0870666503906
# 	Relative L2 error (test) = 54.268401861190796
# Iteration Number = 1440
# 	IC Loss = 0.1085289716720581
# 	BC Loss = 0.8025878071784973
# 	Physics Loss = 220.10501098632812
# 	Training Loss = 221.01612854003906
# 	Relative L2 error (test) = 76.39904022216797
# Iteration Number = 1450
# 	IC Loss = 0.3117748200893402
# 	BC Loss = 1.1809688806533813
# 	Physics Loss = 225.64151000976562
# 	Training Loss = 227.13424682617188
# 	Relative L2 error (test) = 92.70232319831848
# Iteration Number = 1460
# 	IC Loss = 0.1458306908607483
# 	BC Loss = 1.7164256572723389
# 	Physics Loss = 76.4334945678711
# 	Training Loss = 78.2957534790039
# 	Relative L2 error (test) = 58.8171660900116
# Iteration Number = 1470
# 	IC Loss = 0.16143469512462616
# 	BC Loss = 2.2990798950195312
# 	Physics Loss = 35.79489517211914
# 	Training Loss = 38.255409240722656
# 	Relative L2 error (test) = 39.751872420310974
# Iteration Number = 1480
# 	IC Loss = 0.062060873955488205
# 	BC Loss = 1.7286921739578247
# 	Physics Loss = 21.180652618408203
# 	Training Loss = 22.971405029296875
# 	Relative L2 error (test) = 56.37751817703247
# Iteration Number = 1490
# 	IC Loss = 0.10707172751426697
# 	BC Loss = 1.0070006847381592
# 	Physics Loss = 34.29671096801758
# 	Training Loss = 35.41078186035156
# 	Relative L2 error (test) = 40.252330899238586
# Iteration Number = 1500
# 	IC Loss = 0.013285811990499496
# 	BC Loss = 0.8996415138244629
# 	Physics Loss = 12.564018249511719
# 	Training Loss = 13.476945877075195
# 	Relative L2 error (test) = 49.543944001197815
# Iteration Number = 1510
# 	IC Loss = 0.08470061421394348
# 	BC Loss = 0.298064649105072
# 	Physics Loss = 18.961606979370117
# 	Training Loss = 19.344371795654297
# 	Relative L2 error (test) = 38.6370986700058
# Iteration Number = 1520
# 	IC Loss = 0.042253755033016205
# 	BC Loss = 0.9657379388809204
# 	Physics Loss = 48.78056335449219
# 	Training Loss = 49.78855514526367
# 	Relative L2 error (test) = 54.65843081474304
# Iteration Number = 1530
# 	IC Loss = 0.26490020751953125
# 	BC Loss = 1.1139228343963623
# 	Physics Loss = 63.9742546081543
# 	Training Loss = 65.35308074951172
# 	Relative L2 error (test) = 64.86732363700867
# Iteration Number = 1540
# 	IC Loss = 0.03154458478093147
# 	BC Loss = 0.6441973447799683
# 	Physics Loss = 28.515369415283203
# 	Training Loss = 29.191110610961914
# 	Relative L2 error (test) = 46.240147948265076
# Iteration Number = 1550
# 	IC Loss = 0.1112736389040947
# 	BC Loss = 0.49497586488723755
# 	Physics Loss = 48.376197814941406
# 	Training Loss = 48.98244857788086
# 	Relative L2 error (test) = 34.92099940776825
# Iteration Number = 1560
# 	IC Loss = 0.03936386853456497
# 	BC Loss = 0.8279261589050293
# 	Physics Loss = 14.297893524169922
# 	Training Loss = 15.165184020996094
# 	Relative L2 error (test) = 50.20408630371094
# Iteration Number = 1570
# 	IC Loss = 0.11781035363674164
# 	BC Loss = 0.4192699193954468
# 	Physics Loss = 11.757725715637207
# 	Training Loss = 12.294805526733398
# 	Relative L2 error (test) = 50.299036502838135
# Iteration Number = 1580
# 	IC Loss = 0.027838654816150665
# 	BC Loss = 0.5687849521636963
# 	Physics Loss = 45.039852142333984
# 	Training Loss = 45.636474609375
# 	Relative L2 error (test) = 52.687668800354004
# Iteration Number = 1590
# 	IC Loss = 0.02684747986495495
# 	BC Loss = 0.28718701004981995
# 	Physics Loss = 15.449098587036133
# 	Training Loss = 15.76313304901123
# 	Relative L2 error (test) = 34.8884642124176
# Iteration Number = 1600
# 	IC Loss = 0.04914649948477745
# 	BC Loss = 0.3072934150695801
# 	Physics Loss = 8.938088417053223
# 	Training Loss = 9.294528007507324
# 	Relative L2 error (test) = 49.445170164108276
# Iteration Number = 1610
# 	IC Loss = 0.03834608942270279
# 	BC Loss = 0.2259131669998169
# 	Physics Loss = 5.845397472381592
# 	Training Loss = 6.109656810760498
# 	Relative L2 error (test) = 39.187002182006836
# Iteration Number = 1620
# 	IC Loss = 0.08193125575780869
# 	BC Loss = 0.3352671265602112
# 	Physics Loss = 47.99912643432617
# 	Training Loss = 48.416324615478516
# 	Relative L2 error (test) = 50.55081844329834
# Iteration Number = 1630
# 	IC Loss = 0.09605886787176132
# 	BC Loss = 0.48019373416900635
# 	Physics Loss = 29.082788467407227
# 	Training Loss = 29.659040451049805
# 	Relative L2 error (test) = 51.598286628723145
# Iteration Number = 1640
# 	IC Loss = 0.03787136822938919
# 	BC Loss = 0.27830970287323
# 	Physics Loss = 20.662128448486328
# 	Training Loss = 20.978309631347656
# 	Relative L2 error (test) = 26.609987020492554
# Iteration Number = 1650
# 	IC Loss = 0.016457678750157356
# 	BC Loss = 0.37819722294807434
# 	Physics Loss = 5.604534149169922
# 	Training Loss = 5.9991888999938965
# 	Relative L2 error (test) = 32.1306049823761
# Iteration Number = 1660
# 	IC Loss = 0.045005667954683304
# 	BC Loss = 0.24019984900951385
# 	Physics Loss = 21.835933685302734
# 	Training Loss = 22.121139526367188
# 	Relative L2 error (test) = 38.59442174434662
# Iteration Number = 1670
# 	IC Loss = 0.030773745849728584
# 	BC Loss = 0.1815032958984375
# 	Physics Loss = 9.581238746643066
# 	Training Loss = 9.793516159057617
# 	Relative L2 error (test) = 30.177897214889526
# Iteration Number = 1680
# 	IC Loss = 0.02120950259268284
# 	BC Loss = 0.20032723248004913
# 	Physics Loss = 11.078917503356934
# 	Training Loss = 11.300454139709473
# 	Relative L2 error (test) = 29.098427295684814
# Iteration Number = 1690
# 	IC Loss = 0.0353555753827095
# 	BC Loss = 0.15096841752529144
# 	Physics Loss = 8.423062324523926
# 	Training Loss = 8.609386444091797
# 	Relative L2 error (test) = 24.564844369888306
# Iteration Number = 1700
# 	IC Loss = 0.017671560868620872
# 	BC Loss = 0.2705475986003876
# 	Physics Loss = 11.585485458374023
# 	Training Loss = 11.87370491027832
# 	Relative L2 error (test) = 33.59513580799103
# Iteration Number = 1710
# 	IC Loss = 0.0380355566740036
# 	BC Loss = 0.24863804876804352
# 	Physics Loss = 3.6362125873565674
# 	Training Loss = 3.9228861331939697
# 	Relative L2 error (test) = 28.424915671348572
# Iteration Number = 1720
# 	IC Loss = 0.04889770969748497
# 	BC Loss = 0.46494969725608826
# 	Physics Loss = 11.518033981323242
# 	Training Loss = 12.031881332397461
# 	Relative L2 error (test) = 40.547603368759155
# Iteration Number = 1730
# 	IC Loss = 0.04732909053564072
# 	BC Loss = 0.31184107065200806
# 	Physics Loss = 2.9761157035827637
# 	Training Loss = 3.3352859020233154
# 	Relative L2 error (test) = 32.61925280094147
# Iteration Number = 1740
# 	IC Loss = 0.018397828564047813
# 	BC Loss = 0.2555999755859375
# 	Physics Loss = 4.506466388702393
# 	Training Loss = 4.780464172363281
# 	Relative L2 error (test) = 24.12024736404419
# Iteration Number = 1750
# 	IC Loss = 0.02475099265575409
# 	BC Loss = 0.18776831030845642
# 	Physics Loss = 4.781741619110107
# 	Training Loss = 4.994260787963867
# 	Relative L2 error (test) = 25.586500763893127
# Iteration Number = 1760
# 	IC Loss = 0.013024195097386837
# 	BC Loss = 0.25346311926841736
# 	Physics Loss = 9.480210304260254
# 	Training Loss = 9.746697425842285
# 	Relative L2 error (test) = 28.100672364234924
# Iteration Number = 1770
# 	IC Loss = 0.037666596472263336
# 	BC Loss = 0.1412542462348938
# 	Physics Loss = 16.489824295043945
# 	Training Loss = 16.668745040893555
# 	Relative L2 error (test) = 27.192598581314087
# Iteration Number = 1780
# 	IC Loss = 0.009859706275165081
# 	BC Loss = 0.2677922248840332
# 	Physics Loss = 7.218357086181641
# 	Training Loss = 7.49600887298584
# 	Relative L2 error (test) = 35.19701957702637
# Iteration Number = 1790
# 	IC Loss = 0.01961129903793335
# 	BC Loss = 0.17052623629570007
# 	Physics Loss = 5.860238552093506
# 	Training Loss = 6.050375938415527
# 	Relative L2 error (test) = 26.672106981277466
# Iteration Number = 1800
# 	IC Loss = 0.03812754899263382
# 	BC Loss = 0.22236447036266327
# 	Physics Loss = 7.665159702301025
# 	Training Loss = 7.925651550292969
# 	Relative L2 error (test) = 28.93809974193573
# Iteration Number = 1810
# 	IC Loss = 0.022547177970409393
# 	BC Loss = 0.1567498743534088
# 	Physics Loss = 3.23073410987854
# 	Training Loss = 3.4100310802459717
# 	Relative L2 error (test) = 23.022422194480896
# Iteration Number = 1820
# 	IC Loss = 0.01080950628966093
# 	BC Loss = 0.1736089587211609
# 	Physics Loss = 3.2592966556549072
# 	Training Loss = 3.4437150955200195
# 	Relative L2 error (test) = 25.708705186843872
# Iteration Number = 1830
# 	IC Loss = 0.030204664915800095
# 	BC Loss = 0.14854088425636292
# 	Physics Loss = 29.941240310668945
# 	Training Loss = 30.119985580444336
# 	Relative L2 error (test) = 31.01557493209839
# Iteration Number = 1840
# 	IC Loss = 0.041844386607408524
# 	BC Loss = 0.18597137928009033
# 	Physics Loss = 75.83013153076172
# 	Training Loss = 76.05794525146484
# 	Relative L2 error (test) = 44.400715827941895
# Iteration Number = 1850
# 	IC Loss = 0.03847872093319893
# 	BC Loss = 0.3240480124950409
# 	Physics Loss = 18.826799392700195
# 	Training Loss = 19.1893253326416
# 	Relative L2 error (test) = 38.72118294239044
# Iteration Number = 1860
# 	IC Loss = 0.015531377866864204
# 	BC Loss = 0.2821153998374939
# 	Physics Loss = 9.271286010742188
# 	Training Loss = 9.56893253326416
# 	Relative L2 error (test) = 36.13822162151337
# Iteration Number = 1870
# 	IC Loss = 0.004530644975602627
# 	BC Loss = 0.3221968412399292
# 	Physics Loss = 7.21814489364624
# 	Training Loss = 7.544872283935547
# 	Relative L2 error (test) = 41.69670641422272
# Iteration Number = 1880
# 	IC Loss = 0.022550197318196297
# 	BC Loss = 0.3914303779602051
# 	Physics Loss = 5.9723711013793945
# 	Training Loss = 6.386351585388184
# 	Relative L2 error (test) = 33.001455664634705
# Iteration Number = 1890
# 	IC Loss = 0.04411813244223595
# 	BC Loss = 0.3084508180618286
# 	Physics Loss = 18.122177124023438
# 	Training Loss = 18.474746704101562
# 	Relative L2 error (test) = 45.14458179473877
# Iteration Number = 1900
# 	IC Loss = 0.0770043283700943
# 	BC Loss = 0.3406314253807068
# 	Physics Loss = 13.491183280944824
# 	Training Loss = 13.908819198608398
# 	Relative L2 error (test) = 49.03994798660278
# Iteration Number = 1910
# 	IC Loss = 0.12073684483766556
# 	BC Loss = 0.5477344989776611
# 	Physics Loss = 27.459524154663086
# 	Training Loss = 28.127994537353516
# 	Relative L2 error (test) = 54.78522777557373
# Iteration Number = 1920
# 	IC Loss = 0.028620470315217972
# 	BC Loss = 0.4751325249671936
# 	Physics Loss = 28.273242950439453
# 	Training Loss = 28.776996612548828
# 	Relative L2 error (test) = 32.700347900390625
# Iteration Number = 1930
# 	IC Loss = 0.0638200119137764
# 	BC Loss = 0.71578049659729
# 	Physics Loss = 19.29361343383789
# 	Training Loss = 20.073213577270508
# 	Relative L2 error (test) = 65.48144221305847
# Iteration Number = 1940
# 	IC Loss = 0.060963649302721024
# 	BC Loss = 0.33622148633003235
# 	Physics Loss = 5.407993316650391
# 	Training Loss = 5.805178642272949
# 	Relative L2 error (test) = 18.90796571969986
# Iteration Number = 1950
# 	IC Loss = 0.05551786348223686
# 	BC Loss = 0.3361407518386841
# 	Physics Loss = 13.403261184692383
# 	Training Loss = 13.794919967651367
# 	Relative L2 error (test) = 33.007729053497314
# Iteration Number = 1960
# 	IC Loss = 0.12494352459907532
# 	BC Loss = 0.7122178077697754
# 	Physics Loss = 4.955877304077148
# 	Training Loss = 5.793038368225098
# 	Relative L2 error (test) = 66.156005859375
# Iteration Number = 1970
# 	IC Loss = 0.029770880937576294
# 	BC Loss = 0.27808719873428345
# 	Physics Loss = 5.974603652954102
# 	Training Loss = 6.282461643218994
# 	Relative L2 error (test) = 20.137667655944824
# Iteration Number = 1980
# 	IC Loss = 0.01240598876029253
# 	BC Loss = 0.2561931610107422
# 	Physics Loss = 4.542665004730225
# 	Training Loss = 4.8112640380859375
# 	Relative L2 error (test) = 22.17831313610077
# Iteration Number = 1990
# 	IC Loss = 0.02604749985039234
# 	BC Loss = 0.16592854261398315
# 	Physics Loss = 3.2332048416137695
# 	Training Loss = 3.4251809120178223
# 	Relative L2 error (test) = 23.555004596710205
# Iteration Number = 2000
# 	IC Loss = 0.00970478355884552
# 	BC Loss = 0.20199179649353027
# 	Physics Loss = 2.272150993347168
# 	Training Loss = 2.4838476181030273
# 	Relative L2 error (test) = 20.618651807308197
# Iteration Number = 2010
# 	IC Loss = 0.019254237413406372
# 	BC Loss = 0.14784663915634155
# 	Physics Loss = 3.5866832733154297
# 	Training Loss = 3.7537841796875
# 	Relative L2 error (test) = 16.387321054935455
# Iteration Number = 2020
# 	IC Loss = 0.02589733898639679
# 	BC Loss = 0.1309642493724823
# 	Physics Loss = 2.780078172683716
# 	Training Loss = 2.9369397163391113
# 	Relative L2 error (test) = 19.141817092895508
# Iteration Number = 2030
# 	IC Loss = 0.329548180103302
# 	BC Loss = 1.689512014389038
# 	Physics Loss = 32.761356353759766
# 	Training Loss = 34.780418395996094
# 	Relative L2 error (test) = 104.84555959701538
# Iteration Number = 2040
# 	IC Loss = 0.22049884498119354
# 	BC Loss = 2.183013439178467
# 	Physics Loss = 22.984779357910156
# 	Training Loss = 25.38829231262207
# 	Relative L2 error (test) = 89.2811119556427
# Iteration Number = 2050
# 	IC Loss = 0.06555746495723724
# 	BC Loss = 0.7356904745101929
# 	Physics Loss = 29.807043075561523
# 	Training Loss = 30.608291625976562
# 	Relative L2 error (test) = 48.76246452331543
# Iteration Number = 2060
# 	IC Loss = 0.05058471858501434
# 	BC Loss = 0.48245561122894287
# 	Physics Loss = 42.80015182495117
# 	Training Loss = 43.33319091796875
# 	Relative L2 error (test) = 81.7712664604187
# Iteration Number = 2070
# 	IC Loss = 0.03159511089324951
# 	BC Loss = 0.32453155517578125
# 	Physics Loss = 43.70518112182617
# 	Training Loss = 44.06130599975586
# 	Relative L2 error (test) = 35.81562340259552
# Iteration Number = 2080
# 	IC Loss = 0.033398598432540894
# 	BC Loss = 0.4646727442741394
# 	Physics Loss = 9.472878456115723
# 	Training Loss = 9.97095012664795
# 	Relative L2 error (test) = 35.29362678527832
# Iteration Number = 2090
# 	IC Loss = 0.12054108828306198
# 	BC Loss = 0.47513914108276367
# 	Physics Loss = 26.266490936279297
# 	Training Loss = 26.862171173095703
# 	Relative L2 error (test) = 36.82987093925476
# Iteration Number = 2100
# 	IC Loss = 0.04338138550519943
# 	BC Loss = 0.6592753529548645
# 	Physics Loss = 185.82122802734375
# 	Training Loss = 186.5238800048828
# 	Relative L2 error (test) = 47.25470244884491
# Iteration Number = 2110
# 	IC Loss = 0.638180136680603
# 	BC Loss = 2.919767379760742
# 	Physics Loss = 243.88458251953125
# 	Training Loss = 247.44253540039062
# 	Relative L2 error (test) = 119.85911130905151
# Iteration Number = 2120
# 	IC Loss = 0.3208368420600891
# 	BC Loss = 2.7252631187438965
# 	Physics Loss = 73.40508270263672
# 	Training Loss = 76.45117950439453
# 	Relative L2 error (test) = 84.3597412109375
# Iteration Number = 2130
# 	IC Loss = 0.36176785826683044
# 	BC Loss = 1.4742692708969116
# 	Physics Loss = 40.26384735107422
# 	Training Loss = 42.099884033203125
# 	Relative L2 error (test) = 68.21553111076355
# Iteration Number = 2140
# 	IC Loss = 0.04160117357969284
# 	BC Loss = 1.0622410774230957
# 	Physics Loss = 13.288310050964355
# 	Training Loss = 14.392152786254883
# 	Relative L2 error (test) = 45.74208855628967
# Iteration Number = 2150
# 	IC Loss = 0.041425641626119614
# 	BC Loss = 0.56364905834198
# 	Physics Loss = 15.194631576538086
# 	Training Loss = 15.79970645904541
# 	Relative L2 error (test) = 24.341996014118195
# Iteration Number = 2160
# 	IC Loss = 0.023354429751634598
# 	BC Loss = 0.3211459517478943
# 	Physics Loss = 8.20083999633789
# 	Training Loss = 8.545340538024902
# 	Relative L2 error (test) = 20.365048944950104
# Iteration Number = 2170
# 	IC Loss = 0.041232988238334656
# 	BC Loss = 0.3438407778739929
# 	Physics Loss = 8.057093620300293
# 	Training Loss = 8.442167282104492
# 	Relative L2 error (test) = 15.82234501838684
# Iteration Number = 2180
# 	IC Loss = 0.03845972567796707
# 	BC Loss = 0.24960514903068542
# 	Physics Loss = 4.786815643310547
# 	Training Loss = 5.074880599975586
# 	Relative L2 error (test) = 25.241470336914062
# Iteration Number = 2190
# 	IC Loss = 0.01655360497534275
# 	BC Loss = 0.23109707236289978
# 	Physics Loss = 3.017472982406616
# 	Training Loss = 3.2651236057281494
# 	Relative L2 error (test) = 17.89918541908264
# Iteration Number = 2200
# 	IC Loss = 0.0251278355717659
# 	BC Loss = 0.18536949157714844
# 	Physics Loss = 4.030032157897949
# 	Training Loss = 4.240529537200928
# 	Relative L2 error (test) = 19.237487018108368
# Iteration Number = 2210
# 	IC Loss = 0.006591550540179014
# 	BC Loss = 0.2387792468070984
# 	Physics Loss = 6.071190357208252
# 	Training Loss = 6.316561222076416
# 	Relative L2 error (test) = 25.518721342086792
# Iteration Number = 2220
# 	IC Loss = 0.10643459856510162
# 	BC Loss = 0.8256651163101196
# 	Physics Loss = 18.114543914794922
# 	Training Loss = 19.04664421081543
# 	Relative L2 error (test) = 55.16803860664368
# Iteration Number = 2230
# 	IC Loss = 0.10588181763887405
# 	BC Loss = 0.8996336460113525
# 	Physics Loss = 18.07714080810547
# 	Training Loss = 19.082656860351562
# 	Relative L2 error (test) = 78.32616567611694
# Iteration Number = 2240
# 	IC Loss = 0.1944688856601715
# 	BC Loss = 0.8484990000724792
# 	Physics Loss = 16.639196395874023
# 	Training Loss = 17.682165145874023
# 	Relative L2 error (test) = 39.44782912731171
# Iteration Number = 2250
# 	IC Loss = 0.15435315668582916
# 	BC Loss = 0.931502103805542
# 	Physics Loss = 17.112367630004883
# 	Training Loss = 18.198223114013672
# 	Relative L2 error (test) = 56.43572211265564
# Iteration Number = 2260
# 	IC Loss = 0.07270009070634842
# 	BC Loss = 0.3592371344566345
# 	Physics Loss = 10.557527542114258
# 	Training Loss = 10.98946475982666
# 	Relative L2 error (test) = 41.2250816822052
# Iteration Number = 2270
# 	IC Loss = 0.028568144887685776
# 	BC Loss = 0.18234674632549286
# 	Physics Loss = 13.546344757080078
# 	Training Loss = 13.757259368896484
# 	Relative L2 error (test) = 31.578999757766724
# Iteration Number = 2280
# 	IC Loss = 0.021192945539951324
# 	BC Loss = 0.31426769495010376
# 	Physics Loss = 7.392400741577148
# 	Training Loss = 7.727861404418945
# 	Relative L2 error (test) = 30.29441237449646
# Iteration Number = 2290
# 	IC Loss = 0.013609624467790127
# 	BC Loss = 0.3275536298751831
# 	Physics Loss = 3.425323963165283
# 	Training Loss = 3.7664871215820312
# 	Relative L2 error (test) = 25.521183013916016
# Iteration Number = 2300
# 	IC Loss = 0.014944436959922314
# 	BC Loss = 0.44421830773353577
# 	Physics Loss = 11.09505844116211
# 	Training Loss = 11.554221153259277
# 	Relative L2 error (test) = 38.160330057144165
# Iteration Number = 2310
# 	IC Loss = 0.03387470170855522
# 	BC Loss = 0.5346545577049255
# 	Physics Loss = 22.50300407409668
# 	Training Loss = 23.071533203125
# 	Relative L2 error (test) = 34.51124131679535
# Iteration Number = 2320
# 	IC Loss = 0.02646731771528721
# 	BC Loss = 0.3507368564605713
# 	Physics Loss = 16.184450149536133
# ...
# 	IC Loss = 0.00978754460811615
# 	BC Loss = 0.09887062013149261
# 	Physics Loss = 2.888615846633911
# 	Training Loss = 2.9972739219665527
# 	Relative L2 error (test) = 9.361575543880463
# Iteration Number = 9170
# 	IC Loss = 0.009250028990209103
# 	BC Loss = 0.10030042380094528
# 	Physics Loss = 1.528641700744629
# 	Training Loss = 1.6381921768188477
# 	Relative L2 error (test) = 13.194765150547028
# Iteration Number = 9180
# 	IC Loss = 0.02240370772778988
# 	BC Loss = 0.060045093297958374
# 	Physics Loss = 2.987696886062622
# 	Training Loss = 3.070145606994629
# 	Relative L2 error (test) = 17.729829251766205
# Iteration Number = 9190
# 	IC Loss = 0.012759688310325146
# 	BC Loss = 0.07094702124595642
# 	Physics Loss = 3.365812063217163
# 	Training Loss = 3.4495186805725098
# 	Relative L2 error (test) = 16.119565069675446
# Iteration Number = 9200
# 	IC Loss = 0.008218362927436829
# 	BC Loss = 0.13042902946472168
# 	Physics Loss = 15.672987937927246
# 	Training Loss = 15.81163501739502
# 	Relative L2 error (test) = 30.96875548362732
# Iteration Number = 9210
# 	IC Loss = 0.01365305483341217
# 	BC Loss = 0.13456156849861145
# 	Physics Loss = 5.160183906555176
# 	Training Loss = 5.308398723602295
# 	Relative L2 error (test) = 25.37233829498291
# Iteration Number = 9220
# 	IC Loss = 0.03773413226008415
# 	BC Loss = 0.16400504112243652
# 	Physics Loss = 2.4689552783966064
# 	Training Loss = 2.670694351196289
# 	Relative L2 error (test) = 27.560946345329285
# Iteration Number = 9230
# 	IC Loss = 0.009568807668983936
# 	BC Loss = 0.07313837856054306
# 	Physics Loss = 2.7594971656799316
# 	Training Loss = 2.8422043323516846
# 	Relative L2 error (test) = 12.855872511863708
# Iteration Number = 9240
# 	IC Loss = 0.012098548002541065
# 	BC Loss = 0.10859151929616928
# 	Physics Loss = 1.279111385345459
# 	Training Loss = 1.39980149269104
# 	Relative L2 error (test) = 17.340226471424103
# Iteration Number = 9250
# 	IC Loss = 0.009797342121601105
# 	BC Loss = 0.09921760857105255
# 	Physics Loss = 0.7436673641204834
# 	Training Loss = 0.8526822924613953
# 	Relative L2 error (test) = 21.596910059452057
# Iteration Number = 9260
# 	IC Loss = 0.02068505808711052
# 	BC Loss = 0.06618228554725647
# 	Physics Loss = 0.9424662590026855
# 	Training Loss = 1.0293335914611816
# 	Relative L2 error (test) = 13.453266024589539
# Iteration Number = 9270
# 	IC Loss = 0.005559934768825769
# 	BC Loss = 0.06795231997966766
# 	Physics Loss = 9.886362075805664
# 	Training Loss = 9.959874153137207
# 	Relative L2 error (test) = 19.275912642478943
# Iteration Number = 9280
# 	IC Loss = 0.03806963190436363
# 	BC Loss = 0.1724017858505249
# 	Physics Loss = 12.338160514831543
# 	Training Loss = 12.54863166809082
# 	Relative L2 error (test) = 61.3090455532074
# Iteration Number = 9290
# 	IC Loss = 0.01909211464226246
# 	BC Loss = 0.17638343572616577
# 	Physics Loss = 8.089834213256836
# 	Training Loss = 8.285309791564941
# 	Relative L2 error (test) = 24.793969094753265
# Iteration Number = 9300
# 	IC Loss = 0.026527469977736473
# 	BC Loss = 0.16876760125160217
# 	Physics Loss = 2.5766305923461914
# 	Training Loss = 2.771925687789917
# 	Relative L2 error (test) = 35.25555729866028
# Iteration Number = 9310
# 	IC Loss = 0.06064162030816078
# 	BC Loss = 0.1961907595396042
# 	Physics Loss = 2.687272548675537
# 	Training Loss = 2.9441049098968506
# 	Relative L2 error (test) = 36.27880811691284
# Iteration Number = 9320
# 	IC Loss = 0.007645505480468273
# 	BC Loss = 0.04751437157392502
# 	Physics Loss = 6.661320209503174
# 	Training Loss = 6.716480255126953
# 	Relative L2 error (test) = 11.627314984798431
# Iteration Number = 9330
# 	IC Loss = 0.007201012223958969
# 	BC Loss = 0.0668477863073349
# 	Physics Loss = 3.1092233657836914
# 	Training Loss = 3.183272123336792
# 	Relative L2 error (test) = 18.22631061077118
# Iteration Number = 9340
# 	IC Loss = 0.0163457989692688
# 	BC Loss = 0.08562960475683212
# 	Physics Loss = 8.594295501708984
# 	Training Loss = 8.696270942687988
# 	Relative L2 error (test) = 42.096057534217834
# Iteration Number = 9350
# 	IC Loss = 0.013901801779866219
# 	BC Loss = 0.037870243191719055
# 	Physics Loss = 8.530658721923828
# 	Training Loss = 8.582430839538574
# 	Relative L2 error (test) = 14.824305474758148
# Iteration Number = 9360
# 	IC Loss = 0.023310929536819458
# 	BC Loss = 0.05869247764348984
# 	Physics Loss = 5.345246315002441
# 	Training Loss = 5.427249908447266
# 	Relative L2 error (test) = 18.011733889579773
# Iteration Number = 9370
# 	IC Loss = 0.01437528245151043
# 	BC Loss = 0.056811437010765076
# 	Physics Loss = 1.7697944641113281
# 	Training Loss = 1.8409812450408936
# 	Relative L2 error (test) = 12.17081993818283
# Iteration Number = 9380
# 	IC Loss = 0.019742950797080994
# 	BC Loss = 0.14769935607910156
# 	Physics Loss = 1.0366113185882568
# 	Training Loss = 1.2040536403656006
# 	Relative L2 error (test) = 25.13395845890045
# Iteration Number = 9390
# 	IC Loss = 0.6819152235984802
# 	BC Loss = 7.9576520919799805
# 	Physics Loss = 65.65453338623047
# 	Training Loss = 74.29409790039062
# 	Relative L2 error (test) = 187.61242628097534
# Iteration Number = 9400
# 	IC Loss = 0.23802469670772552
# 	BC Loss = 2.671478271484375
# 	Physics Loss = 25.111047744750977
# 	Training Loss = 28.020549774169922
# 	Relative L2 error (test) = 94.9802577495575
# Iteration Number = 9410
# 	IC Loss = 0.18223638832569122
# 	BC Loss = 1.1418046951293945
# 	Physics Loss = 44.23292541503906
# 	Training Loss = 45.55696487426758
# 	Relative L2 error (test) = 105.71788549423218
# Iteration Number = 9420
# 	IC Loss = 0.09162132441997528
# 	BC Loss = 0.19692495465278625
# 	Physics Loss = 32.57980728149414
# 	Training Loss = 32.86835479736328
# 	Relative L2 error (test) = 28.943225741386414
# Iteration Number = 9430
# 	IC Loss = 0.06907471269369125
# 	BC Loss = 0.6334629058837891
# 	Physics Loss = 12.860105514526367
# 	Training Loss = 13.562643051147461
# 	Relative L2 error (test) = 48.17429184913635
# Iteration Number = 9440
# 	IC Loss = 0.03912237659096718
# 	BC Loss = 0.6763187646865845
# 	Physics Loss = 5.698944568634033
# 	Training Loss = 6.414385795593262
# 	Relative L2 error (test) = 50.132936239242554
# Iteration Number = 9450
# 	IC Loss = 0.052732162177562714
# 	BC Loss = 0.24413526058197021
# 	Physics Loss = 5.573751926422119
# 	Training Loss = 5.870619297027588
# 	Relative L2 error (test) = 26.31048560142517
# Iteration Number = 9460
# 	IC Loss = 0.038231443613767624
# 	BC Loss = 0.4007043242454529
# 	Physics Loss = 7.6759538650512695
# 	Training Loss = 8.114889144897461
# 	Relative L2 error (test) = 31.56234622001648
# Iteration Number = 9470
# 	IC Loss = 0.07758353650569916
# 	BC Loss = 0.459140419960022
# 	Physics Loss = 3.1481754779815674
# 	Training Loss = 3.68489933013916
# 	Relative L2 error (test) = 37.05872893333435
# Iteration Number = 9480
# 	IC Loss = 0.06101492792367935
# 	BC Loss = 1.226278305053711
# 	Physics Loss = 6.981465816497803
# 	Training Loss = 8.268758773803711
# 	Relative L2 error (test) = 77.90394425392151
# Iteration Number = 9490
# 	IC Loss = 0.07151475548744202
# 	BC Loss = 0.7030259370803833
# 	Physics Loss = 4.862628936767578
# 	Training Loss = 5.63716983795166
# 	Relative L2 error (test) = 26.20607614517212
# Iteration Number = 9500
# 	IC Loss = 0.08986029028892517
# 	BC Loss = 1.7118496894836426
# 	Physics Loss = 23.184310913085938
# 	Training Loss = 24.986021041870117
# 	Relative L2 error (test) = 68.20023655891418
# Iteration Number = 9510
# 	IC Loss = 0.08323880285024643
# 	BC Loss = 0.7035259008407593
# 	Physics Loss = 12.91598892211914
# 	Training Loss = 13.702754020690918
# 	Relative L2 error (test) = 53.53459119796753
# Iteration Number = 9520
# 	IC Loss = 0.03118668682873249
# 	BC Loss = 0.5657500624656677
# 	Physics Loss = 12.88237476348877
# 	Training Loss = 13.4793119430542
# 	Relative L2 error (test) = 15.162953734397888
# Iteration Number = 9530
# 	IC Loss = 0.021578991785645485
# 	BC Loss = 0.142368346452713
# 	Physics Loss = 9.91202163696289
# 	Training Loss = 10.075968742370605
# 	Relative L2 error (test) = 21.717770397663116
# Iteration Number = 9540
# 	IC Loss = 0.03115982562303543
# 	BC Loss = 0.1695987582206726
# 	Physics Loss = 2.0336718559265137
# 	Training Loss = 2.2344303131103516
# 	Relative L2 error (test) = 20.887351036071777
# Iteration Number = 9550
# 	IC Loss = 0.07172360271215439
# 	BC Loss = 0.2889847457408905
# 	Physics Loss = 4.467753887176514
# 	Training Loss = 4.82846212387085
# 	Relative L2 error (test) = 48.867425322532654
# Iteration Number = 9560
# 	IC Loss = 0.03662692755460739
# 	BC Loss = 0.30198919773101807
# 	Physics Loss = 3.981473684310913
# 	Training Loss = 4.320089817047119
# 	Relative L2 error (test) = 25.662770867347717
# Iteration Number = 9570
# 	IC Loss = 0.05418383702635765
# 	BC Loss = 0.43555325269699097
# 	Physics Loss = 3.915799140930176
# 	Training Loss = 4.40553617477417
# 	Relative L2 error (test) = 13.112449645996094
# Iteration Number = 9580
# 	IC Loss = 0.03686907887458801
# 	BC Loss = 0.12400542199611664
# 	Physics Loss = 6.098103046417236
# 	Training Loss = 6.25897741317749
# 	Relative L2 error (test) = 26.271674036979675
# Iteration Number = 9590
# 	IC Loss = 0.02320905774831772
# 	BC Loss = 0.14587756991386414
# 	Physics Loss = 3.338925361633301
# 	Training Loss = 3.508012056350708
# 	Relative L2 error (test) = 23.221538960933685
# Iteration Number = 9600
# 	IC Loss = 0.024670960381627083
# 	BC Loss = 0.08156053721904755
# 	Physics Loss = 2.758352756500244
# 	Training Loss = 2.86458420753479
# 	Relative L2 error (test) = 32.47062563896179
# Iteration Number = 9610
# 	IC Loss = 0.02563425712287426
# 	BC Loss = 0.15444731712341309
# 	Physics Loss = 2.365962505340576
# 	Training Loss = 2.546044111251831
# 	Relative L2 error (test) = 19.390979409217834
# Iteration Number = 9620
# 	IC Loss = 0.020682107657194138
# 	BC Loss = 0.10876546800136566
# 	Physics Loss = 3.2286839485168457
# 	Training Loss = 3.3581314086914062
# 	Relative L2 error (test) = 17.182902991771698
# Iteration Number = 9630
# 	IC Loss = 0.03798266127705574
# 	BC Loss = 0.30338579416275024
# 	Physics Loss = 1.6392744779586792
# 	Training Loss = 1.9806429147720337
# 	Relative L2 error (test) = 35.218775272369385
# Iteration Number = 9640
# 	IC Loss = 0.021907418966293335
# 	BC Loss = 0.16056577861309052
# 	Physics Loss = 1.330115795135498
# 	Training Loss = 1.5125889778137207
# 	Relative L2 error (test) = 12.58111447095871
# Iteration Number = 9650
# 	IC Loss = 0.01612989604473114
# 	BC Loss = 0.13562491536140442
# 	Physics Loss = 0.7552121877670288
# 	Training Loss = 0.9069669842720032
# 	Relative L2 error (test) = 17.5301656126976
# Iteration Number = 9660
# 	IC Loss = 0.02802816964685917
# 	BC Loss = 0.10050135850906372
# 	Physics Loss = 0.6135473847389221
# 	Training Loss = 0.7420769333839417
# 	Relative L2 error (test) = 20.5452561378479
# Iteration Number = 9670
# 	IC Loss = 0.02560495398938656
# 	BC Loss = 0.11259947717189789
# 	Physics Loss = 10.862081527709961
# 	Training Loss = 11.000286102294922
# 	Relative L2 error (test) = 37.8388375043869
# Iteration Number = 9680
# 	IC Loss = 0.02204553596675396
# 	BC Loss = 0.18663185834884644
# 	Physics Loss = 4.812312602996826
# 	Training Loss = 5.020989894866943
# 	Relative L2 error (test) = 19.889597594738007
# Iteration Number = 9690
# 	IC Loss = 0.029910506680607796
# 	BC Loss = 0.09635695815086365
# 	Physics Loss = 6.268734455108643
# 	Training Loss = 6.3950018882751465
# 	Relative L2 error (test) = 49.40052628517151
# Iteration Number = 9700
# 	IC Loss = 0.13956819474697113
# 	BC Loss = 0.4120238423347473
# 	Physics Loss = 8.881287574768066
# 	Training Loss = 9.432879447937012
# 	Relative L2 error (test) = 46.97834253311157
# Iteration Number = 9710
# 	IC Loss = 0.19843004643917084
# 	BC Loss = 1.4686641693115234
# 	Physics Loss = 11.309459686279297
# 	Training Loss = 12.976553916931152
# 	Relative L2 error (test) = 43.45487356185913
# Iteration Number = 9720
# 	IC Loss = 0.05745440348982811
# 	BC Loss = 0.3347069025039673
# 	Physics Loss = 9.63518238067627
# 	Training Loss = 10.02734375
# 	Relative L2 error (test) = 32.68722891807556
# Iteration Number = 9730
# 	IC Loss = 0.09404302388429642
# 	BC Loss = 0.6385783553123474
# 	Physics Loss = 4.739997863769531
# 	Training Loss = 5.47261905670166
# 	Relative L2 error (test) = 28.100812435150146
# Iteration Number = 9740
# 	IC Loss = 0.9598930478096008
# 	BC Loss = 2.626551628112793
# 	Physics Loss = 37.47007751464844
# 	Training Loss = 41.056522369384766
# 	Relative L2 error (test) = 66.7112410068512
# Iteration Number = 9750
# 	IC Loss = 0.0932571217417717
# 	BC Loss = 0.7517760992050171
# 	Physics Loss = 13.528656005859375
# 	Training Loss = 14.373689651489258
# 	Relative L2 error (test) = 43.844789266586304
# Iteration Number = 9760
# 	IC Loss = 0.14858680963516235
# 	BC Loss = 0.34404605627059937
# 	Physics Loss = 21.986055374145508
# 	Training Loss = 22.478687286376953
# 	Relative L2 error (test) = 34.079357981681824
# Iteration Number = 9770
# 	IC Loss = 0.3681495487689972
# 	BC Loss = 1.3746397495269775
# 	Physics Loss = 11.958874702453613
# 	Training Loss = 13.701663970947266
# 	Relative L2 error (test) = 45.99553942680359
# Iteration Number = 9780
# 	IC Loss = 0.05541115254163742
# 	BC Loss = 0.7594528198242188
# 	Physics Loss = 18.971521377563477
# 	Training Loss = 19.78638458251953
# 	Relative L2 error (test) = 60.57455539703369
# Iteration Number = 9790
# 	IC Loss = 0.040760185569524765
# 	BC Loss = 0.6006662845611572
# 	Physics Loss = 15.575133323669434
# 	Training Loss = 16.21656036376953
# 	Relative L2 error (test) = 60.8862578868866
# Iteration Number = 9800
# 	IC Loss = 0.026286981999874115
# 	BC Loss = 0.17170120775699615
# 	Physics Loss = 5.22192907333374
# 	Training Loss = 5.419917106628418
# 	Relative L2 error (test) = 55.6998610496521
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 563
#     546 for i in repeat:
#     547     pinn = PINN(  k = k,
#     548                   c = c,
#     549                   t= T,
#    (...)
#     560                   model_name = "../models/" + args.model_name + ".model_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i),
#     561                   display_freq = args.display_freq, samp = args.method )
# --> 563     Losses_train, Losses_rel_l2 = pinn.Train(args.epochs, weights = (1, 1, 1)) # initial, boundary, residual
#     565     torch.save(Losses_train, "../models/" + args.model_name + ".loss_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
#     566     torch.save(Losses_rel_l2, "../models/" + args.model_name + ".rel_l2_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
#
# Cell In[4], line 467, in PINN.Train(self, n_iters, weights)
#     463 Total_PhysicsLoss = Total_PhysicsLoss + loss1
#     464 Total_Loss = weights[0]*Total_ICLoss + weights[1]*Total_BCLoss\
#     465             + weights[2]*Total_PhysicsLoss
# --> 467 Total_Loss.backward()
#     468 optimizer.step()
#     469 scheduler.step()
#
# File ~/anaconda3/envs/dj24/lib/python3.12/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/anaconda3/envs/dj24/lib/python3.12/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/anaconda3/envs/dj24/lib/python3.12/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:
