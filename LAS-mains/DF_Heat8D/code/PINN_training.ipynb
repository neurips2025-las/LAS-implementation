# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader 
import numpy as np
from scipy import io
import matplotlib.pyplot as plt
import argparse
import os
import copy
import time


def inital_soln(xt_grid):
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = torch.cos((40/d)*x_grid.sum(axis = 1)).reshape(-1,1)

    return u.flatten()


def exact_soln(xt_grid):
    
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = torch.cos((40/d)*x_grid.sum(axis = 1)).reshape(-1,1)*torch.exp(-t)
    
    return u.flatten()


def f_function(xt_grid):
    
    x_grid = xt_grid[:,:-1]
    t = xt_grid[:,-1].reshape(-1,1)

    d = x_grid.shape[1]
    u = (1600/d-1)*torch.cos((40/d)*x_grid.sum(axis = 1)).reshape(-1,1)*torch.exp(-t)
    
    return u.flatten()


def stacked_grid(*args):
    # Generate meshgrid dynamically
    grids = torch.meshgrid(*args, indexing='ij')
    # Flatten and stack the grids into a single tensor
    stacked = torch.hstack([g.flatten()[:, None] for g in grids])
    return stacked.float()


def cal_domain_grad(model, XTGrid, device):
    Loss = torch.nn.MSELoss(reduction='mean')

    XTGrid = XTGrid.requires_grad_(True).to(device)
    u = model.forward(XTGrid)
    
    # Compute first derivatives
    u_grad = torch.autograd.grad(outputs=u, 
                                 inputs=XTGrid, 
                                 grad_outputs=torch.ones_like(u).to(device), 
                                 create_graph=True, 
                                 allow_unused=True)[0]

    # Compute second derivatives for each spatial dimension
    u_laplacian = torch.zeros_like(u[:,0], device=device)
    for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
        ux = u_grad[:, d]
        uxx = torch.autograd.grad(outputs=ux, 
                                  inputs=XTGrid, 
                                  grad_outputs=torch.ones_like(ux).to(device), 
                                  create_graph=True, 
                                  allow_unused=True)[0][:, d]
        u_laplacian += uxx
    f = f_function(XTGrid)
    # Time derivative
    ut = u_grad[:, -1]  # Assuming last dimension is time

    # PDE residual loss (generalized heat/diffusion equation)
    lossf = Loss(ut-u_laplacian, f.flatten())

    # Compute gradient of loss function w.r.t. inputs (for adaptivity or error estimation)
    grad = torch.autograd.grad(outputs=lossf, 
                               inputs=XTGrid, 
                               grad_outputs=torch.ones_like(lossf).to(device),
                               create_graph=True,
                               allow_unused=True)[0]
    
    return grad


class RADSampler():
    def __init__(self, Nf, device, k, c, dim = 1):    
        self.device = device
        self.k = k
        self.c = c
        self.Nf = Nf
        self.dense_Nf = Nf*1
        self.dim = dim
        
    def update(self, model):
        
        x_new = torch.zeros(self.dense_Nf, self.dim, dtype = torch.float32, device=self.device).uniform_(-1, 1)
        t_new = torch.zeros(self.dense_Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
        x_t_new = torch.concatenate((x_new,t_new), axis = 1)
        
        XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True) 
        XTGrid = XTGrid.to(self.device)

        XTGrid = XTGrid.requires_grad_(True).to(self.device)
        
        u = model.forward(XTGrid)
        
        u_grad = torch.autograd.grad(outputs=u, 
                                     inputs=XTGrid, 
                                     grad_outputs=torch.ones_like(u).to(device), 
                                     create_graph=True, 
                                     allow_unused=True)[0]
    
        u_laplacian = torch.zeros_like(u[:,0], device=device)
        for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
            ux = u_grad[:, d]
            uxx = torch.autograd.grad(outputs=ux, 
                                      inputs=XTGrid, 
                                      grad_outputs=torch.ones_like(ux).to(device), 
                                      create_graph=True, 
                                      allow_unused=True)[0][:, d]
            u_laplacian += uxx
            
        f = f_function(XTGrid)
        ut = u_grad[:, -1]  
    
        err = torch.abs((ut-u_laplacian-f.flatten()))
        err = (err**self.k)/((err**self.k).mean())+self.c
        err_norm = err/(err.sum())
        
        indice = torch.multinomial(err_norm, self.Nf, replacement = True)
        XTGrid = XTGrid[indice]
        self.XTGrid = XTGrid
        
class LASSampler():
    def __init__(self, Nf, fixed_uniform, device, L_iter = 1, beta = 0.2, tau = 0.002):
        self.Nf = Nf
        self.device = device
        self.cnt = 0
        self.beta = beta
        self.tau = tau
        self.L_iter = L_iter
        self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)

    def update(self, phy_lf, model):

        x_data = self.XTGrid
        samples = x_data.clone().detach().requires_grad_(True)
        
        for t in range(1, self.L_iter + 1):
            grad = phy_lf(model, samples, self.device)
            scaler = torch.sqrt(torch.sum((grad+1e-16)**2, axis = 1)).reshape(-1,1)
            grad = grad/scaler

            with torch.no_grad():
                samples = samples + self.tau * grad + self.beta*torch.sqrt(torch.tensor(2 * self.tau, device=self.device)) * torch.randn(samples.shape, device=self.device)
                for i in range(samples.shape[1]):
                    if i < int(samples.shape[1]-1):
                        samples[:, i] = torch.clamp(samples[:, i], min=-1, max=1) 
                    else:
                        samples[:, i] = torch.clamp(samples[:, i], min=0, max=1) 
                        
            samples = samples.clone().detach().requires_grad_(True)
        self.XTGrid = samples.detach()

class L_INFSampler():
    def __init__(self, Nf, device, step_size = 0.05 , n_iter = 20, dim = 1):

        self.Nf = Nf
        self.device = device
        self.step_size = step_size
        self.n_iter = n_iter
        self.dim = dim

    def update(self, phy_lf, model):

        x_new = torch.zeros(self.Nf, self.dim, dtype = torch.float32, device=self.device).uniform_(-1, 1)
        t_new = torch.zeros(self.Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
        x_t_new = torch.concatenate((x_new,t_new), axis = 1)
        self.XTGrid = x_t_new
            
        x_data = self.XTGrid
        samples = x_data.clone().detach().requires_grad_(True)
    
        for t in range(1, self.n_iter + 1):
            grad = phy_lf(model, samples, self.device)
            with torch.no_grad():
                samples = samples + self.step_size * torch.sign(grad)
                for i in range(samples.shape[1]):
                    if i < int(samples.shape[1]-1):
                        samples[:, i] = torch.clamp(samples[:, i], min=-1, max=1)
                    else:
                        samples[:, i] = torch.clamp(samples[:, i], min=0, max=1)
                        
            samples = samples.clone().detach().requires_grad_(True)
        self.XTGrid = samples.detach()           


class R3Sampler(nn.Module):
    def __init__(self,Nf, fixed_uniform, device):
        super(R3Sampler, self).__init__()
        self.Nf = Nf
        self.device = device
        self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
    
    def update(self, loss_aver, loss_ele):
        with torch.no_grad():
            cho_i = loss_ele > loss_aver
            cho_i = cho_i.to('cpu')
            self.XTGrid = self.XTGrid[cho_i].detach()
            need_n_sample = self.Nf-self.XTGrid.shape[0]
            x_new = torch.zeros(need_n_sample, self.XTGrid.shape[1]-1, dtype = torch.float32, device=self.device).uniform_(-1, 1)
            t_new = torch.zeros(need_n_sample, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
            x_t_new = torch.concatenate((x_new,t_new), axis = 1)
            self.XTGrid = torch.concatenate((self.XTGrid, x_t_new), axis = 0)
            self.XTGrid = torch.tensor(self.XTGrid, dtype = torch.float32, device=self.device, requires_grad=True)
    
class PINN(nn.Module):
    def __init__(self,k , c , t, exact_XYT, exact_u, LBs, UBs, Layers, N0, Nb, Nf, 
                 Activation = nn.Tanh(), 
                 model_name = "PINN.model", device = 'cpu',
                  display_freq = 100, samp = 'fixed' ):
        
        super(PINN, self).__init__()
        
        
        self.LBs = torch.tensor(LBs, dtype=torch.float32)
        self.UBs = torch.tensor(UBs, dtype=torch.float32)
        
        self.Layers = Layers
        self.in_dim  = Layers[0]
        self.out_dim = Layers[-1]
        self.Activation = Activation
        
        self.device = device
        
        x_init = torch.zeros(Nf, len(self.LBs) - 1, dtype = torch.float32, device=self.device).uniform_(0, UBs[0])
        t_init = torch.zeros(Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, UBs[-1])
        x_t_init = torch.concatenate((x_init,t_init), axis = 1)
        self.fixed_uniform = torch.tensor(x_t_init, dtype = torch.float32, device=self.device, requires_grad=True)
        
        self.N0 = N0
        self.Nb = Nb
        self.Nf = Nf
        
        self.t = t
        self.exact_XYT = exact_XYT
        self.exact_u = exact_u.reshape(-1,1)
        
        self.XT0, self.u0  = self.InitialCondition(self.N0, self.LBs, self.UBs)
        self.boundary_set = self.BoundaryCondition(self.Nb, self.LBs, self.UBs)
        
        self.XT0 = self.XT0.to(device)
        self.u0 = self.u0.to(device) 
        
        self._nn = self.build_model()
        self._nn.to(self.device)
        self.Loss = torch.nn.MSELoss(reduction='mean')
        
        self.model_name = model_name
        self.display_freq = display_freq
        
        self.k = k
        self.c = c
        self.X_star = self.exact_XYT
        self.method = samp
        
        self.r3_sample = R3Sampler(self.Nf, self.fixed_uniform, device)
        self.las = LASSampler(self.Nf, fixed_uniform=self.fixed_uniform, device=self.device, L_iter = 1, beta = 0.2, tau=1e-2)
        self.l_inf = L_INFSampler(self.Nf, device=self.device, step_size = 0.05 , n_iter = 20, dim = len(self.LBs) - 1)
        self.rad = RADSampler(Nf = self.Nf, device=self.device, k = self.k, c=self.c, dim = len(self.LBs) - 1)
        
    
    def build_model(self):
        Seq = nn.Sequential()
        for ii in range(len(self.Layers)-1):
            this_module = nn.Linear(self.Layers[ii], self.Layers[ii+1])
            nn.init.xavier_normal_(this_module.weight)
            Seq.add_module("Linear" + str(ii), this_module)
            if not ii == len(self.Layers)-2:
                Seq.add_module("Activation" + str(ii), self.Activation)
        return Seq
        
    def forward(self, x):
        return self._nn.forward(x.to(self.device)).reshape(-1)

    def InitialCondition(self, N0, LB, UB):
        n_per_dim = int(np.round(N0**(1/len(LB[:-1]))))
#         n_per_dim = int(np.round(np.sqrt(N0)))
        nodes = []
        for i in range(len(LB)-1):
            X = torch.linspace(LB[i], UB[i], n_per_dim).float()
            nodes.append(X)
            
        t_in = torch.tensor([LB[-1]]).float()
        nodes.append(t_in)
        
        XT_in = stacked_grid(*nodes)
        u0 = inital_soln(XT_in)
        return XT_in, u0

    def ICLoss(self):
        uv0_pred = self.forward(self.XT0)
        loss = self.Loss(uv0_pred, self.u0.to(self.device))
        return loss 

    def BoundaryPoints(self, nb, boundary_index, LBs, UBs, boundary_type):
        """
        Generalized function to get boundary points in an N-dimensional space.
        - `boundary_index`: Index of the dimension where the boundary is applied.
        - `nb`: Number of boundary points.
        - `LBs`, `UBs`: Lower and upper bounds for each dimension.
        - `boundary_type`: 'lower' for the lower boundary, 'upper' for the upper boundary.
        """
        n_per_dim = int(np.round(nb ** (1 / (len(LBs) - 1))))  # Distribute points across remaining dimensions
        
        # Create grid ranges for each dimension
        grid_ranges = []
        for i in range(len(LBs)  - 1):  # Excluding time
            if i == boundary_index:
                if boundary_type == 'lower':
                    grid_ranges.append(torch.tensor([LBs[i]]).float().to(self.device))  # Fixed lower boundary position
                else:
                    grid_ranges.append(torch.tensor([UBs[i]]).float().to(self.device))  # Fixed upper boundary position
            else:
                grid_ranges.append(torch.linspace(LBs[i], UBs[i], n_per_dim).float().to(self.device))

        # Time dimension (last dimension)
        grid_ranges.append(torch.linspace(LBs[-1], UBs[-1], nb).float().to(self.device))

        return stacked_grid(*grid_ranges)

    
    def BoundaryCondition(self, Nb, LBs, UBs):
        """
        Generalized function to get all boundary conditions in an N-dimensional space.
        - `Nb`: Total number of boundary points.
        - `LBs`, `UBs`: Lower and upper bounds for each dimension.
        """
        nb = int(np.round(Nb / (2 * (len(LBs) - 1))))  # Divide points across boundary faces
        boundary_sets = []
        
        for d in range(len(LBs) - 1):  # Iterate over all spatial dimensions
            lower_boundary = self.BoundaryPoints(nb, d, LBs, UBs, 'lower')
            upper_boundary = self.BoundaryPoints(nb, d, LBs, UBs, 'upper')
            boundary_sets.append((lower_boundary, upper_boundary))

        return boundary_sets  # Returns pairs of boundaries per dimension

    def BCLoss(self):
        """
        Compute boundary condition loss given a model, exact solution, and loss function.
        """
        total_loss = 0
        for lower, upper in self.boundary_set:
            U_L, U_R = self.forward(lower), self.forward(upper)
            UL_exact, UR_exact = exact_soln(lower), exact_soln(upper)

            total_loss += self.Loss(U_L, UL_exact) + self.Loss(U_R, UR_exact)
        
        return total_loss
    
    def PhysicsLoss(self, XTGrid):
        XTGrid = XTGrid.requires_grad_(True).to(device)
        u = self.forward(XTGrid)

        # Compute first derivatives
        u_grad = torch.autograd.grad(outputs=u, 
                                     inputs=XTGrid, 
                                     grad_outputs=torch.ones_like(u).to(device), 
                                     create_graph=True, 
                                     allow_unused=True)[0]

        # Compute second derivatives for each spatial dimension
        u_laplacian = torch.zeros_like(u, device=device)
        for d in range(XTGrid.shape[1] - 1):  # Assuming last dim is time
            ux = u_grad[:, d]
            uxx = torch.autograd.grad(outputs=ux, 
                                      inputs=XTGrid, 
                                      grad_outputs=torch.ones_like(ux).to(device), 
                                      create_graph=True, 
                                      allow_unused=True)[0][:, d]
            u_laplacian += uxx
            
        f = f_function(XTGrid)

        # Time derivative
        ut = u_grad[:, -1]  # Assuming last dimension is time

        loss2 = (u_laplacian - ut+f.flatten())**2
        loss1 = loss2.mean()

        return loss1, loss2 

    def Train(self, n_iters, weights=(1.0,1.0,1.0)):
        params = list(self.parameters())
        optimizer = optim.Adam(params, lr=1e-3)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 5000, gamma=0.9, last_epoch=-1)
        min_loss = 999999.0
        Training_Losses = [-10]*n_iters
        Test_Losses = []
        rel_error = [-10]*(1+n_iters//10)
        
        for jj in range(n_iters):
            Total_ICLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            Total_BCLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            Total_PhysicsLoss = torch.tensor(0.0, dtype = torch.float32, device=self.device, requires_grad = True)
            
            Total_ICLoss = Total_ICLoss + self.ICLoss()
            Total_BCLoss = Total_BCLoss + self.BCLoss()
            
            if self.method =='r3':
                if jj == 0:
                    XTGrid = self.r3_sample.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype = torch.float32, device=self.device, requires_grad=True) 
                else:
                    with torch.no_grad():
                        self.r3_sample.update(loss1, loss2)
                        XTGrid = self.r3_sample.XTGrid
                        XTGrid = torch.tensor(XTGrid, dtype = torch.float32, device=self.device, requires_grad=True) 
                        
            elif self.method == 'las':
                if jj == 0:
                    XTGrid = self.las.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                else:
                    if self.las.cnt % 1 == 0:# 4,6,8,10 cnt = 4, 
                        self.las.update(cal_domain_grad, self._nn)
                    XTGrid = self.las.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                self.las.cnt += 1
            
            elif self.method =='l_inf':
                    self.l_inf.update(cal_domain_grad, self._nn)
                    XTGrid = self.l_inf.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)
                
            elif self.method =='rad':
                    self.rad.update(self._nn)
                    XTGrid = self.rad.XTGrid
                    XTGrid = torch.tensor(XTGrid, dtype=torch.float32, requires_grad=True).to(self.device)   
            
            elif self.method =='fixed':
                    XTGrid = torch.tensor(self.fixed_uniform, dtype = torch.float32, device=self.device, requires_grad=True) 
            
            elif self.method =='random-r':
                    x_new = torch.zeros(self.Nf, len(self.LBs) - 1, dtype = torch.float32, device=self.device).uniform_(-1, 1)
                    t_new = torch.zeros(self.Nf, 1, dtype = torch.float32, device=self.device).uniform_(0, 1)
                    x_t_new = torch.concatenate((x_new,t_new), axis = 1)
                    XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True) 
                
            optimizer.zero_grad()    
            loss1, loss2 = self.PhysicsLoss(XTGrid) # For r3 method, loss2 contains element-wise errors
            
            Total_PhysicsLoss = Total_PhysicsLoss + loss1
            Total_Loss = weights[0]*Total_ICLoss + weights[1]*Total_BCLoss\
                        + weights[2]*Total_PhysicsLoss 
            
            Total_Loss.backward()
            optimizer.step()
            scheduler.step()
            if Total_Loss < min_loss:
                torch.save(self._nn.state_dict(), "../models/"+self.method+'_'+str(len(self.Layers)-2)+'_'+str(self.Nf)+'.pt')
                min_loss = float(Total_Loss)
                    
            Training_Losses[jj] = float(Total_Loss)
            
            if (jj+1) % self.display_freq == 0:
                with torch.no_grad():
                    outputs = self.forward(self.X_star)
                    outputs = outputs.reshape(-1,1)
                    re = np.linalg.norm(self.exact_u.cpu()-outputs.cpu().detach()) / np.linalg.norm(self.exact_u.cpu().detach())
                    rel_error[int((jj+1)/10)] = float(re*100)
                    
                print("Iteration Number = {}".format(jj+1))
                print("\tIC Loss = {}".format(float(Total_ICLoss)))
                print("\tBC Loss = {}".format(float(Total_BCLoss)))
                print("\tPhysics Loss = {}".format(float(Total_PhysicsLoss)))
                print("\tTraining Loss = {}".format(float(Total_Loss)))
                print("\tRelative L2 error (test) = {}".format(float(re*100)))

        return Training_Losses, rel_error


if __name__ == "__main__":
                
        parser = argparse.ArgumentParser()
        parser.add_argument('--nodes', type=int, default = 128, help='The number of nodes per hidden layer in the neural network')
        parser.add_argument('--layers', type=int, default = 8, help='The number of hidden layers in the neural network')
        parser.add_argument('--N0', type=int, default = 450, help='The number of points to use on the initial condition')
        parser.add_argument('--Nb', type=int, default = 450, help='The number of points to use on the boundary condition')
        parser.add_argument('--Nf', type=int, default = 1000, help='The number of collocation points to use')
        parser.add_argument('--epochs', type=int, default = 10000, help='The number of epochs to train the neural network')
        parser.add_argument('--method', type=str, default='random-r', help='Sampling method') # fixed, random-r, rad, r3, l_inf, las 
        parser.add_argument('--model-name', type=str, default='PINN_model', help='File name to save the model')
        parser.add_argument('--display-freq', type=int, default=10, help='How often to display loss information')
        parser.add_argument('-f')
        args = parser.parse_args()

        if not os.path.exists("../models/"):
            os.mkdir("../models/")
            
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        NHiddenLayers = args.layers

        desired_dim = 8
    
        LBs = [-1]*desired_dim
        UBs = [1]*desired_dim

        LBs.append(0)
        UBs.append(1)

        Nx = 5
        Nt = 5
        mesh_nodes = []
    
        for i in range(len(LBs)-1):
            X = torch.linspace(LBs[i], UBs[i], Nx).float()
            mesh_nodes.append(X)
        
        T = torch.linspace(LBs[-1], UBs[-1], Nt).float()
        mesh_nodes.append(T)
        
        XYT = stacked_grid(*mesh_nodes)
        Exact_U = exact_soln(XYT)
        Activation = nn.Tanh()
    
        Layers = [desired_dim+1] + [args.nodes]*NHiddenLayers + [1]

        k = 1
        c = 1

        repeat = [0, 1, 2, 3, 4]
        for i in repeat:
            pinn = PINN(  k = k,
                          c = c,
                          t= T,
                          exact_XYT = XYT,
                          exact_u = Exact_U,
                          Layers = Layers,
                          LBs = LBs,
                          UBs = UBs,
                          N0 = args.N0,
                          Nb = args.Nb,
                          Nf = args.Nf,
                          Activation = Activation,
                          device = device,
                          model_name = "../models/" + args.model_name + ".model_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i),
                          display_freq = args.display_freq, samp = args.method )

            Losses_train, Losses_rel_l2 = pinn.Train(args.epochs, weights = (1, 1, 1)) # initial, boundary, residual

            torch.save(Losses_train, "../models/" + args.model_name + ".loss_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
            torch.save(Losses_rel_l2, "../models/" + args.model_name + ".rel_l2_"+args.method+'_'+str(args.layers)+'_'+str(args.Nf)+'_'+str(i))
# Out:
# /tmp/ipykernel_1105682/3399769073.py:248: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.fixed_uniform = torch.tensor(x_t_init, dtype = torch.float32, device=self.device, requires_grad=True)
# /tmp/ipykernel_1105682/3399769073.py:212: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
# /tmp/ipykernel_1105682/3399769073.py:151: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.XTGrid = torch.tensor(copy.deepcopy(fixed_uniform), dtype=torch.float32, requires_grad=True).to(self.device)
# /tmp/ipykernel_1105682/3399769073.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   XTGrid = torch.tensor(x_t_new, dtype = torch.float32, device=self.device, requires_grad=True)
# Iteration Number = 10
# 	IC Loss = 0.7819496989250183
# 	BC Loss = 7.957266807556152
# 	Physics Loss = 8686.935546875
# 	Training Loss = 8695.6748046875
# 	Relative L2 error (test) = 138.54618072509766
# Iteration Number = 20
# 	IC Loss = 0.9641844034194946
# 	BC Loss = 9.61093521118164
# 	Physics Loss = 8955.640625
# 	Training Loss = 8966.2158203125
# 	Relative L2 error (test) = 143.1697130203247
# Iteration Number = 30
# 	IC Loss = 0.669464647769928
# 	BC Loss = 5.067671298980713
# 	Physics Loss = 8509.462890625
# 	Training Loss = 8515.2001953125
# 	Relative L2 error (test) = 104.78730201721191
# Iteration Number = 40
# 	IC Loss = 0.6683111190795898
# 	BC Loss = 5.064704418182373
# 	Physics Loss = 8914.7421875
# 	Training Loss = 8920.4755859375
# 	Relative L2 error (test) = 107.0085883140564
# Iteration Number = 50
# 	IC Loss = 0.656109094619751
# 	BC Loss = 4.824554920196533
# 	Physics Loss = 8482.474609375
# 	Training Loss = 8487.955078125
# 	Relative L2 error (test) = 108.39104652404785
# Iteration Number = 60
# 	IC Loss = 0.6439382433891296
# 	BC Loss = 4.707751750946045
# 	Physics Loss = 8398.1962890625
# 	Training Loss = 8403.5478515625
# 	Relative L2 error (test) = 101.78546905517578
# Iteration Number = 70
# 	IC Loss = 0.6682167053222656
# 	BC Loss = 5.210571765899658
# 	Physics Loss = 8827.8046875
# 	Training Loss = 8833.68359375
# 	Relative L2 error (test) = 106.99363946914673
# Iteration Number = 80
# 	IC Loss = 0.630831778049469
# 	BC Loss = 4.474720001220703
# 	Physics Loss = 8931.1962890625
# 	Training Loss = 8936.3017578125
# 	Relative L2 error (test) = 102.41578817367554
# Iteration Number = 90
# 	IC Loss = 0.6318461894989014
# 	BC Loss = 4.499944686889648
# 	Physics Loss = 8169.00830078125
# 	Training Loss = 8174.14013671875
# 	Relative L2 error (test) = 100.62992572784424
# Iteration Number = 100
# 	IC Loss = 0.6387003660202026
# 	BC Loss = 4.6436309814453125
# 	Physics Loss = 8377.8896484375
# 	Training Loss = 8383.171875
# 	Relative L2 error (test) = 102.77665853500366
# Iteration Number = 110
# 	IC Loss = 0.6559352874755859
# 	BC Loss = 4.911754608154297
# 	Physics Loss = 8548.76171875
# 	Training Loss = 8554.3291015625
# 	Relative L2 error (test) = 106.91357851028442
# Iteration Number = 120
# 	IC Loss = 0.6334558725357056
# 	BC Loss = 4.593956470489502
# 	Physics Loss = 9154.1923828125
# 	Training Loss = 9159.419921875
# 	Relative L2 error (test) = 101.21520757675171
# Iteration Number = 130
# 	IC Loss = 0.6602641940116882
# 	BC Loss = 4.615882873535156
# 	Physics Loss = 8565.1982421875
# 	Training Loss = 8570.474609375
# 	Relative L2 error (test) = 100.77817440032959
# Iteration Number = 140
# 	IC Loss = 0.6551802158355713
# 	BC Loss = 4.591867446899414
# 	Physics Loss = 8111.6728515625
# 	Training Loss = 8116.919921875
# 	Relative L2 error (test) = 100.764000415802
# Iteration Number = 150
# 	IC Loss = 0.6342045068740845
# 	BC Loss = 4.43505859375
# 	Physics Loss = 8788.4716796875
# 	Training Loss = 8793.541015625
# 	Relative L2 error (test) = 100.43306350708008
# Iteration Number = 160
# 	IC Loss = 0.6313998103141785
# 	BC Loss = 4.4130377769470215
# 	Physics Loss = 8811.7841796875
# 	Training Loss = 8816.8291015625
# 	Relative L2 error (test) = 100.3097653388977
# Iteration Number = 170
# 	IC Loss = 0.6364117860794067
# 	BC Loss = 4.469324111938477
# 	Physics Loss = 8644.89453125
# 	Training Loss = 8650.0
# 	Relative L2 error (test) = 100.2489686012268
# Iteration Number = 180
# 	IC Loss = 0.6239598989486694
# 	BC Loss = 4.405282974243164
# 	Physics Loss = 8746.8603515625
# 	Training Loss = 8751.8896484375
# 	Relative L2 error (test) = 100.2180814743042
# Iteration Number = 190
# 	IC Loss = 0.6393308639526367
# 	BC Loss = 4.484889507293701
# 	Physics Loss = 8379.6220703125
# 	Training Loss = 8384.74609375
# 	Relative L2 error (test) = 100.26733875274658
# Iteration Number = 200
# 	IC Loss = 0.6250912547111511
# 	BC Loss = 4.387351989746094
# 	Physics Loss = 8423.69140625
# 	Training Loss = 8428.7041015625
# 	Relative L2 error (test) = 102.1299958229065
# Iteration Number = 210
# 	IC Loss = 0.625189483165741
# 	BC Loss = 4.419227600097656
# 	Physics Loss = 8573.21484375
# 	Training Loss = 8578.2587890625
# 	Relative L2 error (test) = 100.66200494766235
# Iteration Number = 220
# 	IC Loss = 0.6246302127838135
# 	BC Loss = 4.389420032501221
# 	Physics Loss = 8734.34765625
# 	Training Loss = 8739.361328125
# 	Relative L2 error (test) = 100.1865029335022
# Iteration Number = 230
# 	IC Loss = 0.6250997185707092
# 	BC Loss = 4.40631103515625
# 	Physics Loss = 8711.876953125
# 	Training Loss = 8716.908203125
# 	Relative L2 error (test) = 100.63713788986206
# Iteration Number = 240
# 	IC Loss = 0.6245778203010559
# 	BC Loss = 4.3941874504089355
# 	Physics Loss = 8081.109375
# 	Training Loss = 8086.1279296875
# 	Relative L2 error (test) = 101.19142532348633
# Iteration Number = 250
# 	IC Loss = 0.6250758171081543
# 	BC Loss = 4.385236740112305
# 	Physics Loss = 8293.3662109375
# 	Training Loss = 8298.376953125
# 	Relative L2 error (test) = 100.31037330627441
# Iteration Number = 260
# 	IC Loss = 0.6292456388473511
# 	BC Loss = 4.441406726837158
# 	Physics Loss = 8462.734375
# 	Training Loss = 8467.8046875
# 	Relative L2 error (test) = 100.09541511535645
# Iteration Number = 270
# 	IC Loss = 0.6253968477249146
# 	BC Loss = 4.386188507080078
# 	Physics Loss = 8357.80859375
# 	Training Loss = 8362.8203125
# 	Relative L2 error (test) = 100.2279281616211
# Iteration Number = 280
# 	IC Loss = 0.6233018636703491
# 	BC Loss = 4.366715908050537
# 	Physics Loss = 8594.5302734375
# 	Training Loss = 8599.5205078125
# 	Relative L2 error (test) = 100.07520914077759
# Iteration Number = 290
# 	IC Loss = 0.6235974431037903
# 	BC Loss = 4.36808443069458
# 	Physics Loss = 8599.3759765625
# 	Training Loss = 8604.3671875
# 	Relative L2 error (test) = 100.17375946044922
# Iteration Number = 300
# 	IC Loss = 0.6261205077171326
# 	BC Loss = 4.430603981018066
# 	Physics Loss = 8698.8662109375
# 	Training Loss = 8703.9228515625
# 	Relative L2 error (test) = 100.79303979873657
# Iteration Number = 310
# 	IC Loss = 0.626653790473938
# 	BC Loss = 4.3870391845703125
# 	Physics Loss = 8715.701171875
# 	Training Loss = 8720.71484375
# 	Relative L2 error (test) = 100.55322647094727
# Iteration Number = 320
# 	IC Loss = 0.6235149502754211
# 	BC Loss = 4.369409561157227
# 	Physics Loss = 7998.80224609375
# 	Training Loss = 8003.79541015625
# 	Relative L2 error (test) = 100.82365274429321
# Iteration Number = 330
# 	IC Loss = 0.6231708526611328
# 	BC Loss = 4.36643648147583
# 	Physics Loss = 8743.5068359375
# 	Training Loss = 8748.49609375
# 	Relative L2 error (test) = 100.09163618087769
# Iteration Number = 340
# 	IC Loss = 0.6230281591415405
# 	BC Loss = 4.366272449493408
# 	Physics Loss = 8263.0185546875
# 	Training Loss = 8268.0078125
# 	Relative L2 error (test) = 100.06093978881836
# Iteration Number = 350
# 	IC Loss = 0.6243951320648193
# 	BC Loss = 4.368646621704102
# 	Physics Loss = 8549.4609375
# 	Training Loss = 8554.4541015625
# 	Relative L2 error (test) = 100.6656289100647
# Iteration Number = 360
# 	IC Loss = 0.6288934350013733
# 	BC Loss = 4.397884368896484
# 	Physics Loss = 8715.55859375
# 	Training Loss = 8720.5849609375
# 	Relative L2 error (test) = 100.27656555175781
# Iteration Number = 370
# 	IC Loss = 0.6250137686729431
# 	BC Loss = 4.498030185699463
# 	Physics Loss = 8309.056640625
# 	Training Loss = 8314.1796875
# 	Relative L2 error (test) = 102.62026786804199
# Iteration Number = 380
# 	IC Loss = 0.6254106163978577
# 	BC Loss = 4.3790130615234375
# 	Physics Loss = 8364.5810546875
# 	Training Loss = 8369.5859375
# 	Relative L2 error (test) = 100.2738356590271
# Iteration Number = 390
# 	IC Loss = 0.623172402381897
# 	BC Loss = 4.367955684661865
# 	Physics Loss = 8436.482421875
# 	Training Loss = 8441.4736328125
# 	Relative L2 error (test) = 100.13399124145508
# Iteration Number = 400
# 	IC Loss = 0.6232842206954956
# 	BC Loss = 4.367197036743164
# 	Physics Loss = 8578.478515625
# 	Training Loss = 8583.46875
# 	Relative L2 error (test) = 100.21271705627441
# Iteration Number = 410
# 	IC Loss = 0.6233251094818115
# 	BC Loss = 4.367554664611816
# 	Physics Loss = 8556.6982421875
# 	Training Loss = 8561.689453125
# 	Relative L2 error (test) = 100.09760856628418
# Iteration Number = 420
# 	IC Loss = 0.6238824129104614
# 	BC Loss = 4.3731608390808105
# 	Physics Loss = 8305.2919921875
# 	Training Loss = 8310.2890625
# 	Relative L2 error (test) = 100.30989646911621
# Iteration Number = 430
# 	IC Loss = 0.6244115829467773
# 	BC Loss = 4.3720245361328125
# 	Physics Loss = 8824.7177734375
# 	Training Loss = 8829.7138671875
# 	Relative L2 error (test) = 100.19605159759521
# Iteration Number = 440
# 	IC Loss = 0.6249253749847412
# 	BC Loss = 4.37131404876709
# 	Physics Loss = 8193.4169921875
# 	Training Loss = 8198.4130859375
# 	Relative L2 error (test) = 100.184166431427
# Iteration Number = 450
# 	IC Loss = 0.6250760555267334
# 	BC Loss = 4.376371383666992
# 	Physics Loss = 8854.4228515625
# 	Training Loss = 8859.423828125
# 	Relative L2 error (test) = 101.50706768035889
# Iteration Number = 460
# 	IC Loss = 0.6306010484695435
# 	BC Loss = 4.4320759773254395
# 	Physics Loss = 9041.1025390625
# 	Training Loss = 9046.1650390625
# 	Relative L2 error (test) = 100.05502700805664
# Iteration Number = 470
# 	IC Loss = 0.6241145730018616
# 	BC Loss = 4.407619476318359
# 	Physics Loss = 9192.4931640625
# 	Training Loss = 9197.5244140625
# 	Relative L2 error (test) = 100.41128396987915
# Iteration Number = 480
# 	IC Loss = 0.6241341829299927
# 	BC Loss = 4.377776622772217
# 	Physics Loss = 8907.5126953125
# 	Training Loss = 8912.5146484375
# 	Relative L2 error (test) = 101.18303298950195
# Iteration Number = 490
# 	IC Loss = 0.6270191669464111
# 	BC Loss = 4.451874256134033
# 	Physics Loss = 8536.5322265625
# 	Training Loss = 8541.611328125
# 	Relative L2 error (test) = 102.44383811950684
# Iteration Number = 500
# 	IC Loss = 0.6277029514312744
# 	BC Loss = 4.407649517059326
# 	Physics Loss = 8783.7841796875
# 	Training Loss = 8788.8193359375
# 	Relative L2 error (test) = 100.08517503738403
# Iteration Number = 510
# 	IC Loss = 0.6234028339385986
# 	BC Loss = 4.376224040985107
# 	Physics Loss = 8619.39453125
# 	Training Loss = 8624.39453125
# 	Relative L2 error (test) = 100.02492666244507
# Iteration Number = 520
# 	IC Loss = 0.6230804920196533
# 	BC Loss = 4.363325119018555
# 	Physics Loss = 8723.5654296875
# 	Training Loss = 8728.5517578125
# 	Relative L2 error (test) = 100.01161098480225
# Iteration Number = 530
# 	IC Loss = 0.6230048537254333
# 	BC Loss = 4.362104415893555
# 	Physics Loss = 8347.0380859375
# 	Training Loss = 8352.0234375
# 	Relative L2 error (test) = 100.05462169647217
# Iteration Number = 540
# 	IC Loss = 0.6230581402778625
# 	BC Loss = 4.360930919647217
# 	Physics Loss = 8189.0546875
# 	Training Loss = 8194.0390625
# 	Relative L2 error (test) = 100.0190258026123
# Iteration Number = 550
# 	IC Loss = 0.6236023902893066
# 	BC Loss = 4.370622634887695
# 	Physics Loss = 8238.5888671875
# 	Training Loss = 8243.5830078125
# 	Relative L2 error (test) = 100.00230073928833
# Iteration Number = 560
# 	IC Loss = 0.6232283711433411
# 	BC Loss = 4.36647367477417
# 	Physics Loss = 8445.0087890625
# 	Training Loss = 8449.998046875
# 	Relative L2 error (test) = 100.01041889190674
# Iteration Number = 570
# 	IC Loss = 0.6233208179473877
# 	BC Loss = 4.372169494628906
# 	Physics Loss = 8828.7685546875
# 	Training Loss = 8833.763671875
# 	Relative L2 error (test) = 100.45042037963867
# Iteration Number = 580
# 	IC Loss = 0.6262511014938354
# 	BC Loss = 4.396867275238037
# 	Physics Loss = 8706.9404296875
# 	Training Loss = 8711.9638671875
# 	Relative L2 error (test) = 100.02925395965576
# Iteration Number = 590
# 	IC Loss = 0.6229144334793091
# 	BC Loss = 4.3593902587890625
# 	Physics Loss = 8660.57421875
# 	Training Loss = 8665.556640625
# 	Relative L2 error (test) = 100.02210140228271
# Iteration Number = 600
# 	IC Loss = 0.6229944825172424
# 	BC Loss = 4.362028121948242
# 	Physics Loss = 8809.42578125
# 	Training Loss = 8814.4111328125
# 	Relative L2 error (test) = 100.16775131225586
# Iteration Number = 610
# 	IC Loss = 0.6233882904052734
# 	BC Loss = 4.365906238555908
# 	Physics Loss = 8498.7421875
# 	Training Loss = 8503.7314453125
# 	Relative L2 error (test) = 100.03882646560669
# Iteration Number = 620
# 	IC Loss = 0.6238183975219727
# 	BC Loss = 4.375088214874268
# 	Physics Loss = 8212.7060546875
# 	Training Loss = 8217.705078125
# 	Relative L2 error (test) = 100.01412630081177
# Iteration Number = 630
# 	IC Loss = 0.6229918003082275
# 	BC Loss = 4.360536098480225
# 	Physics Loss = 8368.4990234375
# 	Training Loss = 8373.482421875
# 	Relative L2 error (test) = 100.05768537521362
# Iteration Number = 640
# 	IC Loss = 0.6230252981185913
# 	BC Loss = 4.360989093780518
# 	Physics Loss = 8781.48046875
# 	Training Loss = 8786.46484375
# 	Relative L2 error (test) = 100.0164270401001
# Iteration Number = 650
# 	IC Loss = 0.622889518737793
# 	BC Loss = 4.359828472137451
# 	Physics Loss = 8666.82421875
# 	Training Loss = 8671.806640625
# 	Relative L2 error (test) = 100.01204013824463
# Iteration Number = 660
# 	IC Loss = 0.6230728626251221
# 	BC Loss = 4.365177631378174
# 	Physics Loss = 8722.1044921875
# 	Training Loss = 8727.0927734375
# 	Relative L2 error (test) = 100.01192092895508
# Iteration Number = 670
# 	IC Loss = 0.6228783130645752
# 	BC Loss = 4.359104156494141
# 	Physics Loss = 8291.345703125
# 	Training Loss = 8296.328125
# 	Relative L2 error (test) = 100.06997585296631
# Iteration Number = 680
# 	IC Loss = 0.6229637265205383
# 	BC Loss = 4.360062122344971
# 	Physics Loss = 8680.7783203125
# 	Training Loss = 8685.76171875
# 	Relative L2 error (test) = 100.00430345535278
# Iteration Number = 690
# 	IC Loss = 0.6229726076126099
# 	BC Loss = 4.36057710647583
# 	Physics Loss = 8141.390625
# 	Training Loss = 8146.3740234375
# 	Relative L2 error (test) = 100.01143217086792
# Iteration Number = 700
# 	IC Loss = 0.6235644817352295
# 	BC Loss = 4.370019912719727
# 	Physics Loss = 8667.4931640625
# 	Training Loss = 8672.486328125
# 	Relative L2 error (test) = 100.03591775894165
# Iteration Number = 710
# 	IC Loss = 0.622986912727356
# 	BC Loss = 4.360652446746826
# 	Physics Loss = 8455.9443359375
# 	Training Loss = 8460.927734375
# 	Relative L2 error (test) = 100.01589059829712
# Iteration Number = 720
# 	IC Loss = 0.6228747963905334
# 	BC Loss = 4.359015941619873
# 	Physics Loss = 8236.6884765625
# 	Training Loss = 8241.669921875
# 	Relative L2 error (test) = 100.03387928009033
# Iteration Number = 730
# 	IC Loss = 0.6229965686798096
# 	BC Loss = 4.361576557159424
# 	Physics Loss = 8615.609375
# 	Training Loss = 8620.59375
# 	Relative L2 error (test) = 100.05214214324951
# Iteration Number = 740
# 	IC Loss = 0.623131275177002
# 	BC Loss = 4.363677024841309
# 	Physics Loss = 8821.716796875
# 	Training Loss = 8826.703125
# 	Relative L2 error (test) = 100.00265836715698
# Iteration Number = 750
# 	IC Loss = 0.6229842901229858
# 	BC Loss = 4.360744476318359
# 	Physics Loss = 8269.814453125
# 	Training Loss = 8274.7978515625
# 	Relative L2 error (test) = 100.02734661102295
# Iteration Number = 760
# 	IC Loss = 0.6229084730148315
# 	BC Loss = 4.359220504760742
# 	Physics Loss = 8340.7236328125
# 	Training Loss = 8345.7060546875
# 	Relative L2 error (test) = 100.00840425491333
# Iteration Number = 770
# 	IC Loss = 0.6230000257492065
# 	BC Loss = 4.361213684082031
# 	Physics Loss = 8618.8662109375
# 	Training Loss = 8623.8505859375
# 	Relative L2 error (test) = 100.01518726348877
# Iteration Number = 780
# 	IC Loss = 0.6229389905929565
# 	BC Loss = 4.359811782836914
# 	Physics Loss = 8292.4599609375
# 	Training Loss = 8297.4423828125
# 	Relative L2 error (test) = 100.00060796737671
# Iteration Number = 790
# 	IC Loss = 0.622868537902832
# 	BC Loss = 4.35878849029541
# 	Physics Loss = 8691.984375
# 	Training Loss = 8696.9658203125
# 	Relative L2 error (test) = 100.00807046890259
# Iteration Number = 800
# 	IC Loss = 0.6228662729263306
# 	BC Loss = 4.358757019042969
# 	Physics Loss = 8549.318359375
# 	Training Loss = 8554.2998046875
# 	Relative L2 error (test) = 100.05733966827393
# Iteration Number = 810
# 	IC Loss = 0.6228665113449097
# 	BC Loss = 4.358767986297607
# 	Physics Loss = 8587.1005859375
# 	Training Loss = 8592.08203125
# 	Relative L2 error (test) = 100.01159906387329
# Iteration Number = 820
# 	IC Loss = 0.6228796243667603
# 	BC Loss = 4.359104633331299
# 	Physics Loss = 8864.103515625
# 	Training Loss = 8869.0859375
# 	Relative L2 error (test) = 100.00263452529907
# Iteration Number = 830
# 	IC Loss = 0.6233465671539307
# 	BC Loss = 4.3683013916015625
# 	Physics Loss = 8895.013671875
# 	Training Loss = 8900.0048828125
# 	Relative L2 error (test) = 100.00323057174683
# Iteration Number = 840
# 	IC Loss = 0.62330162525177
# 	BC Loss = 4.367035388946533
# 	Physics Loss = 8729.6357421875
# 	Training Loss = 8734.6259765625
# 	Relative L2 error (test) = 100.1598596572876
# Iteration Number = 850
# 	IC Loss = 0.6229119896888733
# 	BC Loss = 4.359603404998779
# 	Physics Loss = 7949.6181640625
# 	Training Loss = 7954.6005859375
# 	Relative L2 error (test) = 100.07157325744629
# Iteration Number = 860
# 	IC Loss = 0.623120903968811
# 	BC Loss = 4.363620281219482
# 	Physics Loss = 8760.9501953125
# 	Training Loss = 8765.9365234375
# 	Relative L2 error (test) = 100.00956058502197
# Iteration Number = 870
# 	IC Loss = 0.6232830286026001
# 	BC Loss = 4.3671793937683105
# 	Physics Loss = 8240.4638671875
# 	Training Loss = 8245.4541015625
# 	Relative L2 error (test) = 100.00201463699341
# Iteration Number = 880
# 	IC Loss = 0.6231437921524048
# 	BC Loss = 4.3648223876953125
# 	Physics Loss = 8755.5615234375
# 	Training Loss = 8760.5498046875
# 	Relative L2 error (test) = 100.07339715957642
# Iteration Number = 890
# 	IC Loss = 0.6228702068328857
# 	BC Loss = 4.3592071533203125
# 	Physics Loss = 8594.392578125
# 	Training Loss = 8599.375
# 	Relative L2 error (test) = 100.10157823562622
# Iteration Number = 900
# 	IC Loss = 0.6228853464126587
# 	BC Loss = 4.358870983123779
# 	Physics Loss = 8769.6162109375
# 	Training Loss = 8774.59765625
# 	Relative L2 error (test) = 100.01475811004639
# Iteration Number = 910
# 	IC Loss = 0.6229658126831055
# 	BC Loss = 4.359805583953857
# 	Physics Loss = 7974.75439453125
# 	Training Loss = 7979.7373046875
# 	Relative L2 error (test) = 100.03583431243896
# Iteration Number = 920
# 	IC Loss = 0.6232553720474243
# 	BC Loss = 4.362904071807861
# 	Physics Loss = 8391.205078125
# 	Training Loss = 8396.19140625
# 	Relative L2 error (test) = 100.01300573348999
# Iteration Number = 930
# 	IC Loss = 0.6230632662773132
# 	BC Loss = 4.360429763793945
# 	Physics Loss = 8350.939453125
# 	Training Loss = 8355.9228515625
# 	Relative L2 error (test) = 100.00511407852173
# Iteration Number = 940
# 	IC Loss = 0.6229860782623291
# 	BC Loss = 4.3597283363342285
# 	Physics Loss = 8270.7314453125
# 	Training Loss = 8275.7138671875
# 	Relative L2 error (test) = 100.00801086425781
# Iteration Number = 950
# 	IC Loss = 0.622864305973053
# 	BC Loss = 4.359292984008789
# 	Physics Loss = 8780.5
# 	Training Loss = 8785.482421875
# 	Relative L2 error (test) = 100.0110387802124
# Iteration Number = 960
# 	IC Loss = 0.6231720447540283
# 	BC Loss = 4.361513137817383
# 	Physics Loss = 8440.5986328125
# 	Training Loss = 8445.5830078125
# 	Relative L2 error (test) = 100.0284194946289
# Iteration Number = 970
# 	IC Loss = 0.6229960918426514
# 	BC Loss = 4.3609538078308105
# 	Physics Loss = 8488.74609375
# 	Training Loss = 8493.73046875
# 	Relative L2 error (test) = 100.0975489616394
# Iteration Number = 980
# 	IC Loss = 0.6229674816131592
# 	BC Loss = 4.3640055656433105
# 	Physics Loss = 8207.5732421875
# 	Training Loss = 8212.560546875
# 	Relative L2 error (test) = 100.20500421524048
# Iteration Number = 990
# 	IC Loss = 0.6229281425476074
# 	BC Loss = 4.361052989959717
# 	Physics Loss = 8568.748046875
# 	Training Loss = 8573.732421875
# 	Relative L2 error (test) = 100.02939701080322
# Iteration Number = 1000
# 	IC Loss = 0.6230593323707581
# 	BC Loss = 4.36475944519043
# 	Physics Loss = 8447.2841796875
# 	Training Loss = 8452.2724609375
# 	Relative L2 error (test) = 100.01404285430908
# Iteration Number = 1010
# 	IC Loss = 0.6230272054672241
# 	BC Loss = 4.361114978790283
# 	Physics Loss = 8173.05126953125
# 	Training Loss = 8178.03564453125
# 	Relative L2 error (test) = 100.01174211502075
# Iteration Number = 1020
# 	IC Loss = 0.6229257583618164
# 	BC Loss = 4.360807418823242
# 	Physics Loss = 8777.9228515625
# 	Training Loss = 8782.90625
# 	Relative L2 error (test) = 100.05159378051758
# Iteration Number = 1030
# 	IC Loss = 0.6229644417762756
# 	BC Loss = 4.362768173217773
# 	Physics Loss = 8260.255859375
# 	Training Loss = 8265.2412109375
# 	Relative L2 error (test) = 100.0425934791565
# Iteration Number = 1040
# 	IC Loss = 0.6228901147842407
# 	BC Loss = 4.359710693359375
# 	Physics Loss = 8646.853515625
# 	Training Loss = 8651.8359375
# 	Relative L2 error (test) = 100.01740455627441
# Iteration Number = 1050
# 	IC Loss = 0.6228768825531006
# 	BC Loss = 4.359297275543213
# 	Physics Loss = 8376.9228515625
# 	Training Loss = 8381.9052734375
# 	Relative L2 error (test) = 100.00965595245361
# Iteration Number = 1060
# 	IC Loss = 0.6229133605957031
# 	BC Loss = 4.360355854034424
# 	Physics Loss = 8488.4248046875
# 	Training Loss = 8493.408203125
# 	Relative L2 error (test) = 100.01678466796875
# Iteration Number = 1070
# 	IC Loss = 0.6228688955307007
# 	BC Loss = 4.359598159790039
# 	Physics Loss = 8588.4970703125
# 	Training Loss = 8593.4794921875
# 	Relative L2 error (test) = 100.01420974731445
# Iteration Number = 1080
# 	IC Loss = 0.6228845715522766
# 	BC Loss = 4.358852386474609
# 	Physics Loss = 8010.41845703125
# 	Training Loss = 8015.400390625
# 	Relative L2 error (test) = 100.00406503677368
# Iteration Number = 1090
# 	IC Loss = 0.6229056715965271
# 	BC Loss = 4.358972549438477
# 	Physics Loss = 8469.6123046875
# 	Training Loss = 8474.59375
# 	Relative L2 error (test) = 100.00385046005249
# Iteration Number = 1100
# 	IC Loss = 0.6228657364845276
# 	BC Loss = 4.358684539794922
# 	Physics Loss = 8927.4521484375
# 	Training Loss = 8932.43359375
# 	Relative L2 error (test) = 100.02809762954712
# Iteration Number = 1110
# 	IC Loss = 0.6228961944580078
# 	BC Loss = 4.358949661254883
# 	Physics Loss = 8426.8916015625
# 	Training Loss = 8431.873046875
# 	Relative L2 error (test) = 100.02262592315674
# Iteration Number = 1120
# 	IC Loss = 0.6228624582290649
# 	BC Loss = 4.358674049377441
# 	Physics Loss = 8914.9697265625
# 	Training Loss = 8919.951171875
# 	Relative L2 error (test) = 100.00195503234863
# Iteration Number = 1130
# 	IC Loss = 0.6228695511817932
# 	BC Loss = 4.35921049118042
# 	Physics Loss = 8215.765625
# 	Training Loss = 8220.748046875
# 	Relative L2 error (test) = 100.00578165054321
# Iteration Number = 1140
# 	IC Loss = 0.6228858232498169
# 	BC Loss = 4.359748363494873
# 	Physics Loss = 8365.369140625
# 	Training Loss = 8370.3515625
# 	Relative L2 error (test) = 100.02007484436035
# Iteration Number = 1150
# 	IC Loss = 0.6229513883590698
# 	BC Loss = 4.3592634201049805
# 	Physics Loss = 8507.818359375
# 	Training Loss = 8512.80078125
# 	Relative L2 error (test) = 100.0401258468628
# Iteration Number = 1160
# 	IC Loss = 0.6228801012039185
# 	BC Loss = 4.359928131103516
# 	Physics Loss = 8872.830078125
# 	Training Loss = 8877.8125
# 	Relative L2 error (test) = 100.0033974647522
# Iteration Number = 1170
# 	IC Loss = 0.6228646039962769
# 	BC Loss = 4.3587470054626465
# 	Physics Loss = 8572.826171875
# 	Training Loss = 8577.8076171875
# 	Relative L2 error (test) = 100.00780820846558
# Iteration Number = 1180
# 	IC Loss = 0.6229596734046936
# 	BC Loss = 4.359420299530029
# 	Physics Loss = 8382.2314453125
# 	Training Loss = 8387.2138671875
# 	Relative L2 error (test) = 100.01767873764038
# Iteration Number = 1190
# 	IC Loss = 0.6228787899017334
# 	BC Loss = 4.358787536621094
# 	Physics Loss = 8514.8115234375
# 	Training Loss = 8519.79296875
# 	Relative L2 error (test) = 100.01629590988159
# Iteration Number = 1200
# 	IC Loss = 0.6229196190834045
# 	BC Loss = 4.359394073486328
# 	Physics Loss = 8727.5927734375
# 	Training Loss = 8732.5751953125
# 	Relative L2 error (test) = 100.00144243240356
# Iteration Number = 1210
# 	IC Loss = 0.6228737831115723
# 	BC Loss = 4.359003067016602
# 	Physics Loss = 8190.30859375
# 	Training Loss = 8195.2900390625
# 	Relative L2 error (test) = 100.0025749206543
# Iteration Number = 1220
# 	IC Loss = 0.6228580474853516
# 	BC Loss = 4.358689308166504
# 	Physics Loss = 8244.3095703125
# 	Training Loss = 8249.291015625
# 	Relative L2 error (test) = 100.00061988830566
# Iteration Number = 1230
# 	IC Loss = 0.6228586435317993
# 	BC Loss = 4.358687877655029
# 	Physics Loss = 8107.271484375
# 	Training Loss = 8112.2529296875
# 	Relative L2 error (test) = 100.00338554382324
# Iteration Number = 1240
# 	IC Loss = 0.6228660941123962
# 	BC Loss = 4.358922004699707
# 	Physics Loss = 8937.9228515625
# 	Training Loss = 8942.904296875
# 	Relative L2 error (test) = 100.02392530441284
# Iteration Number = 1250
# 	IC Loss = 0.6230312585830688
# 	BC Loss = 4.361053943634033
# 	Physics Loss = 8434.3203125
# 	Training Loss = 8439.3046875
# 	Relative L2 error (test) = 100.00721216201782
# Iteration Number = 1260
# 	IC Loss = 0.6228544116020203
# 	BC Loss = 4.358604907989502
# 	Physics Loss = 8371.0576171875
# 	Training Loss = 8376.0390625
# 	Relative L2 error (test) = 100.05267858505249
# Iteration Number = 1270
# 	IC Loss = 0.6228975653648376
# 	BC Loss = 4.359492778778076
# 	Physics Loss = 8376.3046875
# 	Training Loss = 8381.287109375
# 	Relative L2 error (test) = 100.02269744873047
# Iteration Number = 1280
# 	IC Loss = 0.6231611967086792
# 	BC Loss = 4.363117218017578
# 	Physics Loss = 8937.15234375
# 	Training Loss = 8942.138671875
# 	Relative L2 error (test) = 100.00046491622925
# Iteration Number = 1290
# 	IC Loss = 0.6228537559509277
# 	BC Loss = 4.358606338500977
# 	Physics Loss = 8562.4873046875
# 	Training Loss = 8567.46875
# 	Relative L2 error (test) = 100.00051259994507
# Iteration Number = 1300
# 	IC Loss = 0.6228595972061157
# 	BC Loss = 4.358781814575195
# 	Physics Loss = 8784.0966796875
# 	Training Loss = 8789.078125
# 	Relative L2 error (test) = 100.00138282775879
# Iteration Number = 1310
# 	IC Loss = 0.6228702068328857
# 	BC Loss = 4.358826160430908
# 	Physics Loss = 8780.8603515625
# 	Training Loss = 8785.841796875
# 	Relative L2 error (test) = 100.01120567321777
# Iteration Number = 1320
# 	IC Loss = 0.6228814125061035
# 	BC Loss = 4.359245300292969
# 	Physics Loss = 8500.30859375
# 	Training Loss = 8505.291015625
# 	Relative L2 error (test) = 100.01124143600464
# Iteration Number = 1330
# 	IC Loss = 0.6228904724121094
# 	BC Loss = 4.359220027923584
# 	Physics Loss = 8772.6689453125
# 	Training Loss = 8777.6513671875
# 	Relative L2 error (test) = 100.00537633895874
# Iteration Number = 1340
# 	IC Loss = 0.62290358543396
# 	BC Loss = 4.359703063964844
# 	Physics Loss = 7986.25830078125
# 	Training Loss = 7991.24072265625
# 	Relative L2 error (test) = 100.00275373458862
# Iteration Number = 1350
# 	IC Loss = 0.6228971481323242
# 	BC Loss = 4.359043598175049
# 	Physics Loss = 8918.7587890625
# 	Training Loss = 8923.7412109375
# 	Relative L2 error (test) = 100.00758171081543
# Iteration Number = 1360
# 	IC Loss = 0.6230588555335999
# 	BC Loss = 4.3608293533325195
# 	Physics Loss = 8977.2607421875
# 	Training Loss = 8982.2451171875
# 	Relative L2 error (test) = 100.01692771911621
# Iteration Number = 1370
# 	IC Loss = 0.6228620409965515
# 	BC Loss = 4.358892917633057
# 	Physics Loss = 8666.388671875
# 	Training Loss = 8671.3701171875
# 	Relative L2 error (test) = 100.06177425384521
# Iteration Number = 1380
# 	IC Loss = 0.622874915599823
# 	BC Loss = 4.358913421630859
# 	Physics Loss = 8717.8623046875
# 	Training Loss = 8722.84375
# 	Relative L2 error (test) = 100.00872611999512
# Iteration Number = 1390
# 	IC Loss = 0.6230087280273438
# 	BC Loss = 4.362277507781982
# 	Physics Loss = 8305.1748046875
# 	Training Loss = 8310.16015625
# 	Relative L2 error (test) = 100.031578540802
# Iteration Number = 1400
# 	IC Loss = 0.6230850219726562
# 	BC Loss = 4.361556529998779
# 	Physics Loss = 8477.453125
# 	Training Loss = 8482.4375
# 	Relative L2 error (test) = 100.04993677139282
# Iteration Number = 1410
# 	IC Loss = 0.6229899525642395
# 	BC Loss = 4.366791725158691
# 	Physics Loss = 8711.359375
# 	Training Loss = 8716.349609375
# 	Relative L2 error (test) = 100.07287263870239
# Iteration Number = 1420
# 	IC Loss = 0.6228692531585693
# 	BC Loss = 4.3588337898254395
# 	Physics Loss = 8743.771484375
# 	Training Loss = 8748.7529296875
# 	Relative L2 error (test) = 100.02065896987915
# Iteration Number = 1430
# 	IC Loss = 0.6228811144828796
# 	BC Loss = 4.359189987182617
# 	Physics Loss = 8754.97265625
# 	Training Loss = 8759.955078125
# 	Relative L2 error (test) = 100.00268220901489
# Iteration Number = 1440
# 	IC Loss = 0.6228815317153931
# 	BC Loss = 4.358985900878906
# 	Physics Loss = 8243.12109375
# 	Training Loss = 8248.1025390625
# 	Relative L2 error (test) = 100.00473260879517
# Iteration Number = 1450
# 	IC Loss = 0.6228703260421753
# 	BC Loss = 4.3590006828308105
# 	Physics Loss = 8660.95703125
# 	Training Loss = 8665.9384765625
# 	Relative L2 error (test) = 100.00429153442383
# Iteration Number = 1460
# 	IC Loss = 0.62287437915802
# 	BC Loss = 4.359071731567383
# 	Physics Loss = 8689.984375
# 	Training Loss = 8694.966796875
# 	Relative L2 error (test) = 100.00609159469604
# Iteration Number = 1470
# 	IC Loss = 0.6228715181350708
# 	BC Loss = 4.358926773071289
# 	Physics Loss = 8474.259765625
# 	Training Loss = 8479.2412109375
# 	Relative L2 error (test) = 100.00492334365845
# Iteration Number = 1480
# 	IC Loss = 0.6229524612426758
# 	BC Loss = 4.36037015914917
# 	Physics Loss = 9391.5458984375
# 	Training Loss = 9396.529296875
# 	Relative L2 error (test) = 100.01202821731567
# Iteration Number = 1490
# 	IC Loss = 0.62308269739151
# 	BC Loss = 4.3619513511657715
# 	Physics Loss = 9006.810546875
# 	Training Loss = 9011.7958984375
# 	Relative L2 error (test) = 100.0109314918518
# Iteration Number = 1500
# 	IC Loss = 0.6229069828987122
# 	BC Loss = 4.359883785247803
# 	Physics Loss = 8639.330078125
# 	Training Loss = 8644.3125
# 	Relative L2 error (test) = 100.00540018081665
# Iteration Number = 1510
# 	IC Loss = 0.6231787204742432
# 	BC Loss = 4.362903594970703
# 	Physics Loss = 8654.423828125
# 	Training Loss = 8659.41015625
# 	Relative L2 error (test) = 100.03014802932739
# Iteration Number = 1520
# 	IC Loss = 0.622922420501709
# 	BC Loss = 4.360241889953613
# 	Physics Loss = 8550.1953125
# 	Training Loss = 8555.1787109375
# 	Relative L2 error (test) = 100.02692937850952
# Iteration Number = 1530
# 	IC Loss = 0.6229196786880493
# 	BC Loss = 4.359543323516846
# 	Physics Loss = 8412.208984375
# 	Training Loss = 8417.19140625
# 	Relative L2 error (test) = 100.04150867462158
# Iteration Number = 1540
# 	IC Loss = 0.6228809952735901
# 	BC Loss = 4.359317302703857
# 	Physics Loss = 8476.677734375
# 	Training Loss = 8481.66015625
# 	Relative L2 error (test) = 100.0927209854126
# Iteration Number = 1550
# 	IC Loss = 0.6229000091552734
# 	BC Loss = 4.359237194061279
# 	Physics Loss = 8732.9873046875
# 	Training Loss = 8737.9697265625
# 	Relative L2 error (test) = 100.04043579101562
# Iteration Number = 1560
# 	IC Loss = 0.6228600740432739
# 	BC Loss = 4.358675479888916
# 	Physics Loss = 8778.78515625
# 	Training Loss = 8783.7666015625
# 	Relative L2 error (test) = 100.02850294113159
# Iteration Number = 1570
# 	IC Loss = 0.6229343414306641
# 	BC Loss = 4.359727382659912
# 	Physics Loss = 8736.888671875
# 	Training Loss = 8741.87109375
# 	Relative L2 error (test) = 100.02577304840088
# Iteration Number = 1580
# 	IC Loss = 0.6230915784835815
# 	BC Loss = 4.362427234649658
# 	Physics Loss = 8694.0927734375
# 	Training Loss = 8699.078125
# 	Relative L2 error (test) = 100.043785572052
# Iteration Number = 1590
# 	IC Loss = 0.62307208776474
# 	BC Loss = 4.361812114715576
# 	Physics Loss = 8633.501953125
# 	Training Loss = 8638.4873046875
# 	Relative L2 error (test) = 100.00518560409546
# Iteration Number = 1600
# 	IC Loss = 0.6229170560836792
# 	BC Loss = 4.359704494476318
# 	Physics Loss = 8340.3662109375
# 	Training Loss = 8345.3486328125
# 	Relative L2 error (test) = 100.02269744873047
# Iteration Number = 1610
# 	IC Loss = 0.6228938102722168
# 	BC Loss = 4.359218120574951
# 	Physics Loss = 8750.39453125
# 	Training Loss = 8755.376953125
# 	Relative L2 error (test) = 100.01667737960815
# Iteration Number = 1620
# 	IC Loss = 0.6229152083396912
# 	BC Loss = 4.359469890594482
# 	Physics Loss = 8389.267578125
# 	Training Loss = 8394.25
# 	Relative L2 error (test) = 100.0075101852417
# Iteration Number = 1630
# 	IC Loss = 0.6228761672973633
# 	BC Loss = 4.359123706817627
# 	Physics Loss = 8735.666015625
# 	Training Loss = 8740.6484375
# 	Relative L2 error (test) = 100.02351999282837
# Iteration Number = 1640
# 	IC Loss = 0.622852087020874
# 	BC Loss = 4.358639240264893
# 	Physics Loss = 8347.326171875
# 	Training Loss = 8352.3076171875
# 	Relative L2 error (test) = 100.00215768814087
# Iteration Number = 1650
# 	IC Loss = 0.6228619813919067
# 	BC Loss = 4.35880708694458
# 	Physics Loss = 8755.4462890625
# 	Training Loss = 8760.427734375
# 	Relative L2 error (test) = 100.00454187393188
# Iteration Number = 1660
# 	IC Loss = 0.6229026317596436
# 	BC Loss = 4.359331130981445
# 	Physics Loss = 8922.6494140625
# 	Training Loss = 8927.6318359375
# 	Relative L2 error (test) = 100.00275373458862
# Iteration Number = 1670
# 	IC Loss = 0.6229681968688965
# 	BC Loss = 4.360494613647461
# 	Physics Loss = 8582.0966796875
# 	Training Loss = 8587.080078125
# 	Relative L2 error (test) = 100.03025531768799
# Iteration Number = 1680
# 	IC Loss = 0.6228480339050293
# 	BC Loss = 4.3585286140441895
# 	Physics Loss = 9000.798828125
# 	Training Loss = 9005.7802734375
# 	Relative L2 error (test) = 100.03467798233032
# Iteration Number = 1690
# 	IC Loss = 0.6228711605072021
# 	BC Loss = 4.358791828155518
# 	Physics Loss = 7915.26513671875
# 	Training Loss = 7920.24658203125
# 	Relative L2 error (test) = 100.00916719436646
# Iteration Number = 1700
# 	IC Loss = 0.6228685975074768
# 	BC Loss = 4.358999252319336
# 	Physics Loss = 8577.791015625
# 	Training Loss = 8582.7724609375
# 	Relative L2 error (test) = 100.00133514404297
# Iteration Number = 1710
# 	IC Loss = 0.622855544090271
# 	BC Loss = 4.3586344718933105
# 	Physics Loss = 8311.9189453125
# 	Training Loss = 8316.900390625
# 	Relative L2 error (test) = 100.00079870223999
# Iteration Number = 1720
# 	IC Loss = 0.6228570938110352
# 	BC Loss = 4.358657360076904
# 	Physics Loss = 8586.2431640625
# 	Training Loss = 8591.224609375
# 	Relative L2 error (test) = 100.00134706497192
# Iteration Number = 1730
# 	IC Loss = 0.6228513717651367
# 	BC Loss = 4.358587265014648
# 	Physics Loss = 8274.9248046875
# 	Training Loss = 8279.90625
# 	Relative L2 error (test) = 100.00272989273071
# Iteration Number = 1740
# 	IC Loss = 0.6228504776954651
# 	BC Loss = 4.35856819152832
# 	Physics Loss = 8403.40625
# 	Training Loss = 8408.3876953125
# 	Relative L2 error (test) = 100.00661611557007
# Iteration Number = 1750
# 	IC Loss = 0.6228612661361694
# 	BC Loss = 4.358730316162109
# 	Physics Loss = 8279.8994140625
# 	Training Loss = 8284.880859375
# 	Relative L2 error (test) = 100.0009536743164
# Iteration Number = 1760
# 	IC Loss = 0.6228768229484558
# 	BC Loss = 4.359010696411133
# 	Physics Loss = 8886.083984375
# 	Training Loss = 8891.0654296875
# 	Relative L2 error (test) = 100.00677108764648
# Iteration Number = 1770
# 	IC Loss = 0.6228593587875366
# 	BC Loss = 4.358695983886719
# 	Physics Loss = 8482.021484375
# 	Training Loss = 8487.0029296875
# 	Relative L2 error (test) = 100.00076293945312
# Iteration Number = 1780
# 	IC Loss = 0.6228707432746887
# 	BC Loss = 4.35881233215332
# 	Physics Loss = 8385.8671875
# 	Training Loss = 8390.8486328125
# 	Relative L2 error (test) = 100.00163316726685
# Iteration Number = 1790
# 	IC Loss = 0.6228839159011841
# 	BC Loss = 4.359003067016602
# 	Physics Loss = 8573.5966796875
# 	Training Loss = 8578.578125
# 	Relative L2 error (test) = 100.00367164611816
# Iteration Number = 1800
# 	IC Loss = 0.622864305973053
# 	BC Loss = 4.358837604522705
# 	Physics Loss = 8562.9755859375
# 	Training Loss = 8567.95703125
# 	Relative L2 error (test) = 100.00015497207642
# Iteration Number = 1810
# 	IC Loss = 0.6228522062301636
# 	BC Loss = 4.358574390411377
# 	Physics Loss = 7916.7724609375
# 	Training Loss = 7921.75390625
# 	Relative L2 error (test) = 100.02460479736328
# Iteration Number = 1820
# 	IC Loss = 0.622893214225769
# 	BC Loss = 4.359209060668945
# 	Physics Loss = 8587.634765625
# 	Training Loss = 8592.6171875
# 	Relative L2 error (test) = 100.00439882278442
# Iteration Number = 1830
# 	IC Loss = 0.6228563785552979
# 	BC Loss = 4.358668804168701
# 	Physics Loss = 8736.5322265625
# 	Training Loss = 8741.513671875
# 	Relative L2 error (test) = 99.99996423721313
# Iteration Number = 1840
# 	IC Loss = 0.6228506565093994
# 	BC Loss = 4.3585662841796875
# 	Physics Loss = 8620.9658203125
# 	Training Loss = 8625.947265625
# 	Relative L2 error (test) = 100.00022649765015
# Iteration Number = 1850
# 	IC Loss = 0.622897744178772
# 	BC Loss = 4.3593902587890625
# 	Physics Loss = 8705.4228515625
# 	Training Loss = 8710.4052734375
# 	Relative L2 error (test) = 100.00133514404297
# Iteration Number = 1860
# 	IC Loss = 0.6228774785995483
# 	BC Loss = 4.359150409698486
# 	Physics Loss = 8667.2021484375
# 	Training Loss = 8672.1845703125
# 	Relative L2 error (test) = 100.00604391098022
# Iteration Number = 1870
# 	IC Loss = 0.6228609085083008
# 	BC Loss = 4.358821868896484
# 	Physics Loss = 8769.6083984375
# 	Training Loss = 8774.58984375
# 	Relative L2 error (test) = 100.0028133392334
# Iteration Number = 1880
# 	IC Loss = 0.6228628158569336
# 	BC Loss = 4.358814716339111
# 	Physics Loss = 8204.5537109375
# 	Training Loss = 8209.53515625
# 	Relative L2 error (test) = 100.01236200332642
# Iteration Number = 1890
# 	IC Loss = 0.6228740215301514
# 	BC Loss = 4.358888626098633
# 	Physics Loss = 8099.04345703125
# 	Training Loss = 8104.025390625
# 	Relative L2 error (test) = 100.0022292137146
# Iteration Number = 1900
# 	IC Loss = 0.622848629951477
# 	BC Loss = 4.358524799346924
# 	Physics Loss = 8637.4150390625
# 	Training Loss = 8642.396484375
# 	Relative L2 error (test) = 100.00171661376953
# Iteration Number = 1910
# 	IC Loss = 0.6228708624839783
# 	BC Loss = 4.35896110534668
# 	Physics Loss = 8928.1044921875
# 	Training Loss = 8933.0859375
# 	Relative L2 error (test) = 100.00094175338745
# Iteration Number = 1920
# 	IC Loss = 0.6228474974632263
# 	BC Loss = 4.358539581298828
# 	Physics Loss = 8715.453125
# 	Training Loss = 8720.4345703125
# 	Relative L2 error (test) = 100.00021457672119
# Iteration Number = 1930
# 	IC Loss = 0.6228576898574829
# 	BC Loss = 4.358798503875732
# 	Physics Loss = 8780.3876953125
# 	Training Loss = 8785.369140625
# 	Relative L2 error (test) = 100.00123977661133
# Iteration Number = 1940
# 	IC Loss = 0.6228654384613037
# 	BC Loss = 4.358921527862549
# 	Physics Loss = 8597.4384765625
# 	Training Loss = 8602.419921875
# 	Relative L2 error (test) = 100.02052783966064
# Iteration Number = 1950
# 	IC Loss = 0.6228470802307129
# 	BC Loss = 4.358536243438721
# 	Physics Loss = 9037.1123046875
# 	Training Loss = 9042.09375
# 	Relative L2 error (test) = 100.01022815704346
# Iteration Number = 1960
# 	IC Loss = 0.6228885650634766
# 	BC Loss = 4.359294414520264
# 	Physics Loss = 8553.4755859375
# 	Training Loss = 8558.4580078125
# 	Relative L2 error (test) = 100.00190734863281
# Iteration Number = 1970
# 	IC Loss = 0.6229499578475952
# 	BC Loss = 4.360416889190674
# 	Physics Loss = 8442.484375
# 	Training Loss = 8447.4677734375
# 	Relative L2 error (test) = 100.00954866409302
# Iteration Number = 1980
# 	IC Loss = 0.6228534579277039
# 	BC Loss = 4.358699798583984
# 	Physics Loss = 8756.96484375
# 	Training Loss = 8761.9462890625
# 	Relative L2 error (test) = 100.01060962677002
# Iteration Number = 1990
# 	IC Loss = 0.6228543519973755
# 	BC Loss = 4.358566761016846
# 	Physics Loss = 8245.9150390625
# 	Training Loss = 8250.896484375
# 	Relative L2 error (test) = 100.05767345428467
# Iteration Number = 2000
# 	IC Loss = 0.6229403018951416
# 	BC Loss = 4.359781742095947
# 	Physics Loss = 8082.00634765625
# 	Training Loss = 8086.9892578125
# 	Relative L2 error (test) = 100.0340461730957
# Iteration Number = 2010
# 	IC Loss = 0.6228984594345093
# 	BC Loss = 4.359133243560791
# 	Physics Loss = 8701.5498046875
# 	Training Loss = 8706.5322265625
# 	Relative L2 error (test) = 100.00391006469727
# Iteration Number = 2020
# 	IC Loss = 0.6229272484779358
# 	BC Loss = 4.359450817108154
# 	Physics Loss = 8599.30078125
# 	Training Loss = 8604.283203125
# 	Relative L2 error (test) = 100.00032186508179
# Iteration Number = 2030
# 	IC Loss = 0.6228461861610413
# 	BC Loss = 4.358601093292236
# 	Physics Loss = 8920.3740234375
# 	Training Loss = 8925.35546875
# 	Relative L2 error (test) = 100.00455379486084
# Iteration Number = 2040
# 	IC Loss = 0.6228687763214111
# 	BC Loss = 4.359640598297119
# 	Physics Loss = 8197.080078125
# 	Training Loss = 8202.0625
# 	Relative L2 error (test) = 100.00663995742798
# Iteration Number = 2050
# 	IC Loss = 0.6229126453399658
# 	BC Loss = 4.360617637634277
# 	Physics Loss = 8401.6103515625
# 	Training Loss = 8406.59375
# 	Relative L2 error (test) = 100.00324249267578
# Iteration Number = 2060
# 	IC Loss = 0.622890830039978
# 	BC Loss = 4.358954906463623
# 	Physics Loss = 8613.5087890625
# 	Training Loss = 8618.490234375
# 	Relative L2 error (test) = 100.00320672988892
# Iteration Number = 2070
# 	IC Loss = 0.6230782270431519
# 	BC Loss = 4.361491680145264
# 	Physics Loss = 8733.21484375
# 	Training Loss = 8738.19921875
# 	Relative L2 error (test) = 100.05401372909546
# Iteration Number = 2080
# 	IC Loss = 0.6229380369186401
# 	BC Loss = 4.360061168670654
# 	Physics Loss = 8182.81640625
# 	Training Loss = 8187.79931640625
# 	Relative L2 error (test) = 100.00878572463989
# Iteration Number = 2090
# 	IC Loss = 0.6228803396224976
# 	BC Loss = 4.359182834625244
# 	Physics Loss = 8135.490234375
# 	Training Loss = 8140.47216796875
# 	Relative L2 error (test) = 100.00306367874146
# Iteration Number = 2100
# 	IC Loss = 0.6228615045547485
# 	BC Loss = 4.358916759490967
# 	Physics Loss = 8141.654296875
# 	Training Loss = 8146.63623046875
# 	Relative L2 error (test) = 100.04056692123413
# Iteration Number = 2110
# 	IC Loss = 0.6229256987571716
# 	BC Loss = 4.359630107879639
# 	Physics Loss = 8610.9599609375
# 	Training Loss = 8615.9423828125
# 	Relative L2 error (test) = 100.00786781311035
# Iteration Number = 2120
# 	IC Loss = 0.6228946447372437
# 	BC Loss = 4.359277725219727
# 	Physics Loss = 8310.0107421875
# 	Training Loss = 8314.9931640625
# 	Relative L2 error (test) = 100.00122785568237
# Iteration Number = 2130
# 	IC Loss = 0.6229686737060547
# 	BC Loss = 4.360348224639893
# 	Physics Loss = 8588.0185546875
# 	Training Loss = 8593.001953125
# 	Relative L2 error (test) = 100.00160932540894
# Iteration Number = 2140
# 	IC Loss = 0.6230630278587341
# 	BC Loss = 4.361598491668701
# 	Physics Loss = 8271.349609375
# 	Training Loss = 8276.333984375
# 	Relative L2 error (test) = 100.02535581588745
# Iteration Number = 2150
# 	IC Loss = 0.6229225397109985
# 	BC Loss = 4.359629154205322
# 	Physics Loss = 8568.5322265625
# 	Training Loss = 8573.5146484375
# 	Relative L2 error (test) = 100.10594129562378
# Iteration Number = 2160
# 	IC Loss = 0.6228525638580322
# 	BC Loss = 4.358615398406982
# 	Physics Loss = 8513.4013671875
# 	Training Loss = 8518.3828125
# 	Relative L2 error (test) = 100.03652572631836
# Iteration Number = 2170
# 	IC Loss = 0.6228609085083008
# 	BC Loss = 4.358772277832031
# 	Physics Loss = 8444.150390625
# 	Training Loss = 8449.1318359375
# 	Relative L2 error (test) = 100.00137090682983
# Iteration Number = 2180
# 	IC Loss = 0.6228793859481812
# 	BC Loss = 4.359128952026367
# 	Physics Loss = 8238.02734375
# 	Training Loss = 8243.009765625
# 	Relative L2 error (test) = 100.00536441802979
# Iteration Number = 2190
# 	IC Loss = 0.6228832006454468
# 	BC Loss = 4.359130859375
# 	Physics Loss = 8249.8896484375
# 	Training Loss = 8254.8720703125
# 	Relative L2 error (test) = 100.00983476638794
# Iteration Number = 2200
# 	IC Loss = 0.6230658292770386
# 	BC Loss = 4.362023830413818
# 	Physics Loss = 8222.7705078125
# 	Training Loss = 8227.755859375
# 	Relative L2 error (test) = 100.01295804977417
# Iteration Number = 2210
# 	IC Loss = 0.62295001745224
# 	BC Loss = 4.360479354858398
# 	Physics Loss = 8223.412109375
# 	Training Loss = 8228.3955078125
# 	Relative L2 error (test) = 100.01976490020752
# Iteration Number = 2220
# 	IC Loss = 0.622856616973877
# 	BC Loss = 4.358642101287842
# 	Physics Loss = 8824.802734375
# 	Training Loss = 8829.7841796875
# 	Relative L2 error (test) = 100.0116229057312
# Iteration Number = 2230
# 	IC Loss = 0.6228641867637634
# 	BC Loss = 4.358806610107422
# 	Physics Loss = 8736.4248046875
# 	Training Loss = 8741.40625
# 	Relative L2 error (test) = 100.00567436218262
# Iteration Number = 2240
# 	IC Loss = 0.6228645443916321
# 	BC Loss = 4.358798980712891
# 	Physics Loss = 8710.298828125
# 	Training Loss = 8715.2802734375
# 	Relative L2 error (test) = 100.00364780426025
# Iteration Number = 2250
# 	IC Loss = 0.6228633522987366
# 	BC Loss = 4.358768463134766
# 	Physics Loss = 8535.544921875
# 	Training Loss = 8540.5263671875
# 	Relative L2 error (test) = 100.003981590271
# Iteration Number = 2260
# 	IC Loss = 0.6228731274604797
# 	BC Loss = 4.359018325805664
# 	Physics Loss = 8888.0419921875
# 	Training Loss = 8893.0234375
# 	Relative L2 error (test) = 100.01600980758667
# Iteration Number = 2270
# 	IC Loss = 0.6229206323623657
# 	BC Loss = 4.359994888305664
# 	Physics Loss = 8783.0048828125
# 	Training Loss = 8787.98828125
# 	Relative L2 error (test) = 100.00731945037842
# Iteration Number = 2280
# 	IC Loss = 0.6228665113449097
# 	BC Loss = 4.358764171600342
# 	Physics Loss = 8543.8544921875
# 	Training Loss = 8548.8359375
# 	Relative L2 error (test) = 100.0062346458435
# Iteration Number = 2290
# 	IC Loss = 0.6228788495063782
# 	BC Loss = 4.358967304229736
# 	Physics Loss = 9008.71484375
# 	Training Loss = 9013.6962890625
# 	Relative L2 error (test) = 100.00207424163818
# Iteration Number = 2300
# 	IC Loss = 0.6228590607643127
# 	BC Loss = 4.358737945556641
# 	Physics Loss = 8676.91796875
# 	Training Loss = 8681.8994140625
# 	Relative L2 error (test) = 100.00208616256714
# Iteration Number = 2310
# 	IC Loss = 0.6229321956634521
# 	BC Loss = 4.359864234924316
# 	Physics Loss = 8572.4306640625
# 	Training Loss = 8577.4130859375
# 	Relative L2 error (test) = 100.00245571136475
# Iteration Number = 2320
# 	IC Loss = 0.622879147529602
# 	BC Loss = 4.359142780303955
# 	Physics Loss = 8479.8974609375
# 	Training Loss = 8484.8798828125
# 	Relative L2 error (test) = 100.00141859054565
# Iteration Number = 2330
# 	IC Loss = 0.6228709816932678
# 	BC Loss = 4.358870983123779
# 	Physics Loss = 8673.8505859375
# 	Training Loss = 8678.83203125
# 	Relative L2 error (test) = 100.0042200088501
# Iteration Number = 2340
# 	IC Loss = 0.6230521202087402
# 	BC Loss = 4.361347675323486
# 	Physics Loss = 8360.404296875
# 	Training Loss = 8365.388671875
# 	Relative L2 error (test) = 100.02925395965576
# Iteration Number = 2350
# 	IC Loss = 0.6229009628295898
# 	BC Loss = 4.35948371887207
# 	Physics Loss = 8748.234375
# 	Training Loss = 8753.216796875
# 	Relative L2 error (test) = 100.00091791152954
# Iteration Number = 2360
# 	IC Loss = 0.6228501796722412
# 	BC Loss = 4.358564376831055
# 	Physics Loss = 8600.2607421875
# 	Training Loss = 8605.2421875
# 	Relative L2 error (test) = 100.0029444694519
# Iteration Number = 2370
# 	IC Loss = 0.6228518486022949
# 	BC Loss = 4.358610153198242
# 	Physics Loss = 7902.2275390625
# 	Training Loss = 7907.208984375
# 	Relative L2 error (test) = 100.00125169754028
# Iteration Number = 2380
# 	IC Loss = 0.6228621006011963
# 	BC Loss = 4.3586812019348145
# 	Physics Loss = 8645.9599609375
# 	Training Loss = 8650.94140625
# 	Relative L2 error (test) = 100.00255107879639
# Iteration Number = 2390
# 	IC Loss = 0.6228495836257935
# 	BC Loss = 4.358564853668213
# 	Physics Loss = 8504.3896484375
# 	Training Loss = 8509.37109375
# 	Relative L2 error (test) = 100.00346899032593
# Iteration Number = 2400
# 	IC Loss = 0.6228536367416382
# 	BC Loss = 4.358687400817871
# 	Physics Loss = 8719.048828125
# 	Training Loss = 8724.0302734375
# 	Relative L2 error (test) = 100.00027418136597
# Iteration Number = 2410
# 	IC Loss = 0.6228588819503784
# 	BC Loss = 4.358650207519531
# 	Physics Loss = 8391.6484375
# 	Training Loss = 8396.6298828125
# 	Relative L2 error (test) = 100.01188516616821
# Iteration Number = 2420
# 	IC Loss = 0.6228581666946411
# 	BC Loss = 4.358645915985107
# 	Physics Loss = 8819.4033203125
# 	Training Loss = 8824.384765625
# 	Relative L2 error (test) = 100.00110864639282
# Iteration Number = 2430
# 	IC Loss = 0.6228609085083008
# 	BC Loss = 4.358707904815674
# ...
# Iteration Number = 2990
# 	IC Loss = 0.6228500008583069
# 	BC Loss = 4.358541488647461
# 	Physics Loss = 8820.7431640625
# 	Training Loss = 8825.724609375
# 	Relative L2 error (test) = 100.0004529953003
# Iteration Number = 3000
# 	IC Loss = 0.6228498220443726
# 	BC Loss = 4.35853910446167
# 	Physics Loss = 8592.98046875
# 	Training Loss = 8597.9619140625
# 	Relative L2 error (test) = 100.00036954879761
# Iteration Number = 3010
# 	IC Loss = 0.6228491067886353
# 	BC Loss = 4.358531475067139
# 	Physics Loss = 9075.4755859375
# 	Training Loss = 9080.45703125
# 	Relative L2 error (test) = 100.00026226043701
# Iteration Number = 3020
# 	IC Loss = 0.6228494048118591
# 	BC Loss = 4.358529567718506
# 	Physics Loss = 8303.951171875
# 	Training Loss = 8308.9326171875
# 	Relative L2 error (test) = 100.00035762786865
# Iteration Number = 3030
# 	IC Loss = 0.6228491067886353
# 	BC Loss = 4.3585205078125
# 	Physics Loss = 8432.5048828125
# 	Training Loss = 8437.486328125
# 	Relative L2 error (test) = 100.00014305114746
# Iteration Number = 3040
# 	IC Loss = 0.6228492259979248
# 	BC Loss = 4.358520030975342
# 	Physics Loss = 8198.7919921875
# 	Training Loss = 8203.7734375
# 	Relative L2 error (test) = 100.00015497207642
# Iteration Number = 3050
# 	IC Loss = 0.622847855091095
# 	BC Loss = 4.35850715637207
# 	Physics Loss = 8538.025390625
# 	Training Loss = 8543.0068359375
# 	Relative L2 error (test) = 99.99996423721313
# Iteration Number = 3060
# 	IC Loss = 0.6228471994400024
# 	BC Loss = 4.358503341674805
# 	Physics Loss = 8244.0966796875
# 	Training Loss = 8249.078125
# 	Relative L2 error (test) = 99.9999463558197
# Iteration Number = 3070
# 	IC Loss = 0.6228467226028442
# 	BC Loss = 4.3584980964660645
# 	Physics Loss = 9006.6728515625
# 	Training Loss = 9011.654296875
# 	Relative L2 error (test) = 99.99974966049194
# Iteration Number = 3080
# 	IC Loss = 0.6228469014167786
# 	BC Loss = 4.358499526977539
# 	Physics Loss = 8313.49609375
# 	Training Loss = 8318.4775390625
# 	Relative L2 error (test) = 99.99982118606567
# Iteration Number = 3090
# 	IC Loss = 0.6228474378585815
# 	BC Loss = 4.3585028648376465
# 	Physics Loss = 8354.9453125
# 	Training Loss = 8359.9267578125
# 	Relative L2 error (test) = 99.99987483024597
# Iteration Number = 3100
# 	IC Loss = 0.6228474974632263
# 	BC Loss = 4.358503341674805
# 	Physics Loss = 8844.30859375
# 	Training Loss = 8849.2900390625
# 	Relative L2 error (test) = 99.99986290931702
# Iteration Number = 3110
# 	IC Loss = 0.6228475570678711
# 	BC Loss = 4.358504772186279
# 	Physics Loss = 8302.1748046875
# 	Training Loss = 8307.15625
# 	Relative L2 error (test) = 99.99991059303284
# Iteration Number = 3120
# 	IC Loss = 0.6228469610214233
# 	BC Loss = 4.358501434326172
# 	Physics Loss = 8772.1826171875
# 	Training Loss = 8777.1640625
# 	Relative L2 error (test) = 99.99988079071045
# Iteration Number = 3130
# 	IC Loss = 0.6228471398353577
# 	BC Loss = 4.3585028648376465
# 	Physics Loss = 8253.755859375
# 	Training Loss = 8258.7373046875
# 	Relative L2 error (test) = 99.9998927116394
# Iteration Number = 3140
# 	IC Loss = 0.6228475570678711
# 	BC Loss = 4.358506679534912
# 	Physics Loss = 8403.6005859375
# 	Training Loss = 8408.58203125
# 	Relative L2 error (test) = 99.99991655349731
# Iteration Number = 3150
# 	IC Loss = 0.6228480339050293
# 	BC Loss = 4.358512878417969
# 	Physics Loss = 8117.76416015625
# 	Training Loss = 8122.74560546875
# 	Relative L2 error (test) = 99.99997019767761
# Iteration Number = 3160
# 	IC Loss = 0.6228479743003845
# 	BC Loss = 4.358513355255127
# 	Physics Loss = 8232.21875
# 	Training Loss = 8237.2001953125
# 	Relative L2 error (test) = 100.00002384185791
# Iteration Number = 3170
# 	IC Loss = 0.6228477954864502
# 	BC Loss = 4.358518123626709
# 	Physics Loss = 8663.69140625
# 	Training Loss = 8668.6728515625
# 	Relative L2 error (test) = 100.00011920928955
# Iteration Number = 3180
# 	IC Loss = 0.6228477358818054
# 	BC Loss = 4.3585124015808105
# 	Physics Loss = 8984.048828125
# 	Training Loss = 8989.0302734375
# 	Relative L2 error (test) = 99.9998390674591
# Iteration Number = 3190
# 	IC Loss = 0.6228475570678711
# 	BC Loss = 4.3585124015808105
# 	Physics Loss = 8627.232421875
# 	Training Loss = 8632.2138671875
# 	Relative L2 error (test) = 99.99989867210388
# Iteration Number = 3200
# 	IC Loss = 0.6228474378585815
# 	BC Loss = 4.3585124015808105
# 	Physics Loss = 8412.333984375
# 	Training Loss = 8417.3154296875
# 	Relative L2 error (test) = 99.99989867210388
# Iteration Number = 3210
# 	IC Loss = 0.6228477954864502
# 	BC Loss = 4.358517169952393
# 	Physics Loss = 8428.671875
# 	Training Loss = 8433.6533203125
# 	Relative L2 error (test) = 99.99987483024597
# Iteration Number = 3220
# 	IC Loss = 0.6228482127189636
# 	BC Loss = 4.358522891998291
# 	Physics Loss = 8401.4296875
# 	Training Loss = 8406.4111328125
# 	Relative L2 error (test) = 99.99998807907104
# Iteration Number = 3230
# 	IC Loss = 0.622848391532898
# 	BC Loss = 4.358528137207031
# 	Physics Loss = 8126.62255859375
# 	Training Loss = 8131.60400390625
# 	Relative L2 error (test) = 100.00005960464478
# Iteration Number = 3240
# 	IC Loss = 0.6228489875793457
# 	BC Loss = 4.35853385925293
# 	Physics Loss = 8654.6669921875
# 	Training Loss = 8659.6484375
# 	Relative L2 error (test) = 100.00005960464478
# Iteration Number = 3250
# 	IC Loss = 0.6228488683700562
# 	BC Loss = 4.358537197113037
# 	Physics Loss = 8744.53515625
# 	Training Loss = 8749.5166015625
# 	Relative L2 error (test) = 100.00026226043701
# Iteration Number = 3260
# 	IC Loss = 0.6228489279747009
# 	BC Loss = 4.358540058135986
# 	Physics Loss = 8427.0
# 	Training Loss = 8431.9814453125
# 	Relative L2 error (test) = 100.00021457672119
# Iteration Number = 3270
# 	IC Loss = 0.6228494644165039
# 	BC Loss = 4.358543872833252
# 	Physics Loss = 8372.0244140625
# 	Training Loss = 8377.005859375
# 	Relative L2 error (test) = 100.00021457672119
# Iteration Number = 3280
# 	IC Loss = 0.6228495240211487
# 	BC Loss = 4.358547210693359
# 	Physics Loss = 8511.283203125
# 	Training Loss = 8516.2646484375
# 	Relative L2 error (test) = 100.0001311302185
# Iteration Number = 3290
# 	IC Loss = 0.622849702835083
# 	BC Loss = 4.358547687530518
# 	Physics Loss = 8383.2841796875
# 	Training Loss = 8388.265625
# 	Relative L2 error (test) = 100.0001311302185
# Iteration Number = 3300
# 	IC Loss = 0.6228493452072144
# 	BC Loss = 4.358545303344727
# 	Physics Loss = 8314.0234375
# 	Training Loss = 8319.0048828125
# 	Relative L2 error (test) = 100.00011920928955
# Iteration Number = 3310
# 	IC Loss = 0.6228492856025696
# 	BC Loss = 4.358536243438721
# 	Physics Loss = 8746.6552734375
# 	Training Loss = 8751.63671875
# 	Relative L2 error (test) = 100.0003457069397
# Iteration Number = 3320
# 	IC Loss = 0.6228475570678711
# 	BC Loss = 4.358518600463867
# 	Physics Loss = 8263.201171875
# 	Training Loss = 8268.1826171875
# 	Relative L2 error (test) = 99.99982714653015
# Iteration Number = 3330
# 	IC Loss = 0.6228473782539368
# 	BC Loss = 4.358513355255127
# 	Physics Loss = 8660.5400390625
# 	Training Loss = 8665.521484375
# 	Relative L2 error (test) = 99.99993443489075
# Iteration Number = 3340
# 	IC Loss = 0.6228472590446472
# 	BC Loss = 4.358511447906494
# 	Physics Loss = 7981.79541015625
# 	Training Loss = 7986.77685546875
# 	Relative L2 error (test) = 99.99987483024597
# Iteration Number = 3350
# 	IC Loss = 0.6228474974632263
# 	BC Loss = 4.358516216278076
# 	Physics Loss = 8207.455078125
# 	Training Loss = 8212.4365234375
# 	Relative L2 error (test) = 99.9998927116394
# Iteration Number = 3360
# 	IC Loss = 0.6228474974632263
# 	BC Loss = 4.358513832092285
# 	Physics Loss = 8100.68798828125
# 	Training Loss = 8105.66943359375
# 	Relative L2 error (test) = 99.99991059303284
# Iteration Number = 3370
# 	IC Loss = 0.622847318649292
# 	BC Loss = 4.358510971069336
# 	Physics Loss = 8842.0791015625
# 	Training Loss = 8847.060546875
# 	Relative L2 error (test) = 99.99984502792358
# Iteration Number = 3380
# 	IC Loss = 0.6228468418121338
# 	BC Loss = 4.358503341674805
# 	Physics Loss = 8478.4482421875
# 	Training Loss = 8483.4296875
# 	Relative L2 error (test) = 99.99971985816956
# Iteration Number = 3390
# 	IC Loss = 0.6228466033935547
# 	BC Loss = 4.358498573303223
# 	Physics Loss = 8687.154296875
# 	Training Loss = 8692.1357421875
# 	Relative L2 error (test) = 99.9997079372406
# Iteration Number = 3400
# 	IC Loss = 0.6228467226028442
# 	BC Loss = 4.358500957489014
# 	Physics Loss = 8033.29736328125
# 	Training Loss = 8038.27880859375
# 	Relative L2 error (test) = 99.99973773956299
# Iteration Number = 3410
# 	IC Loss = 0.6228464841842651
# 	BC Loss = 4.358495712280273
# 	Physics Loss = 8408.1962890625
# 	Training Loss = 8413.177734375
# 	Relative L2 error (test) = 99.99963641166687
# Iteration Number = 3420
# 	IC Loss = 0.6228470802307129
# 	BC Loss = 4.3584980964660645
# 	Physics Loss = 8723.296875
# 	Training Loss = 8728.2783203125
# 	Relative L2 error (test) = 99.99971985816956
# Iteration Number = 3430
# 	IC Loss = 0.6228469610214233
# 	BC Loss = 4.358500957489014
# 	Physics Loss = 8433.3818359375
# 	Training Loss = 8438.36328125
# 	Relative L2 error (test) = 99.99987483024597
# Iteration Number = 3440
# 	IC Loss = 0.6228471994400024
# 	BC Loss = 4.35850191116333
# 	Physics Loss = 8606.712890625
# 	Training Loss = 8611.6943359375
# 	Relative L2 error (test) = 99.99971985816956
# Iteration Number = 3450
# 	IC Loss = 0.6228469014167786
# 	BC Loss = 4.3584980964660645
# 	Physics Loss = 8511.56640625
# 	Training Loss = 8516.5478515625
# 	Relative L2 error (test) = 99.99970197677612
# Iteration Number = 3460
# 	IC Loss = 0.6228464245796204
# 	BC Loss = 4.358497142791748
# 	Physics Loss = 8604.3681640625
# 	Training Loss = 8609.349609375
# 	Relative L2 error (test) = 99.99969005584717
# Iteration Number = 3470
# 	IC Loss = 0.6228464841842651
# 	BC Loss = 4.358495712280273
# 	Physics Loss = 8377.064453125
# 	Training Loss = 8382.0458984375
# 	Relative L2 error (test) = 99.99961853027344
# Iteration Number = 3480
# 	IC Loss = 0.6228465437889099
# 	BC Loss = 4.358497142791748
# 	Physics Loss = 8645.2060546875
# 	Training Loss = 8650.1875
# 	Relative L2 error (test) = 99.9996542930603
# Iteration Number = 3490
# 	IC Loss = 0.6228464841842651
# 	BC Loss = 4.358497142791748
# 	Physics Loss = 8811.548828125
# 	Training Loss = 8816.5302734375
# 	Relative L2 error (test) = 99.99966621398926
# Iteration Number = 3500
# 	IC Loss = 0.6228464841842651
# 	BC Loss = 4.358497142791748
# 	Physics Loss = 8504.1650390625
# 	Training Loss = 8509.146484375
# 	Relative L2 error (test) = 99.9996542930603
# Iteration Number = 3510
# 	IC Loss = 0.6228463649749756
# 	BC Loss = 4.358495235443115
# 	Physics Loss = 8933.146484375
# 	Training Loss = 8938.1279296875
# 	Relative L2 error (test) = 99.99960064888
# Iteration Number = 3520
# 	IC Loss = 0.6228463649749756
# 	BC Loss = 4.358494281768799
# 	Physics Loss = 8692.0146484375
# 	Training Loss = 8696.99609375
# 	Relative L2 error (test) = 99.99963641166687
# Iteration Number = 3530
# 	IC Loss = 0.6228463649749756
# 	BC Loss = 4.358494281768799
# 	Physics Loss = 8748.33203125
# 	Training Loss = 8753.3134765625
# 	Relative L2 error (test) = 99.99964833259583
# Iteration Number = 3540
# 	IC Loss = 0.6228464245796204
# 	BC Loss = 4.358495712280273
# 	Physics Loss = 8589.2841796875
# 	Training Loss = 8594.265625
# 	Relative L2 error (test) = 99.99964833259583
# Iteration Number = 3550
# 	IC Loss = 0.6228465437889099
# 	BC Loss = 4.3584980964660645
# 	Physics Loss = 9020.99609375
# 	Training Loss = 9025.9775390625
# 	Relative L2 error (test) = 99.99966621398926
# Iteration Number = 3560
# 	IC Loss = 0.6228466033935547
# 	BC Loss = 4.358500957489014
# 	Physics Loss = 8513.7607421875
# 	Training Loss = 8518.7421875
# 	Relative L2 error (test) = 99.99971985816956
# Iteration Number = 3570
# 	IC Loss = 0.6228470802307129
# 	BC Loss = 4.35850715637207
# 	Physics Loss = 8670.904296875
# 	Training Loss = 8675.8857421875
# 	Relative L2 error (test) = 99.99978542327881
# Iteration Number = 3580
# 	IC Loss = 0.6228482723236084
# 	BC Loss = 4.358527660369873
# 	Physics Loss = 8676.5048828125
# 	Training Loss = 8681.486328125
# 	Relative L2 error (test) = 100.00016689300537
# Iteration Number = 3590
# 	IC Loss = 0.6228516697883606
# 	BC Loss = 4.358577728271484
# 	Physics Loss = 8397.310546875
# 	Training Loss = 8402.2919921875
# 	Relative L2 error (test) = 100.00054836273193
# Iteration Number = 3600
# 	IC Loss = 0.6228524446487427
# 	BC Loss = 4.358593463897705
# 	Physics Loss = 8200.5224609375
# 	Training Loss = 8205.50390625
# 	Relative L2 error (test) = 100.00098943710327
# Iteration Number = 3610
# 	IC Loss = 0.6228538751602173
# 	BC Loss = 4.358631610870361
# 	Physics Loss = 8614.0380859375
# 	Training Loss = 8619.01953125
# 	Relative L2 error (test) = 100.00128746032715
# Iteration Number = 3620
# 	IC Loss = 0.6228640079498291
# 	BC Loss = 4.358755588531494
# 	Physics Loss = 8552.40234375
# 	Training Loss = 8557.3837890625
# 	Relative L2 error (test) = 100.0043272972107
# Iteration Number = 3630
# 	IC Loss = 0.6228622794151306
# 	BC Loss = 4.3587188720703125
# 	Physics Loss = 8505.3203125
# 	Training Loss = 8510.3017578125
# 	Relative L2 error (test) = 100.00174045562744
# Iteration Number = 3640
# 	IC Loss = 0.6228588819503784
# 	BC Loss = 4.35868501663208
# 	Physics Loss = 8278.048828125
# 	Training Loss = 8283.0302734375
# 	Relative L2 error (test) = 100.00320672988892
# Iteration Number = 3650
# 	IC Loss = 0.6228605508804321
# 	BC Loss = 4.358697891235352
# 	Physics Loss = 8641.46875
# 	Training Loss = 8646.4501953125
# 	Relative L2 error (test) = 100.0020980834961
# Iteration Number = 3660
# 	IC Loss = 0.622854471206665
# 	BC Loss = 4.3586273193359375
# 	Physics Loss = 8362.767578125
# 	Training Loss = 8367.7490234375
# 	Relative L2 error (test) = 100.00174045562744
# Iteration Number = 3670
# 	IC Loss = 0.6228594779968262
# 	BC Loss = 4.358675003051758
# 	Physics Loss = 8950.5244140625
# 	Training Loss = 8955.505859375
# 	Relative L2 error (test) = 100.00258684158325
# Iteration Number = 3680
# 	IC Loss = 0.6228538155555725
# 	BC Loss = 4.3586039543151855
# 	Physics Loss = 8263.8515625
# 	Training Loss = 8268.8330078125
# 	Relative L2 error (test) = 100.00158548355103
# Iteration Number = 3690
# 	IC Loss = 0.622856080532074
# 	BC Loss = 4.358615398406982
# 	Physics Loss = 8387.05859375
# 	Training Loss = 8392.0400390625
# 	Relative L2 error (test) = 100.00250339508057
# Iteration Number = 3700
# 	IC Loss = 0.6228587627410889
# 	BC Loss = 4.35862922668457
# 	Physics Loss = 8499.8095703125
# 	Training Loss = 8504.791015625
# 	Relative L2 error (test) = 100.00215768814087
# Iteration Number = 3710
# 	IC Loss = 0.6228587031364441
# 	BC Loss = 4.358672618865967
# 	Physics Loss = 8373.8486328125
# 	Training Loss = 8378.830078125
# 	Relative L2 error (test) = 100.00441074371338
# Iteration Number = 3720
# 	IC Loss = 0.6228599548339844
# 	BC Loss = 4.358633041381836
# 	Physics Loss = 8246.943359375
# 	Training Loss = 8251.9248046875
# 	Relative L2 error (test) = 100.0031590461731
# Iteration Number = 3730
# 	IC Loss = 0.6228530406951904
# 	BC Loss = 4.358597278594971
# 	Physics Loss = 8877.8505859375
# 	Training Loss = 8882.83203125
# 	Relative L2 error (test) = 100.00268220901489
# Iteration Number = 3740
# 	IC Loss = 0.6228522062301636
# 	BC Loss = 4.358546733856201
# 	Physics Loss = 8706.994140625
# 	Training Loss = 8711.9755859375
# 	Relative L2 error (test) = 100.0009298324585
# Iteration Number = 3750
# 	IC Loss = 0.6228498220443726
# 	BC Loss = 4.358537673950195
# 	Physics Loss = 8279.65234375
# 	Training Loss = 8284.6337890625
# 	Relative L2 error (test) = 100.00113248825073
# Iteration Number = 3760
# 	IC Loss = 0.6228523254394531
# 	BC Loss = 4.358547210693359
# 	Physics Loss = 8607.1298828125
# 	Training Loss = 8612.111328125
# 	Relative L2 error (test) = 100.00098943710327
# Iteration Number = 3770
# 	IC Loss = 0.6228504180908203
# 	BC Loss = 4.358540058135986
# 	Physics Loss = 8891.2353515625
# 	Training Loss = 8896.216796875
# 	Relative L2 error (test) = 100.00064373016357
# Iteration Number = 3780
# 	IC Loss = 0.6228473782539368
# 	BC Loss = 4.358509540557861
# 	Physics Loss = 8231.314453125
# 	Training Loss = 8236.2958984375
# 	Relative L2 error (test) = 99.99986290931702
# Iteration Number = 3790
# 	IC Loss = 0.6228470802307129
# 	BC Loss = 4.35850715637207
# 	Physics Loss = 8655.3662109375
# 	Training Loss = 8660.34765625
# 	Relative L2 error (test) = 99.99971985816956
# Iteration Number = 3800
# 	IC Loss = 0.6228471994400024
# 	BC Loss = 4.3585076332092285
# 	Physics Loss = 8439.5068359375
# 	Training Loss = 8444.48828125
# 	Relative L2 error (test) = 99.99972581863403
# Iteration Number = 3810
# 	IC Loss = 0.6228499412536621
# 	BC Loss = 4.358543395996094
# 	Physics Loss = 8570.4462890625
# 	Training Loss = 8575.427734375
# 	Relative L2 error (test) = 99.99991059303284
# KeyboardInterrupt
